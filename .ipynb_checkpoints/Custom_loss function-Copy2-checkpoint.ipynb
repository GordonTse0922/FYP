# %%
import yfinance as yf
import keras.backend as K
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler ,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score, mean_squared_error,mean_absolute_percentage_error
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
import tensorflow as tf
import seaborn as sns
from tensorflow import keras
from keras.layers import LSTM,Dropout, BatchNormalization, Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras.models import Sequential
from keras.optimizer_v2.adam import Adam
from keras.optimizer_v2.rmsprop import RMSprop
import talib
tf.config.run_functions_eagerly(True)
tf.data.experimental.enable_debug_mode()

# %%
# Get the data for the SPY ETF by specifying the stock ticker, start date, and end date
data = yf.download('0098.hk')
data.columns
# Out:
# [*********************100%***********************]  1 of 1 completed
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data['H-L'] = data['High'] - data['Low']
data['O-C'] = data['Close'] - data['Open']
# data=pd.merge(data,data["Close"].pct_change(),left_index=True,right_index=True)
data["% Change"]=data["Close"].pct_change(7)
data['7day MA'] = data['Close'].shift(1).rolling(window = 7).mean()
data['14day MA'] = data['Close'].shift(1).rolling(window = 14).mean()
data['21day MA'] = data['Close'].shift(1).rolling(window = 21).mean()
data['Std_dev']= data['Close'].shift(1).rolling(7).std()
data['RSI'] = talib.RSI(data['Close'].values, timeperiod = 7)
data['Williams %R'] = talib.WILLR(data['High'].values, data['Low'].values, data['Close'].values, 7)
data
# Out:
#              Open   High   Low  Close  Adj Close    Volume   H-L       O-C  \
# Date
# 2008-03-31   2.21   2.21  2.09   2.11   1.491716  29090000  0.12 -0.100000
# 2008-04-01   2.17   2.26  2.08   2.09   1.477577   7606000  0.18 -0.080000
# 2008-04-02   2.21   2.24  2.12   2.18   1.541204  12680000  0.12 -0.030000
# 2008-04-03   2.17   2.22  2.15   2.19   1.548274   3905000  0.07  0.020000
# 2008-04-07   2.20   2.32  2.17   2.23   1.576553   9895000  0.15  0.030000
# ...           ...    ...   ...    ...        ...       ...   ...       ...
# 2021-10-20  10.28  10.28  9.76   9.87   9.870000     26000  0.52 -0.410000
# 2021-10-21   9.87   9.87  9.74   9.74   9.740000    113000  0.13 -0.130000
# 2021-10-22   9.75   9.79  9.62   9.79   9.790000    114000  0.17  0.040000
# 2021-10-25   9.86   9.86  9.70   9.85   9.850000     10000  0.16 -0.009999
# 2021-10-26   9.68   9.68  9.46   9.48   9.480000     47000  0.22 -0.200001
#
#             % Change   7day MA  14day MA   21day MA   Std_dev        RSI  \
# Date
# 2008-03-31       NaN       NaN       NaN        NaN       NaN        NaN
# 2008-04-01       NaN       NaN       NaN        NaN       NaN        NaN
# 2008-04-02       NaN       NaN       NaN        NaN       NaN        NaN
# 2008-04-03       NaN       NaN       NaN        NaN       NaN        NaN
# 2008-04-07       NaN       NaN       NaN        NaN       NaN        NaN
# ...              ...       ...       ...        ...       ...        ...
# 2021-10-20  0.056745  9.525714  9.750000  10.193333  0.161437  51.135335
# 2021-10-21  0.040598  9.601428  9.699286  10.120476  0.182705  43.903897
# 2021-10-22  0.031612  9.655714  9.656428  10.049048  0.153064  47.251170
# 2021-10-25  0.037935  9.698571  9.612857   9.982857  0.140407  51.318002
# 2021-10-26 -0.004202  9.750000  9.636428   9.921428  0.114891  33.008829
#
#             Williams %R
# Date
# 2008-03-31          NaN
# 2008-04-01          NaN
# 2008-04-02          NaN
# 2008-04-03          NaN
# 2008-04-07          NaN
# ...                 ...
# 2021-10-20   -44.565197
# 2021-10-21   -68.354429
# 2021-10-22   -62.025290
# 2021-10-25   -58.904058
# 2021-10-26   -97.561035
#
# [3056 rows x 15 columns]

# %%
data.isnull().sum()
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# H-L             0
# O-C             0
# % Change        7
# 7day MA         7
# 14day MA       14
# 21day MA       21
# Std_dev         7
# RSI             7
# Williams %R     6
# dtype: int64

# %%
data.dropna(inplace=True,axis=0)
data
# Out:
#              Open   High   Low  Close  Adj Close   Volume   H-L       O-C  \
# Date
# 2008-04-30   2.12   2.14  2.01   2.10   1.484646  1467000  0.13 -0.020000
# 2008-05-02   2.12   2.15  2.06   2.11   1.491716   937000  0.09 -0.010000
# 2008-05-05   2.13   2.16  2.10   2.13   1.505856   673000  0.06  0.000000
# 2008-05-06   2.11   2.15  2.10   2.13   1.505856  1488000  0.05  0.020000
# 2008-05-07   2.15   2.15  2.07   2.09   1.477577   696000  0.08 -0.060000
# ...           ...    ...   ...    ...        ...      ...   ...       ...
# 2021-10-20  10.28  10.28  9.76   9.87   9.870000    26000  0.52 -0.410000
# 2021-10-21   9.87   9.87  9.74   9.74   9.740000   113000  0.13 -0.130000
# 2021-10-22   9.75   9.79  9.62   9.79   9.790000   114000  0.17  0.040000
# 2021-10-25   9.86   9.86  9.70   9.85   9.850000    10000  0.16 -0.009999
# 2021-10-26   9.68   9.68  9.46   9.48   9.480000    47000  0.22 -0.200001
#
#             % Change   7day MA  14day MA   21day MA   Std_dev        RSI  \
# Date
# 2008-04-30 -0.018692  2.144286  2.167143   2.175238  0.021492  34.882569
# 2008-05-02 -0.018605  2.138571  2.160000   2.174762  0.027343  39.393817
# 2008-05-05 -0.022936  2.132857  2.153571   2.175714  0.028702  47.827595
# 2008-05-06 -0.013889  2.125714  2.150000   2.173333  0.019881  47.827595
# 2008-05-07 -0.023365  2.121429  2.143571   2.170476  0.013452  34.687484
# ...              ...       ...       ...        ...       ...        ...
# 2021-10-20  0.056745  9.525714  9.750000  10.193333  0.161437  51.135335
# 2021-10-21  0.040598  9.601428  9.699286  10.120476  0.182705  43.903897
# 2021-10-22  0.031612  9.655714  9.656428  10.049048  0.153064  47.251170
# 2021-10-25  0.037935  9.698571  9.612857   9.982857  0.140407  51.318002
# 2021-10-26 -0.004202  9.750000  9.636428   9.921428  0.114891  33.008829
#
#             Williams %R
# Date
# 2008-04-30   -65.384647
# 2008-05-02   -61.538497
# 2008-05-05   -53.846104
# 2008-05-06   -36.842059
# 2008-05-07   -52.941242
# ...                 ...
# 2021-10-20   -44.565197
# 2021-10-21   -68.354429
# 2021-10-22   -62.025290
# 2021-10-25   -58.904058
# 2021-10-26   -97.561035
#
# [3035 rows x 15 columns]

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
cor_target = abs(cor["Close"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# Open         0.999215
# High         0.999509
# Low          0.999340
# Close        1.000000
# Adj Close    0.997427
# 7day MA      0.997601
# 14day MA     0.995439
# 21day MA     0.993116
# Std_dev      0.578952
# Name: Close, dtype: float64

# %%
# print(data[["RSI","Williams %R"]].corr())

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
correlated_features = cor[cor>0.1].index.tolist()
corr_matrix = data[correlated_features].corr()
sns.heatmap(corr_matrix, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
features = ["Open","High","Low","Close","Volume","H-L","O-C","7day MA","14day MA","21day MA","Std_dev"]
X=data.drop(["Close","Adj Close"],1)
y=data['Close']
reg = RidgeCV()
reg.fit(X, y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,y))
coef = pd.Series(reg.coef_, index = X.columns)
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
imp_coef = coef.sort_values()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
# Out:
# Best alpha using built-in LassoCV: 0.100000
# Best score using built-in LassoCV: 0.938447
# Lasso picked 13 variables and eliminated the other 0 variables
# Text(0.5, 1.0, 'Feature importance using Lasso Model')

# %%
data.drop("Volume",1)
# Out:
#              Open   High   Low  Close  Adj Close   H-L       O-C  % Change  \
# Date
# 2008-04-30   2.12   2.14  2.01   2.10   1.484646  0.13 -0.020000 -0.018692
# 2008-05-02   2.12   2.15  2.06   2.11   1.491716  0.09 -0.010000 -0.018605
# 2008-05-05   2.13   2.16  2.10   2.13   1.505856  0.06  0.000000 -0.022936
# 2008-05-06   2.11   2.15  2.10   2.13   1.505856  0.05  0.020000 -0.013889
# 2008-05-07   2.15   2.15  2.07   2.09   1.477577  0.08 -0.060000 -0.023365
# ...           ...    ...   ...    ...        ...   ...       ...       ...
# 2021-10-20  10.28  10.28  9.76   9.87   9.870000  0.52 -0.410000  0.056745
# 2021-10-21   9.87   9.87  9.74   9.74   9.740000  0.13 -0.130000  0.040598
# 2021-10-22   9.75   9.79  9.62   9.79   9.790000  0.17  0.040000  0.031612
# 2021-10-25   9.86   9.86  9.70   9.85   9.850000  0.16 -0.009999  0.037935
# 2021-10-26   9.68   9.68  9.46   9.48   9.480000  0.22 -0.200001 -0.004202
#
#              7day MA  14day MA   21day MA   Std_dev        RSI  Williams %R
# Date
# 2008-04-30  2.144286  2.167143   2.175238  0.021492  34.882569   -65.384647
# 2008-05-02  2.138571  2.160000   2.174762  0.027343  39.393817   -61.538497
# 2008-05-05  2.132857  2.153571   2.175714  0.028702  47.827595   -53.846104
# 2008-05-06  2.125714  2.150000   2.173333  0.019881  47.827595   -36.842059
# 2008-05-07  2.121429  2.143571   2.170476  0.013452  34.687484   -52.941242
# ...              ...       ...        ...       ...        ...          ...
# 2021-10-20  9.525714  9.750000  10.193333  0.161437  51.135335   -44.565197
# 2021-10-21  9.601428  9.699286  10.120476  0.182705  43.903897   -68.354429
# 2021-10-22  9.655714  9.656428  10.049048  0.153064  47.251170   -62.025290
# 2021-10-25  9.698571  9.612857   9.982857  0.140407  51.318002   -58.904058
# 2021-10-26  9.750000  9.636428   9.921428  0.114891  33.008829   -97.561035
#
# [3035 rows x 14 columns]

# %%
def trim_dataset(mat, batch_size):
    
    #trims dataset to a size that's divisible by BATCH_SIZE
    no_of_rows_drop = mat.shape[0] % batch_size

    if no_of_rows_drop > 0:
        return mat[:-no_of_rows_drop]
    else:
        return mat
    
def build_timeseries(mat, y_col_index):
    
    dim_0 = mat.shape[0] - TIME_STEPS
    dim_1 = mat.shape[1]

    x = np.zeros((dim_0, TIME_STEPS, dim_1))
    y = np.zeros((dim_0,))

    print("Length of inputs", dim_0)

    for i in range(dim_0):
        x[i] = mat[i:TIME_STEPS+i]
        y[i] = mat[TIME_STEPS+i, y_col_index]

    print("length of time-series - inputs", x.shape)
    print("length of time-series - outputs", y.shape)

    return x, y

train_cols = ["Close","H-L","O-C","7day MA","14day MA","21day MA","% Change"]
params = {
    "batch_size": 20,  # 20<16<10, 25 was a bust
    "epochs": 300,
    "lr": 0.00010000,
    "time_steps": 30
}
TIME_STEPS = params["time_steps"]
BATCH_SIZE = params["batch_size"]
df_train, df_test = train_test_split(data, train_size=0.8, test_size=0.2, shuffle=False)
print("Train--Test size", len(df_train), len(df_test))
x = df_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler()
x_train = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.transform(df_test.loc[:,train_cols])
x_t, y_t = build_timeseries(x_train, 0)
x_t = trim_dataset(x_t, BATCH_SIZE)
y_t = trim_dataset(y_t, BATCH_SIZE)
# print(x_test.shape)
print("Batch trimmed size", x_t.shape, y_t.shape)
# Out:
# Train--Test size 2428 607
# Length of inputs 2398
# length of time-series - inputs (2398, 30, 7)
# length of time-series - outputs (2398,)
# Batch trimmed size (2380, 30, 7) (2380,)

# %%
'''Step 9 - Construct customized loss function for training'''
def custom_loss(y_true, y_pred):
    
    #extract the "next day's price" of tensor
    y_true_next = y_true[1:]
    y_pred_next = y_pred[1:]
    
    #extract the "today's price" of tensor
    y_true_tdy = y_true[:-1]
    y_pred_tdy = y_pred[:-1]
    
    print('Shape of y_pred_back -', y_pred_tdy.get_shape())
    
    #substract to get up/down movement of the two tensors
    y_true_diff = tf.subtract(y_true_next, y_true_tdy)
    y_pred_diff = tf.subtract(y_pred_next, y_pred_tdy)
        
    #create a standard tensor with zero value for comparison
    standard = tf.zeros_like(y_pred_diff)
    
    #compare with the standard; if true, UP; else DOWN
    y_true_move = tf.greater_equal(y_true_diff, standard)
    y_pred_move = tf.greater_equal(y_pred_diff, standard)
    y_true_move = tf.reshape(y_true_move, [-1])
    y_pred_move = tf.reshape(y_pred_move, [-1])
    

    #find indices where the directions are not the same
    condition = tf.not_equal(y_true_move, y_pred_move)
    indices = tf.where(condition)

    #move one position later
    ones = tf.ones_like(indices)
    indices = tf.add(indices, ones)
    indices = K.cast(indices, dtype='int32')
    
    
    #create a tensor to store directional loss and put it into custom loss output
    direction_loss = tf.Variable(tf.ones_like(y_pred), dtype='float32')
    updates = K.cast(tf.ones_like(indices), dtype='float32')
    alpha = 1000
    direction_loss = tf.compat.v1.scatter_nd_update(direction_loss, indices, alpha*updates)
    
    custom_loss = K.mean(tf.multiply(K.square(y_true - y_pred), direction_loss), axis=-1)
    
    return custom_loss

# %%
'''Step 10 - Build LSTM model'''

def create_lstm_model():
    lstm_model = Sequential()
    lstm_model.add(LSTM(100, batch_input_shape=(BATCH_SIZE, TIME_STEPS, x_t.shape[2]),
                        dropout=0.0, recurrent_dropout=0.0,
                        stateful=True, return_sequences=True,
                        kernel_initializer='random_uniform'))
    lstm_model.add(Dropout(0.2))

    lstm_model.add(LSTM(100, dropout=0.0))
    lstm_model.add(Dropout(0.2))
    
#     lstm_model.add(Dense(32))
    lstm_model.add(Dense(1))
        
    #compile the model
    optimizer = Adam(lr=params["lr"])
    lstm_model.compile(loss=custom_loss, optimizer=optimizer)
  
    return lstm_model

lstm_model = None

# %%
# lstm_model = Sequential()
#     # (batch_size, timesteps, data_dim)
# lstm_model.add(LSTM(100, batch_input_shape=(BATCH_SIZE, TIME_STEPS, x_t.shape[2]),
#                     dropout=0.0, recurrent_dropout=0.0, stateful=True, return_sequences=True,
#                     kernel_initializer='random_uniform'))
# # lstm_model.add(Dropout(0.4))
# lstm_model.add(LSTM(60, dropout=0.0))
# # lstm_model.add(Dropout(0.4))
# lstm_model.add(Dense(20,activation='relu'))
# lstm_model.add(Dense(1,activation='sigmoid'))
# optimizer = RMSprop(learning_rate=params["lr"])
# # optimizer = optimizers.SGD(lr=0.000001, decay=1e-6, momentum=0.9, nesterov=True)
# lstm_model.compile(loss=custom_loss, optimizer=optimizer)

# %%
x_temp, y_temp = build_timeseries(x_test, 3)
x_val, x_test_t = np.split(trim_dataset(x_temp, BATCH_SIZE),2)
y_val, y_test_t = np.split(trim_dataset(y_temp, BATCH_SIZE),2)
# Out:
# Length of inputs 577
# length of time-series - inputs (577, 30, 7)
# length of time-series - outputs (577,)

# %%
lstm_model = create_lstm_model()
print(lstm_model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (20, 30, 100)             43200
# _________________________________________________________________
# dropout (Dropout)            (20, 30, 100)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (20, 100)                 80400
# _________________________________________________________________
# dropout_1 (Dropout)          (20, 100)                 0
# _________________________________________________________________
# dense (Dense)                (20, 1)                   101
# =================================================================
# Total params: 123,701
# Trainable params: 123,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# /home/gordon/anaconda3/envs/FYP/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:357: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
# es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=40, min_delta=0.0001)
history = lstm_model.fit(x_t, y_t, epochs=params["epochs"], batch_size=BATCH_SIZE,
                        shuffle=False, validation_data=(trim_dataset(x_val, BATCH_SIZE),
                        trim_dataset(y_val, BATCH_SIZE)))
# Out:
# Epoch 1/300
# Shape of y_pred_back - (19, 1)
#   1/119 [..............................] - ETA: 1:46 - loss: 33.5708Shape of y_pred_back - (19, 1)
#   2/119 [..............................] - ETA: 7s - loss: 31.5861  Shape of y_pred_back - (19, 1)
#   3/119 [..............................] - ETA: 7s - loss: 28.5371Shape of y_pred_back - (19, 1)
#   4/119 [>.............................] - ETA: 7s - loss: 25.7682Shape of y_pred_back - (19, 1)
#   5/119 [>.............................] - ETA: 6s - loss: 23.4657Shape of y_pred_back - (19, 1)
#   6/119 [>.............................] - ETA: 7s - loss: 21.5601Shape of y_pred_back - (19, 1)
#   7/119 [>.............................] - ETA: 7s - loss: 20.0131Shape of y_pred_back - (19, 1)
#   8/119 [=>............................] - ETA: 7s - loss: 18.7206Shape of y_pred_back - (19, 1)
#   9/119 [=>............................] - ETA: 6s - loss: 17.6207Shape of y_pred_back - (19, 1)
#  10/119 [=>............................] - ETA: 6s - loss: 16.6892Shape of y_pred_back - (19, 1)
#  11/119 [=>............................] - ETA: 6s - loss: 15.8957Shape of y_pred_back - (19, 1)
#  12/119 [==>...........................] - ETA: 6s - loss: 15.2561Shape of y_pred_back - (19, 1)
#  13/119 [==>...........................] - ETA: 6s - loss: 14.6972Shape of y_pred_back - (19, 1)
#  14/119 [==>...........................] - ETA: 6s - loss: 14.2310Shape of y_pred_back - (19, 1)
#  15/119 [==>...........................] - ETA: 6s - loss: 13.8145Shape of y_pred_back - (19, 1)
#  16/119 [===>..........................] - ETA: 6s - loss: 13.4413Shape of y_pred_back - (19, 1)
#  17/119 [===>..........................] - ETA: 6s - loss: 13.1096Shape of y_pred_back - (19, 1)
#  18/119 [===>..........................] - ETA: 6s - loss: 12.8045Shape of y_pred_back - (19, 1)
#  19/119 [===>..........................] - ETA: 6s - loss: 12.5172Shape of y_pred_back - (19, 1)
#  20/119 [====>.........................] - ETA: 6s - loss: 12.2455Shape of y_pred_back - (19, 1)
#  21/119 [====>.........................] - ETA: 6s - loss: 11.9886Shape of y_pred_back - (19, 1)
#  22/119 [====>.........................] - ETA: 6s - loss: 11.7460Shape of y_pred_back - (19, 1)
#  23/119 [====>.........................] - ETA: 5s - loss: 11.5162Shape of y_pred_back - (19, 1)
#  24/119 [=====>........................] - ETA: 5s - loss: 11.2964Shape of y_pred_back - (19, 1)
#  25/119 [=====>........................] - ETA: 5s - loss: 11.0866Shape of y_pred_back - (19, 1)
#  26/119 [=====>........................] - ETA: 5s - loss: 10.8856Shape of y_pred_back - (19, 1)
#  27/119 [=====>........................] - ETA: 5s - loss: 10.6923Shape of y_pred_back - (19, 1)
#  28/119 [======>.......................] - ETA: 5s - loss: 10.5057Shape of y_pred_back - (19, 1)
#  29/119 [======>.......................] - ETA: 5s - loss: 10.3256Shape of y_pred_back - (19, 1)
#  30/119 [======>.......................] - ETA: 5s - loss: 10.1540Shape of y_pred_back - (19, 1)
#  31/119 [======>.......................] - ETA: 5s - loss: 9.9909 Shape of y_pred_back - (19, 1)
#  32/119 [=======>......................] - ETA: 5s - loss: 9.8353Shape of y_pred_back - (19, 1)
#  33/119 [=======>......................] - ETA: 5s - loss: 9.6848Shape of y_pred_back - (19, 1)
#  34/119 [=======>......................] - ETA: 5s - loss: 9.5391Shape of y_pred_back - (19, 1)
#  35/119 [=======>......................] - ETA: 5s - loss: 9.3981Shape of y_pred_back - (19, 1)
#  36/119 [========>.....................] - ETA: 5s - loss: 9.2616Shape of y_pred_back - (19, 1)
#  37/119 [========>.....................] - ETA: 5s - loss: 9.1295Shape of y_pred_back - (19, 1)
#  38/119 [========>.....................] - ETA: 5s - loss: 9.0015Shape of y_pred_back - (19, 1)
#  39/119 [========>.....................] - ETA: 4s - loss: 8.8775Shape of y_pred_back - (19, 1)
#  40/119 [=========>....................] - ETA: 4s - loss: 8.7581Shape of y_pred_back - (19, 1)
#  41/119 [=========>....................] - ETA: 4s - loss: 8.6431Shape of y_pred_back - (19, 1)
#  42/119 [=========>....................] - ETA: 4s - loss: 8.5327Shape of y_pred_back - (19, 1)
#  43/119 [=========>....................] - ETA: 4s - loss: 8.4277Shape of y_pred_back - (19, 1)
#  44/119 [==========>...................] - ETA: 4s - loss: 8.3268Shape of y_pred_back - (19, 1)
#  45/119 [==========>...................] - ETA: 4s - loss: 8.2324Shape of y_pred_back - (19, 1)
#  46/119 [==========>...................] - ETA: 4s - loss: 8.1419Shape of y_pred_back - (19, 1)
#  47/119 [==========>...................] - ETA: 4s - loss: 8.0555Shape of y_pred_back - (19, 1)
#  48/119 [===========>..................] - ETA: 4s - loss: 7.9721Shape of y_pred_back - (19, 1)
#  49/119 [===========>..................] - ETA: 4s - loss: 7.8913Shape of y_pred_back - (19, 1)
#  50/119 [===========>..................] - ETA: 4s - loss: 7.8129Shape of y_pred_back - (19, 1)
#  51/119 [===========>..................] - ETA: 4s - loss: 7.7365Shape of y_pred_back - (19, 1)
#  52/119 [============>.................] - ETA: 4s - loss: 7.6615Shape of y_pred_back - (19, 1)
#  53/119 [============>.................] - ETA: 4s - loss: 7.5882Shape of y_pred_back - (19, 1)
#  54/119 [============>.................] - ETA: 4s - loss: 7.5163Shape of y_pred_back - (19, 1)
#  55/119 [============>.................] - ETA: 3s - loss: 7.4458Shape of y_pred_back - (19, 1)
#  56/119 [=============>................] - ETA: 3s - loss: 7.3769Shape of y_pred_back - (19, 1)
#  57/119 [=============>................] - ETA: 3s - loss: 7.3094Shape of y_pred_back - (19, 1)
#  58/119 [=============>................] - ETA: 3s - loss: 7.2433Shape of y_pred_back - (19, 1)
#  59/119 [=============>................] - ETA: 3s - loss: 7.1786Shape of y_pred_back - (19, 1)
#  60/119 [==============>...............] - ETA: 3s - loss: 7.1153Shape of y_pred_back - (19, 1)
#  61/119 [==============>...............] - ETA: 3s - loss: 7.0534Shape of y_pred_back - (19, 1)
#  62/119 [==============>...............] - ETA: 3s - loss: 6.9930Shape of y_pred_back - (19, 1)
#  63/119 [==============>...............] - ETA: 3s - loss: 6.9341Shape of y_pred_back - (19, 1)
#  64/119 [===============>..............] - ETA: 3s - loss: 6.8767Shape of y_pred_back - (19, 1)
#  65/119 [===============>..............] - ETA: 3s - loss: 6.8204Shape of y_pred_back - (19, 1)
#  66/119 [===============>..............] - ETA: 3s - loss: 6.7652Shape of y_pred_back - (19, 1)
#  67/119 [===============>..............] - ETA: 3s - loss: 6.7114Shape of y_pred_back - (19, 1)
#  68/119 [================>.............] - ETA: 3s - loss: 6.6593Shape of y_pred_back - (19, 1)
#  69/119 [================>.............] - ETA: 3s - loss: 6.6083Shape of y_pred_back - (19, 1)
#  70/119 [================>.............] - ETA: 3s - loss: 6.5584Shape of y_pred_back - (19, 1)
#  71/119 [================>.............] - ETA: 2s - loss: 6.5094Shape of y_pred_back - (19, 1)
#  72/119 [=================>............] - ETA: 2s - loss: 6.4613Shape of y_pred_back - (19, 1)
#  73/119 [=================>............] - ETA: 2s - loss: 6.4140Shape of y_pred_back - (19, 1)
#  74/119 [=================>............] - ETA: 2s - loss: 6.3675Shape of y_pred_back - (19, 1)
#  75/119 [=================>............] - ETA: 2s - loss: 6.3230Shape of y_pred_back - (19, 1)
#  76/119 [==================>...........] - ETA: 2s - loss: 6.2850Shape of y_pred_back - (19, 1)
#  77/119 [==================>...........] - ETA: 2s - loss: 6.2515Shape of y_pred_back - (19, 1)
#  78/119 [==================>...........] - ETA: 2s - loss: 6.2187Shape of y_pred_back - (19, 1)
#  79/119 [==================>...........] - ETA: 2s - loss: 6.1867Shape of y_pred_back - (19, 1)
#  80/119 [===================>..........] - ETA: 2s - loss: 6.1551Shape of y_pred_back - (19, 1)
#  81/119 [===================>..........] - ETA: 2s - loss: 6.1241Shape of y_pred_back - (19, 1)
#  82/119 [===================>..........] - ETA: 2s - loss: 6.0937Shape of y_pred_back - (19, 1)
#  83/119 [===================>..........] - ETA: 2s - loss: 6.0638Shape of y_pred_back - (19, 1)
#  84/119 [====================>.........] - ETA: 2s - loss: 6.0341Shape of y_pred_back - (19, 1)
#  85/119 [====================>.........] - ETA: 2s - loss: 6.0047Shape of y_pred_back - (19, 1)
#  86/119 [====================>.........] - ETA: 2s - loss: 5.9757Shape of y_pred_back - (19, 1)
#  87/119 [====================>.........] - ETA: 1s - loss: 5.9468Shape of y_pred_back - (19, 1)
#  88/119 [=====================>........] - ETA: 1s - loss: 5.9182Shape of y_pred_back - (19, 1)
#  89/119 [=====================>........] - ETA: 1s - loss: 5.8902Shape of y_pred_back - (19, 1)
#  90/119 [=====================>........] - ETA: 1s - loss: 5.8624Shape of y_pred_back - (19, 1)
#  91/119 [=====================>........] - ETA: 1s - loss: 5.8350Shape of y_pred_back - (19, 1)
#  92/119 [======================>.......] - ETA: 1s - loss: 5.8078Shape of y_pred_back - (19, 1)
#  93/119 [======================>.......] - ETA: 1s - loss: 5.7811Shape of y_pred_back - (19, 1)
#  94/119 [======================>.......] - ETA: 1s - loss: 5.7546Shape of y_pred_back - (19, 1)
#  95/119 [======================>.......] - ETA: 1s - loss: 5.7284Shape of y_pred_back - (19, 1)
#  96/119 [=======================>......] - ETA: 1s - loss: 5.7025Shape of y_pred_back - (19, 1)
#  97/119 [=======================>......] - ETA: 1s - loss: 5.6769Shape of y_pred_back - (19, 1)
#  98/119 [=======================>......] - ETA: 1s - loss: 5.6516Shape of y_pred_back - (19, 1)
#  99/119 [=======================>......] - ETA: 1s - loss: 5.6265Shape of y_pred_back - (19, 1)
# 100/119 [========================>.....] - ETA: 1s - loss: 5.6017Shape of y_pred_back - (19, 1)
# 101/119 [========================>.....] - ETA: 1s - loss: 5.5772Shape of y_pred_back - (19, 1)
# 102/119 [========================>.....] - ETA: 1s - loss: 5.5536Shape of y_pred_back - (19, 1)
# 103/119 [========================>.....] - ETA: 0s - loss: 5.5310Shape of y_pred_back - (19, 1)
# 104/119 [=========================>....] - ETA: 0s - loss: 5.5092Shape of y_pred_back - (19, 1)
# 105/119 [=========================>....] - ETA: 0s - loss: 5.4888Shape of y_pred_back - (19, 1)
# 106/119 [=========================>....] - ETA: 0s - loss: 5.4690Shape of y_pred_back - (19, 1)
# 107/119 [=========================>....] - ETA: 0s - loss: 5.4499Shape of y_pred_back - (19, 1)
# 108/119 [==========================>...] - ETA: 0s - loss: 5.4312Shape of y_pred_back - (19, 1)
# 109/119 [==========================>...] - ETA: 0s - loss: 5.4128Shape of y_pred_back - (19, 1)
# 110/119 [==========================>...] - ETA: 0s - loss: 5.3947Shape of y_pred_back - (19, 1)
# 111/119 [==========================>...] - ETA: 0s - loss: 5.3770Shape of y_pred_back - (19, 1)
# 112/119 [===========================>..] - ETA: 0s - loss: 5.3598Shape of y_pred_back - (19, 1)
# 113/119 [===========================>..] - ETA: 0s - loss: 5.3431Shape of y_pred_back - (19, 1)
# 114/119 [===========================>..] - ETA: 0s - loss: 5.3271Shape of y_pred_back - (19, 1)
# 115/119 [===========================>..] - ETA: 0s - loss: 5.3117Shape of y_pred_back - (19, 1)
# 116/119 [============================>.] - ETA: 0s - loss: 5.2965Shape of y_pred_back - (19, 1)
# 117/119 [============================>.] - ETA: 0s - loss: 5.2816Shape of y_pred_back - (19, 1)
# 118/119 [============================>.] - ETA: 0s - loss: 5.2669Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - ETA: 0s - loss: 5.2522Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - 9s 65ms/step - loss: 5.2379 - val_loss: 16.6401
# Epoch 2/300
# Shape of y_pred_back - (19, 1)
#   1/119 [..............................] - ETA: 6s - loss: 16.1738Shape of y_pred_back - (19, 1)
#   2/119 [..............................] - ETA: 6s - loss: 16.7712Shape of y_pred_back - (19, 1)
#   3/119 [..............................] - ETA: 6s - loss: 16.5535Shape of y_pred_back - (19, 1)
#   4/119 [>.............................] - ETA: 6s - loss: 15.8019Shape of y_pred_back - (19, 1)
#   5/119 [>.............................] - ETA: 6s - loss: 15.5115Shape of y_pred_back - (19, 1)
#   6/119 [>.............................] - ETA: 6s - loss: 15.2855Shape of y_pred_back - (19, 1)
#   7/119 [>.............................] - ETA: 6s - loss: 14.9227Shape of y_pred_back - (19, 1)
#   8/119 [=>............................] - ETA: 6s - loss: 14.5640Shape of y_pred_back - (19, 1)
#   9/119 [=>............................] - ETA: 6s - loss: 14.2060Shape of y_pred_back - (19, 1)
#  10/119 [=>............................] - ETA: 6s - loss: 13.8398Shape of y_pred_back - (19, 1)
#  11/119 [=>............................] - ETA: 6s - loss: 13.4681Shape of y_pred_back - (19, 1)
#  12/119 [==>...........................] - ETA: 6s - loss: 13.0920Shape of y_pred_back - (19, 1)
#  13/119 [==>...........................] - ETA: 6s - loss: 12.7225Shape of y_pred_back - (19, 1)
#  14/119 [==>...........................] - ETA: 6s - loss: 12.3645Shape of y_pred_back - (19, 1)
#  15/119 [==>...........................] - ETA: 6s - loss: 12.0202Shape of y_pred_back - (19, 1)
#  16/119 [===>..........................] - ETA: 6s - loss: 11.6919Shape of y_pred_back - (19, 1)
#  17/119 [===>..........................] - ETA: 6s - loss: 11.3800Shape of y_pred_back - (19, 1)
#  18/119 [===>..........................] - ETA: 5s - loss: 11.0841Shape of y_pred_back - (19, 1)
#  19/119 [===>..........................] - ETA: 5s - loss: 10.8031Shape of y_pred_back - (19, 1)
#  20/119 [====>.........................] - ETA: 5s - loss: 10.5361Shape of y_pred_back - (19, 1)
#  21/119 [====>.........................] - ETA: 5s - loss: 10.2827Shape of y_pred_back - (19, 1)
#  22/119 [====>.........................] - ETA: 5s - loss: 10.0433Shape of y_pred_back - (19, 1)
#  23/119 [====>.........................] - ETA: 5s - loss: 9.8168 Shape of y_pred_back - (19, 1)
#  24/119 [=====>........................] - ETA: 5s - loss: 9.6027Shape of y_pred_back - (19, 1)
#  25/119 [=====>........................] - ETA: 5s - loss: 9.4012Shape of y_pred_back - (19, 1)
#  26/119 [=====>........................] - ETA: 5s - loss: 9.2108Shape of y_pred_back - (19, 1)
#  27/119 [=====>........................] - ETA: 5s - loss: 9.0289Shape of y_pred_back - (19, 1)
#  28/119 [======>.......................] - ETA: 5s - loss: 8.8551Shape of y_pred_back - (19, 1)
#  29/119 [======>.......................] - ETA: 5s - loss: 8.6887Shape of y_pred_back - (19, 1)
#  30/119 [======>.......................] - ETA: 5s - loss: 8.5323Shape of y_pred_back - (19, 1)
#  31/119 [======>.......................] - ETA: 5s - loss: 8.3869Shape of y_pred_back - (19, 1)
#  32/119 [=======>......................] - ETA: 5s - loss: 8.2490Shape of y_pred_back - (19, 1)
#  33/119 [=======>......................] - ETA: 5s - loss: 8.1166Shape of y_pred_back - (19, 1)
#  34/119 [=======>......................] - ETA: 5s - loss: 7.9898Shape of y_pred_back - (19, 1)
#  35/119 [=======>......................] - ETA: 5s - loss: 7.8683Shape of y_pred_back - (19, 1)
#  36/119 [========>.....................] - ETA: 4s - loss: 7.7536Shape of y_pred_back - (19, 1)
#  37/119 [========>.....................] - ETA: 4s - loss: 7.6445Shape of y_pred_back - (19, 1)
#  38/119 [========>.....................] - ETA: 4s - loss: 7.5393Shape of y_pred_back - (19, 1)
#  39/119 [========>.....................] - ETA: 4s - loss: 7.4377Shape of y_pred_back - (19, 1)
#  40/119 [=========>....................] - ETA: 4s - loss: 7.3390Shape of y_pred_back - (19, 1)
#  41/119 [=========>....................] - ETA: 4s - loss: 7.2434Shape of y_pred_back - (19, 1)
#  42/119 [=========>....................] - ETA: 4s - loss: 7.1506Shape of y_pred_back - (19, 1)
#  43/119 [=========>....................] - ETA: 4s - loss: 7.0604Shape of y_pred_back - (19, 1)
#  44/119 [==========>...................] - ETA: 4s - loss: 6.9727Shape of y_pred_back - (19, 1)
#  45/119 [==========>...................] - ETA: 4s - loss: 6.8877Shape of y_pred_back - (19, 1)
#  46/119 [==========>...................] - ETA: 4s - loss: 6.8055Shape of y_pred_back - (19, 1)
#  47/119 [==========>...................] - ETA: 4s - loss: 6.7260Shape of y_pred_back - (19, 1)
#  48/119 [===========>..................] - ETA: 4s - loss: 6.6491Shape of y_pred_back - (19, 1)
#  49/119 [===========>..................] - ETA: 4s - loss: 6.5744Shape of y_pred_back - (19, 1)
#  50/119 [===========>..................] - ETA: 4s - loss: 6.5017Shape of y_pred_back - (19, 1)
#  51/119 [===========>..................] - ETA: 4s - loss: 6.4309Shape of y_pred_back - (19, 1)
#  52/119 [============>.................] - ETA: 4s - loss: 6.3618Shape of y_pred_back - (19, 1)
#  53/119 [============>.................] - ETA: 3s - loss: 6.2944Shape of y_pred_back - (19, 1)
#  54/119 [============>.................] - ETA: 3s - loss: 6.2287Shape of y_pred_back - (19, 1)
#  55/119 [============>.................] - ETA: 3s - loss: 6.1647Shape of y_pred_back - (19, 1)
#  56/119 [=============>................] - ETA: 3s - loss: 6.1025Shape of y_pred_back - (19, 1)
#  57/119 [=============>................] - ETA: 3s - loss: 6.0419Shape of y_pred_back - (19, 1)
#  58/119 [=============>................] - ETA: 3s - loss: 5.9826Shape of y_pred_back - (19, 1)
#  59/119 [=============>................] - ETA: 3s - loss: 5.9246Shape of y_pred_back - (19, 1)
#  60/119 [==============>...............] - ETA: 3s - loss: 5.8679Shape of y_pred_back - (19, 1)
#  61/119 [==============>...............] - ETA: 3s - loss: 5.8125Shape of y_pred_back - (19, 1)
#  62/119 [==============>...............] - ETA: 3s - loss: 5.7583Shape of y_pred_back - (19, 1)
#  63/119 [==============>...............] - ETA: 3s - loss: 5.7052Shape of y_pred_back - (19, 1)
#  64/119 [===============>..............] - ETA: 3s - loss: 5.6533Shape of y_pred_back - (19, 1)
#  65/119 [===============>..............] - ETA: 3s - loss: 5.6025Shape of y_pred_back - (19, 1)
#  66/119 [===============>..............] - ETA: 3s - loss: 5.5528Shape of y_pred_back - (19, 1)
#  67/119 [===============>..............] - ETA: 3s - loss: 5.5041Shape of y_pred_back - (19, 1)
#  68/119 [================>.............] - ETA: 3s - loss: 5.4565Shape of y_pred_back - (19, 1)
#  69/119 [================>.............] - ETA: 2s - loss: 5.4099Shape of y_pred_back - (19, 1)
#  70/119 [================>.............] - ETA: 2s - loss: 5.3643Shape of y_pred_back - (19, 1)
#  71/119 [================>.............] - ETA: 2s - loss: 5.3195Shape of y_pred_back - (19, 1)
#  72/119 [=================>............] - ETA: 2s - loss: 5.2756Shape of y_pred_back - (19, 1)
#  73/119 [=================>............] - ETA: 2s - loss: 5.2326Shape of y_pred_back - (19, 1)
#  74/119 [=================>............] - ETA: 2s - loss: 5.1903Shape of y_pred_back - (19, 1)
#  75/119 [=================>............] - ETA: 2s - loss: 5.1498Shape of y_pred_back - (19, 1)
#  76/119 [==================>...........] - ETA: 2s - loss: 5.1134Shape of y_pred_back - (19, 1)
#  77/119 [==================>...........] - ETA: 2s - loss: 5.0792Shape of y_pred_back - (19, 1)
#  78/119 [==================>...........] - ETA: 2s - loss: 5.0455Shape of y_pred_back - (19, 1)
#  79/119 [==================>...........] - ETA: 2s - loss: 5.0127Shape of y_pred_back - (19, 1)
#  80/119 [===================>..........] - ETA: 2s - loss: 4.9806Shape of y_pred_back - (19, 1)
#  81/119 [===================>..........] - ETA: 2s - loss: 4.9494Shape of y_pred_back - (19, 1)
#  82/119 [===================>..........] - ETA: 2s - loss: 4.9193Shape of y_pred_back - (19, 1)
#  83/119 [===================>..........] - ETA: 2s - loss: 4.8902Shape of y_pred_back - (19, 1)
#  84/119 [====================>.........] - ETA: 2s - loss: 4.8615Shape of y_pred_back - (19, 1)
#  85/119 [====================>.........] - ETA: 2s - loss: 4.8333Shape of y_pred_back - (19, 1)
#  86/119 [====================>.........] - ETA: 1s - loss: 4.8060Shape of y_pred_back - (19, 1)
#  87/119 [====================>.........] - ETA: 1s - loss: 4.7792Shape of y_pred_back - (19, 1)
#  88/119 [=====================>........] - ETA: 1s - loss: 4.7527Shape of y_pred_back - (19, 1)
#  89/119 [=====================>........] - ETA: 1s - loss: 4.7265Shape of y_pred_back - (19, 1)
#  90/119 [=====================>........] - ETA: 1s - loss: 4.7007Shape of y_pred_back - (19, 1)
#  91/119 [=====================>........] - ETA: 1s - loss: 4.6752Shape of y_pred_back - (19, 1)
#  92/119 [======================>.......] - ETA: 1s - loss: 4.6505Shape of y_pred_back - (19, 1)
#  93/119 [======================>.......] - ETA: 1s - loss: 4.6266Shape of y_pred_back - (19, 1)
#  94/119 [======================>.......] - ETA: 1s - loss: 4.6034Shape of y_pred_back - (19, 1)
#  95/119 [======================>.......] - ETA: 1s - loss: 4.5806Shape of y_pred_back - (19, 1)
#  96/119 [=======================>......] - ETA: 1s - loss: 4.5581Shape of y_pred_back - (19, 1)
#  97/119 [=======================>......] - ETA: 1s - loss: 4.5358Shape of y_pred_back - (19, 1)
#  98/119 [=======================>......] - ETA: 1s - loss: 4.5139Shape of y_pred_back - (19, 1)
#  99/119 [=======================>......] - ETA: 1s - loss: 4.4922Shape of y_pred_back - (19, 1)
# 100/119 [========================>.....] - ETA: 1s - loss: 4.4709Shape of y_pred_back - (19, 1)
# 101/119 [========================>.....] - ETA: 1s - loss: 4.4498Shape of y_pred_back - (19, 1)
# 102/119 [========================>.....] - ETA: 1s - loss: 4.4303Shape of y_pred_back - (19, 1)
# 103/119 [========================>.....] - ETA: 0s - loss: 4.4111Shape of y_pred_back - (19, 1)
# 104/119 [=========================>....] - ETA: 0s - loss: 4.3924Shape of y_pred_back - (19, 1)
# 105/119 [=========================>....] - ETA: 0s - loss: 4.3754Shape of y_pred_back - (19, 1)
# 106/119 [=========================>....] - ETA: 0s - loss: 4.3592Shape of y_pred_back - (19, 1)
# 107/119 [=========================>....] - ETA: 0s - loss: 4.3433Shape of y_pred_back - (19, 1)
# 108/119 [==========================>...] - ETA: 0s - loss: 4.3278Shape of y_pred_back - (19, 1)
# 109/119 [==========================>...] - ETA: 0s - loss: 4.3129Shape of y_pred_back - (19, 1)
# 110/119 [==========================>...] - ETA: 0s - loss: 4.2986Shape of y_pred_back - (19, 1)
# 111/119 [==========================>...] - ETA: 0s - loss: 4.2845Shape of y_pred_back - (19, 1)
# 112/119 [===========================>..] - ETA: 0s - loss: 4.2708Shape of y_pred_back - (19, 1)
# 113/119 [===========================>..] - ETA: 0s - loss: 4.2575Shape of y_pred_back - (19, 1)
# 114/119 [===========================>..] - ETA: 0s - loss: 4.2445Shape of y_pred_back - (19, 1)
# 115/119 [===========================>..] - ETA: 0s - loss: 4.2317Shape of y_pred_back - (19, 1)
# 116/119 [============================>.] - ETA: 0s - loss: 4.2196Shape of y_pred_back - (19, 1)
# 117/119 [============================>.] - ETA: 0s - loss: 4.2076Shape of y_pred_back - (19, 1)
# 118/119 [============================>.] - ETA: 0s - loss: 4.1959Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - ETA: 0s - loss: 4.1844Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - 8s 64ms/step - loss: 4.1731 - val_loss: 5.9567
# Epoch 3/300
# Shape of y_pred_back - (19, 1)
#   1/119 [..............................] - ETA: 7s - loss: 21.1169Shape of y_pred_back - (19, 1)
#   2/119 [..............................] - ETA: 6s - loss: 18.3213Shape of y_pred_back - (19, 1)
#   3/119 [..............................] - ETA: 6s - loss: 17.7303Shape of y_pred_back - (19, 1)
#   4/119 [>.............................] - ETA: 6s - loss: 17.5876Shape of y_pred_back - (19, 1)
#   5/119 [>.............................] - ETA: 6s - loss: 17.7586Shape of y_pred_back - (19, 1)
#   6/119 [>.............................] - ETA: 6s - loss: 17.7551Shape of y_pred_back - (19, 1)
#   7/119 [>.............................] - ETA: 6s - loss: 17.7271Shape of y_pred_back - (19, 1)
#   8/119 [=>............................] - ETA: 6s - loss: 17.5336Shape of y_pred_back - (19, 1)
#   9/119 [=>............................] - ETA: 6s - loss: 17.3400Shape of y_pred_back - (19, 1)
#  10/119 [=>............................] - ETA: 6s - loss: 17.0842Shape of y_pred_back - (19, 1)
#  11/119 [=>............................] - ETA: 6s - loss: 16.8002Shape of y_pred_back - (19, 1)
#  12/119 [==>...........................] - ETA: 6s - loss: 16.4761Shape of y_pred_back - (19, 1)
#  13/119 [==>...........................] - ETA: 6s - loss: 16.1294Shape of y_pred_back - (19, 1)
#  14/119 [==>...........................] - ETA: 6s - loss: 15.7717Shape of y_pred_back - (19, 1)
#  15/119 [==>...........................] - ETA: 6s - loss: 15.4127Shape of y_pred_back - (19, 1)
#  16/119 [===>..........................] - ETA: 6s - loss: 15.0590Shape of y_pred_back - (19, 1)
#  17/119 [===>..........................] - ETA: 6s - loss: 14.7138Shape of y_pred_back - (19, 1)
#  18/119 [===>..........................] - ETA: 6s - loss: 14.3792Shape of y_pred_back - (19, 1)
#  19/119 [===>..........................] - ETA: 6s - loss: 14.0561Shape of y_pred_back - (19, 1)
#  20/119 [====>.........................] - ETA: 5s - loss: 13.7452Shape of y_pred_back - (19, 1)
#  21/119 [====>.........................] - ETA: 5s - loss: 13.4468Shape of y_pred_back - (19, 1)
#  22/119 [====>.........................] - ETA: 5s - loss: 13.1611Shape of y_pred_back - (19, 1)
#  23/119 [====>.........................] - ETA: 5s - loss: 12.8874Shape of y_pred_back - (19, 1)
#  24/119 [=====>........................] - ETA: 5s - loss: 12.6252Shape of y_pred_back - (19, 1)
#  25/119 [=====>........................] - ETA: 5s - loss: 12.3751Shape of y_pred_back - (19, 1)
#  26/119 [=====>........................] - ETA: 5s - loss: 12.1371Shape of y_pred_back - (19, 1)
#  27/119 [=====>........................] - ETA: 5s - loss: 11.9089Shape of y_pred_back - (19, 1)
#  28/119 [======>.......................] - ETA: 5s - loss: 11.6898Shape of y_pred_back - (19, 1)
#  29/119 [======>.......................] - ETA: 5s - loss: 11.4799Shape of y_pred_back - (19, 1)
#  30/119 [======>.......................] - ETA: 5s - loss: 11.2814Shape of y_pred_back - (19, 1)
#  31/119 [======>.......................] - ETA: 5s - loss: 11.0940Shape of y_pred_back - (19, 1)
#  32/119 [=======>......................] - ETA: 5s - loss: 10.9161Shape of y_pred_back - (19, 1)
#  33/119 [=======>......................] - ETA: 5s - loss: 10.7451Shape of y_pred_back - (19, 1)
#  34/119 [=======>......................] - ETA: 5s - loss: 10.5810Shape of y_pred_back - (19, 1)
#  35/119 [=======>......................] - ETA: 5s - loss: 10.4241Shape of y_pred_back - (19, 1)
#  36/119 [========>.....................] - ETA: 5s - loss: 10.2741Shape of y_pred_back - (19, 1)
#  37/119 [========>.....................] - ETA: 4s - loss: 10.1304Shape of y_pred_back - (19, 1)
#  38/119 [========>.....................] - ETA: 4s - loss: 9.9920 Shape of y_pred_back - (19, 1)
#  39/119 [========>.....................] - ETA: 4s - loss: 9.8580Shape of y_pred_back - (19, 1)
#  40/119 [=========>....................] - ETA: 4s - loss: 9.7278Shape of y_pred_back - (19, 1)
#  41/119 [=========>....................] - ETA: 4s - loss: 9.6020Shape of y_pred_back - (19, 1)
#  42/119 [=========>....................] - ETA: 4s - loss: 9.4797Shape of y_pred_back - (19, 1)
#  43/119 [=========>....................] - ETA: 4s - loss: 9.3607Shape of y_pred_back - (19, 1)
#  44/119 [==========>...................] - ETA: 4s - loss: 9.2450Shape of y_pred_back - (19, 1)
#  45/119 [==========>...................] - ETA: 4s - loss: 9.1326Shape of y_pred_back - (19, 1)
#  46/119 [==========>...................] - ETA: 4s - loss: 9.0233Shape of y_pred_back - (19, 1)
#  47/119 [==========>...................] - ETA: 4s - loss: 8.9172Shape of y_pred_back - (19, 1)
#  48/119 [===========>..................] - ETA: 4s - loss: 8.8143Shape of y_pred_back - (19, 1)
#  49/119 [===========>..................] - ETA: 4s - loss: 8.7142Shape of y_pred_back - (19, 1)
#  50/119 [===========>..................] - ETA: 4s - loss: 8.6168Shape of y_pred_back - (19, 1)
#  51/119 [===========>..................] - ETA: 4s - loss: 8.5218Shape of y_pred_back - (19, 1)
#  52/119 [============>.................] - ETA: 4s - loss: 8.4291Shape of y_pred_back - (19, 1)
#  53/119 [============>.................] - ETA: 3s - loss: 8.3386Shape of y_pred_back - (19, 1)
#  54/119 [============>.................] - ETA: 3s - loss: 8.2503Shape of y_pred_back - (19, 1)
#  55/119 [============>.................] - ETA: 3s - loss: 8.1641Shape of y_pred_back - (19, 1)
#  56/119 [=============>................] - ETA: 3s - loss: 8.0799Shape of y_pred_back - (19, 1)
#  57/119 [=============>................] - ETA: 3s - loss: 7.9978Shape of y_pred_back - (19, 1)
#  58/119 [=============>................] - ETA: 3s - loss: 7.9175Shape of y_pred_back - (19, 1)
#  59/119 [=============>................] - ETA: 3s - loss: 7.8390Shape of y_pred_back - (19, 1)
#  60/119 [==============>...............] - ETA: 3s - loss: 7.7622Shape of y_pred_back - (19, 1)
#  61/119 [==============>...............] - ETA: 3s - loss: 7.6871Shape of y_pred_back - (19, 1)
#  62/119 [==============>...............] - ETA: 3s - loss: 7.6136Shape of y_pred_back - (19, 1)
#  63/119 [==============>...............] - ETA: 3s - loss: 7.5418Shape of y_pred_back - (19, 1)
#  64/119 [===============>..............] - ETA: 3s - loss: 7.4715Shape of y_pred_back - (19, 1)
#  65/119 [===============>..............] - ETA: 3s - loss: 7.4027Shape of y_pred_back - (19, 1)
#  66/119 [===============>..............] - ETA: 3s - loss: 7.3353Shape of y_pred_back - (19, 1)
#  67/119 [===============>..............] - ETA: 3s - loss: 7.2693Shape of y_pred_back - (19, 1)
#  68/119 [================>.............] - ETA: 3s - loss: 7.2049Shape of y_pred_back - (19, 1)
#  69/119 [================>.............] - ETA: 3s - loss: 7.1418Shape of y_pred_back - (19, 1)
#  70/119 [================>.............] - ETA: 2s - loss: 7.0800Shape of y_pred_back - (19, 1)
#  71/119 [================>.............] - ETA: 2s - loss: 7.0194Shape of y_pred_back - (19, 1)
#  72/119 [=================>............] - ETA: 2s - loss: 6.9599Shape of y_pred_back - (19, 1)
#  73/119 [=================>............] - ETA: 2s - loss: 6.9016Shape of y_pred_back - (19, 1)
#  74/119 [=================>............] - ETA: 2s - loss: 6.8444Shape of y_pred_back - (19, 1)
#  75/119 [=================>............] - ETA: 2s - loss: 6.7893Shape of y_pred_back - (19, 1)
#  76/119 [==================>...........] - ETA: 2s - loss: 6.7371Shape of y_pred_back - (19, 1)
#  77/119 [==================>...........] - ETA: 2s - loss: 6.6869Shape of y_pred_back - (19, 1)
#  78/119 [==================>...........] - ETA: 2s - loss: 6.6378Shape of y_pred_back - (19, 1)
#  79/119 [==================>...........] - ETA: 2s - loss: 6.5897Shape of y_pred_back - (19, 1)
#  80/119 [===================>..........] - ETA: 2s - loss: 6.5425Shape of y_pred_back - (19, 1)
#  81/119 [===================>..........] - ETA: 2s - loss: 6.4964Shape of y_pred_back - (19, 1)
#  82/119 [===================>..........] - ETA: 2s - loss: 6.4516Shape of y_pred_back - (19, 1)
#  83/119 [===================>..........] - ETA: 2s - loss: 6.4078Shape of y_pred_back - (19, 1)
#  84/119 [====================>.........] - ETA: 2s - loss: 6.3651Shape of y_pred_back - (19, 1)
#  85/119 [====================>.........] - ETA: 2s - loss: 6.3232Shape of y_pred_back - (19, 1)
#  86/119 [====================>.........] - ETA: 1s - loss: 6.2823Shape of y_pred_back - (19, 1)
#  87/119 [====================>.........] - ETA: 1s - loss: 6.2420Shape of y_pred_back - (19, 1)
#  88/119 [=====================>........] - ETA: 1s - loss: 6.2024Shape of y_pred_back - (19, 1)
#  89/119 [=====================>........] - ETA: 1s - loss: 6.1634Shape of y_pred_back - (19, 1)
#  90/119 [=====================>........] - ETA: 1s - loss: 6.1250Shape of y_pred_back - (19, 1)
#  91/119 [=====================>........] - ETA: 1s - loss: 6.0873Shape of y_pred_back - (19, 1)
#  92/119 [======================>.......] - ETA: 1s - loss: 6.0504Shape of y_pred_back - (19, 1)
#  93/119 [======================>.......] - ETA: 1s - loss: 6.0143Shape of y_pred_back - (19, 1)
#  94/119 [======================>.......] - ETA: 1s - loss: 5.9791Shape of y_pred_back - (19, 1)
#  95/119 [======================>.......] - ETA: 1s - loss: 5.9446Shape of y_pred_back - (19, 1)
#  96/119 [=======================>......] - ETA: 1s - loss: 5.9108Shape of y_pred_back - (19, 1)
#  97/119 [=======================>......] - ETA: 1s - loss: 5.8776Shape of y_pred_back - (19, 1)
#  98/119 [=======================>......] - ETA: 1s - loss: 5.8449Shape of y_pred_back - (19, 1)
#  99/119 [=======================>......] - ETA: 1s - loss: 5.8128Shape of y_pred_back - (19, 1)
# 100/119 [========================>.....] - ETA: 1s - loss: 5.7812Shape of y_pred_back - (19, 1)
# 101/119 [========================>.....] - ETA: 1s - loss: 5.7502Shape of y_pred_back - (19, 1)
# 102/119 [========================>.....] - ETA: 1s - loss: 5.7205Shape of y_pred_back - (19, 1)
# 103/119 [========================>.....] - ETA: 0s - loss: 5.6916Shape of y_pred_back - (19, 1)
# 104/119 [=========================>....] - ETA: 0s - loss: 5.6631Shape of y_pred_back - (19, 1)
# 105/119 [=========================>....] - ETA: 0s - loss: 5.6355Shape of y_pred_back - (19, 1)
# 106/119 [=========================>....] - ETA: 0s - loss: 5.6085Shape of y_pred_back - (19, 1)
# 107/119 [=========================>....] - ETA: 0s - loss: 5.5819Shape of y_pred_back - (19, 1)
# 108/119 [==========================>...] - ETA: 0s - loss: 5.5562Shape of y_pred_back - (19, 1)
# 109/119 [==========================>...] - ETA: 0s - loss: 5.5310Shape of y_pred_back - (19, 1)
# 110/119 [==========================>...] - ETA: 0s - loss: 5.5062Shape of y_pred_back - (19, 1)
# 111/119 [==========================>...] - ETA: 0s - loss: 5.4825Shape of y_pred_back - (19, 1)
# 112/119 [===========================>..] - ETA: 0s - loss: 5.4596Shape of y_pred_back - (19, 1)
# 113/119 [===========================>..] - ETA: 0s - loss: 5.4372Shape of y_pred_back - (19, 1)
# 114/119 [===========================>..] - ETA: 0s - loss: 5.4154Shape of y_pred_back - (19, 1)
# 115/119 [===========================>..] - ETA: 0s - loss: 5.3939Shape of y_pred_back - (19, 1)
# 116/119 [============================>.] - ETA: 0s - loss: 5.3730Shape of y_pred_back - (19, 1)
# 117/119 [============================>.] - ETA: 0s - loss: 5.3523Shape of y_pred_back - (19, 1)
# 118/119 [============================>.] - ETA: 0s - loss: 5.3319Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - ETA: 0s - loss: 5.3119Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - 8s 64ms/step - loss: 5.2921 - val_loss: 6.7962
# Epoch 4/300
# Shape of y_pred_back - (19, 1)
#   1/119 [..............................] - ETA: 6s - loss: 9.5261Shape of y_pred_back - (19, 1)
#   2/119 [..............................] - ETA: 6s - loss: 10.2686Shape of y_pred_back - (19, 1)
#   3/119 [..............................] - ETA: 6s - loss: 10.3987Shape of y_pred_back - (19, 1)
#   4/119 [>.............................] - ETA: 6s - loss: 10.9244Shape of y_pred_back - (19, 1)
#   5/119 [>.............................] - ETA: 6s - loss: 11.3382Shape of y_pred_back - (19, 1)
#   6/119 [>.............................] - ETA: 6s - loss: 11.3457Shape of y_pred_back - (19, 1)
#   7/119 [>.............................] - ETA: 6s - loss: 11.2643Shape of y_pred_back - (19, 1)
#   8/119 [=>............................] - ETA: 6s - loss: 11.1832Shape of y_pred_back - (19, 1)
#   9/119 [=>............................] - ETA: 6s - loss: 11.0926Shape of y_pred_back - (19, 1)
#  10/119 [=>............................] - ETA: 6s - loss: 10.9899Shape of y_pred_back - (19, 1)
#  11/119 [=>............................] - ETA: 6s - loss: 10.8510Shape of y_pred_back - (19, 1)
#  12/119 [==>...........................] - ETA: 6s - loss: 10.6783Shape of y_pred_back - (19, 1)
#  13/119 [==>...........................] - ETA: 6s - loss: 10.4839Shape of y_pred_back - (19, 1)
#  14/119 [==>...........................] - ETA: 6s - loss: 10.2769Shape of y_pred_back - (19, 1)
#  15/119 [==>...........................] - ETA: 6s - loss: 10.0681Shape of y_pred_back - (19, 1)
#  16/119 [===>..........................] - ETA: 6s - loss: 9.8584 Shape of y_pred_back - (19, 1)
#  17/119 [===>..........................] - ETA: 6s - loss: 9.6504Shape of y_pred_back - (19, 1)
#  18/119 [===>..........................] - ETA: 6s - loss: 9.4466Shape of y_pred_back - (19, 1)
#  19/119 [===>..........................] - ETA: 6s - loss: 9.2492Shape of y_pred_back - (19, 1)
#  20/119 [====>.........................] - ETA: 6s - loss: 9.0583Shape of y_pred_back - (19, 1)
#  21/119 [====>.........................] - ETA: 5s - loss: 8.8738Shape of y_pred_back - (19, 1)
#  22/119 [====>.........................] - ETA: 5s - loss: 8.6959Shape of y_pred_back - (19, 1)
#  23/119 [====>.........................] - ETA: 5s - loss: 8.5244Shape of y_pred_back - (19, 1)
#  24/119 [=====>........................] - ETA: 5s - loss: 8.3595Shape of y_pred_back - (19, 1)
#  25/119 [=====>........................] - ETA: 5s - loss: 8.2012Shape of y_pred_back - (19, 1)
#  26/119 [=====>........................] - ETA: 5s - loss: 8.0491Shape of y_pred_back - (19, 1)
#  27/119 [=====>........................] - ETA: 5s - loss: 7.9026Shape of y_pred_back - (19, 1)
#  28/119 [======>.......................] - ETA: 5s - loss: 7.7615Shape of y_pred_back - (19, 1)
#  29/119 [======>.......................] - ETA: 5s - loss: 7.6259Shape of y_pred_back - (19, 1)
#  30/119 [======>.......................] - ETA: 5s - loss: 7.4972Shape of y_pred_back - (19, 1)
#  31/119 [======>.......................] - ETA: 5s - loss: 7.3754Shape of y_pred_back - (19, 1)
#  32/119 [=======>......................] - ETA: 5s - loss: 7.2599Shape of y_pred_back - (19, 1)
#  33/119 [=======>......................] - ETA: 5s - loss: 7.1488Shape of y_pred_back - (19, 1)
#  34/119 [=======>......................] - ETA: 5s - loss: 7.0419Shape of y_pred_back - (19, 1)
#  35/119 [=======>......................] - ETA: 5s - loss: 6.9394Shape of y_pred_back - (19, 1)
#  36/119 [========>.....................] - ETA: 4s - loss: 6.8412Shape of y_pred_back - (19, 1)
#  37/119 [========>.....................] - ETA: 4s - loss: 6.7478Shape of y_pred_back - (19, 1)
#  38/119 [========>.....................] - ETA: 4s - loss: 6.6575Shape of y_pred_back - (19, 1)
#  39/119 [========>.....................] - ETA: 4s - loss: 6.5702Shape of y_pred_back - (19, 1)
#  40/119 [=========>....................] - ETA: 4s - loss: 6.4853Shape of y_pred_back - (19, 1)
#  41/119 [=========>....................] - ETA: 4s - loss: 6.4030Shape of y_pred_back - (19, 1)
#  42/119 [=========>....................] - ETA: 4s - loss: 6.3228Shape of y_pred_back - (19, 1)
#  43/119 [=========>....................] - ETA: 4s - loss: 6.2449Shape of y_pred_back - (19, 1)
#  44/119 [==========>...................] - ETA: 4s - loss: 6.1691Shape of y_pred_back - (19, 1)
#  45/119 [==========>...................] - ETA: 4s - loss: 6.0955Shape of y_pred_back - (19, 1)
#  46/119 [==========>...................] - ETA: 4s - loss: 6.0241Shape of y_pred_back - (19, 1)
#  47/119 [==========>...................] - ETA: 4s - loss: 5.9551Shape of y_pred_back - (19, 1)
#  48/119 [===========>..................] - ETA: 4s - loss: 5.8879Shape of y_pred_back - (19, 1)
#  49/119 [===========>..................] - ETA: 4s - loss: 5.8226Shape of y_pred_back - (19, 1)
#  50/119 [===========>..................] - ETA: 4s - loss: 5.7589Shape of y_pred_back - (19, 1)
#  51/119 [===========>..................] - ETA: 4s - loss: 5.6968Shape of y_pred_back - (19, 1)
#  52/119 [============>.................] - ETA: 4s - loss: 5.6363Shape of y_pred_back - (19, 1)
#  53/119 [============>.................] - ETA: 3s - loss: 5.5772Shape of y_pred_back - (19, 1)
#  54/119 [============>.................] - ETA: 3s - loss: 5.5194Shape of y_pred_back - (19, 1)
#  55/119 [============>.................] - ETA: 3s - loss: 5.4631Shape of y_pred_back - (19, 1)
#  56/119 [=============>................] - ETA: 3s - loss: 5.4081Shape of y_pred_back - (19, 1)
#  57/119 [=============>................] - ETA: 3s - loss: 5.3544Shape of y_pred_back - (19, 1)
#  58/119 [=============>................] - ETA: 3s - loss: 5.3019Shape of y_pred_back - (19, 1)
#  59/119 [=============>................] - ETA: 3s - loss: 5.2506Shape of y_pred_back - (19, 1)
#  60/119 [==============>...............] - ETA: 3s - loss: 5.2003Shape of y_pred_back - (19, 1)
#  61/119 [==============>...............] - ETA: 3s - loss: 5.1512Shape of y_pred_back - (19, 1)
#  62/119 [==============>...............] - ETA: 3s - loss: 5.1031Shape of y_pred_back - (19, 1)
#  63/119 [==============>...............] - ETA: 3s - loss: 5.0561Shape of y_pred_back - (19, 1)
#  64/119 [===============>..............] - ETA: 3s - loss: 5.0101Shape of y_pred_back - (19, 1)
#  65/119 [===============>..............] - ETA: 3s - loss: 4.9650Shape of y_pred_back - (19, 1)
#  66/119 [===============>..............] - ETA: 3s - loss: 4.9208Shape of y_pred_back - (19, 1)
#  67/119 [===============>..............] - ETA: 3s - loss: 4.8777Shape of y_pred_back - (19, 1)
#  68/119 [================>.............] - ETA: 3s - loss: 4.8354Shape of y_pred_back - (19, 1)
#  69/119 [================>.............] - ETA: 3s - loss: 4.7941Shape of y_pred_back - (19, 1)
#  70/119 [================>.............] - ETA: 2s - loss: 4.7535Shape of y_pred_back - (19, 1)
#  71/119 [================>.............] - ETA: 2s - loss: 4.7137Shape of y_pred_back - (19, 1)
#  72/119 [=================>............] - ETA: 2s - loss: 4.6747Shape of y_pred_back - (19, 1)
#  73/119 [=================>............] - ETA: 2s - loss: 4.6364Shape of y_pred_back - (19, 1)
#  74/119 [=================>............] - ETA: 2s - loss: 4.5989Shape of y_pred_back - (19, 1)
#  75/119 [=================>............] - ETA: 2s - loss: 4.5628Shape of y_pred_back - (19, 1)
#  76/119 [==================>...........] - ETA: 2s - loss: 4.5296Shape of y_pred_back - (19, 1)
#  77/119 [==================>...........] - ETA: 2s - loss: 4.4982Shape of y_pred_back - (19, 1)
#  78/119 [==================>...........] - ETA: 2s - loss: 4.4674Shape of y_pred_back - (19, 1)
#  79/119 [==================>...........] - ETA: 2s - loss: 4.4372Shape of y_pred_back - (19, 1)
#  80/119 [===================>..........] - ETA: 2s - loss: 4.4076Shape of y_pred_back - (19, 1)
#  81/119 [===================>..........] - ETA: 2s - loss: 4.3791Shape of y_pred_back - (19, 1)
#  82/119 [===================>..........] - ETA: 2s - loss: 4.3516Shape of y_pred_back - (19, 1)
#  83/119 [===================>..........] - ETA: 2s - loss: 4.3248Shape of y_pred_back - (19, 1)
#  84/119 [====================>.........] - ETA: 2s - loss: 4.2986Shape of y_pred_back - (19, 1)
#  85/119 [====================>.........] - ETA: 2s - loss: 4.2729Shape of y_pred_back - (19, 1)
#  86/119 [====================>.........] - ETA: 1s - loss: 4.2477Shape of y_pred_back - (19, 1)
#  87/119 [====================>.........] - ETA: 1s - loss: 4.2230Shape of y_pred_back - (19, 1)
#  88/119 [=====================>........] - ETA: 1s - loss: 4.1985Shape of y_pred_back - (19, 1)
#  89/119 [=====================>........] - ETA: 1s - loss: 4.1744Shape of y_pred_back - (19, 1)
#  90/119 [=====================>........] - ETA: 1s - loss: 4.1506Shape of y_pred_back - (19, 1)
#  91/119 [=====================>........] - ETA: 1s - loss: 4.1272Shape of y_pred_back - (19, 1)
#  92/119 [======================>.......] - ETA: 1s - loss: 4.1045Shape of y_pred_back - (19, 1)
#  93/119 [======================>.......] - ETA: 1s - loss: 4.0826Shape of y_pred_back - (19, 1)
#  94/119 [======================>.......] - ETA: 1s - loss: 4.0612Shape of y_pred_back - (19, 1)
#  95/119 [======================>.......] - ETA: 1s - loss: 4.0401Shape of y_pred_back - (19, 1)
#  96/119 [=======================>......] - ETA: 1s - loss: 4.0194Shape of y_pred_back - (19, 1)
#  97/119 [=======================>......] - ETA: 1s - loss: 3.9991Shape of y_pred_back - (19, 1)
#  98/119 [=======================>......] - ETA: 1s - loss: 3.9792Shape of y_pred_back - (19, 1)
#  99/119 [=======================>......] - ETA: 1s - loss: 3.9596Shape of y_pred_back - (19, 1)
# 100/119 [========================>.....] - ETA: 1s - loss: 3.9403Shape of y_pred_back - (19, 1)
# 101/119 [========================>.....] - ETA: 1s - loss: 3.9213Shape of y_pred_back - (19, 1)
# 102/119 [========================>.....] - ETA: 1s - loss: 3.9031Shape of y_pred_back - (19, 1)
# 103/119 [========================>.....] - ETA: 0s - loss: 3.8855Shape of y_pred_back - (19, 1)
# 104/119 [=========================>....] - ETA: 0s - loss: 3.8684Shape of y_pred_back - (19, 1)
# 105/119 [=========================>....] - ETA: 0s - loss: 3.8517Shape of y_pred_back - (19, 1)
# 106/119 [=========================>....] - ETA: 0s - loss: 3.8356Shape of y_pred_back - (19, 1)
# 107/119 [=========================>....] - ETA: 0s - loss: 3.8197Shape of y_pred_back - (19, 1)
# 108/119 [==========================>...] - ETA: 0s - loss: 3.8041Shape of y_pred_back - (19, 1)
# 109/119 [==========================>...] - ETA: 0s - loss: 3.7886Shape of y_pred_back - (19, 1)
# 110/119 [==========================>...] - ETA: 0s - loss: 3.7735Shape of y_pred_back - (19, 1)
# 111/119 [==========================>...] - ETA: 0s - loss: 3.7588Shape of y_pred_back - (19, 1)
# 112/119 [===========================>..] - ETA: 0s - loss: 3.7445Shape of y_pred_back - (19, 1)
# 113/119 [===========================>..] - ETA: 0s - loss: 3.7304Shape of y_pred_back - (19, 1)
# 114/119 [===========================>..] - ETA: 0s - loss: 3.7177Shape of y_pred_back - (19, 1)
# 115/119 [===========================>..] - ETA: 0s - loss: 3.7054Shape of y_pred_back - (19, 1)
# 116/119 [============================>.] - ETA: 0s - loss: 3.6938Shape of y_pred_back - (19, 1)
# 117/119 [============================>.] - ETA: 0s - loss: 3.6826Shape of y_pred_back - (19, 1)
# 118/119 [============================>.] - ETA: 0s - loss: 3.6715Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - ETA: 0s - loss: 3.6606Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - 8s 64ms/step - loss: 3.6498 - val_loss: 6.0215
# Epoch 5/300
# Shape of y_pred_back - (19, 1)
# ...
# 119/119 [==============================] - ETA: 0s - loss: 0.5963Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - 7s 60ms/step - loss: 0.5981 - val_loss: 1.0274
# Epoch 49/300
# Shape of y_pred_back - (19, 1)
#   1/119 [..............................] - ETA: 6s - loss: 2.2954Shape of y_pred_back - (19, 1)
#   2/119 [..............................] - ETA: 6s - loss: 2.3315Shape of y_pred_back - (19, 1)
#   3/119 [..............................] - ETA: 6s - loss: 2.2373Shape of y_pred_back - (19, 1)
#   4/119 [>.............................] - ETA: 6s - loss: 2.1373Shape of y_pred_back - (19, 1)
#   5/119 [>.............................] - ETA: 6s - loss: 2.0127Shape of y_pred_back - (19, 1)
#   6/119 [>.............................] - ETA: 6s - loss: 1.8887Shape of y_pred_back - (19, 1)
#   7/119 [>.............................] - ETA: 6s - loss: 1.7782Shape of y_pred_back - (19, 1)
#   8/119 [=>............................] - ETA: 6s - loss: 1.6807Shape of y_pred_back - (19, 1)
#   9/119 [=>............................] - ETA: 6s - loss: 1.5935Shape of y_pred_back - (19, 1)
#  10/119 [=>............................] - ETA: 5s - loss: 1.5162Shape of y_pred_back - (19, 1)
#  11/119 [=>............................] - ETA: 5s - loss: 1.4474Shape of y_pred_back - (19, 1)
#  12/119 [==>...........................] - ETA: 5s - loss: 1.3898Shape of y_pred_back - (19, 1)
#  13/119 [==>...........................] - ETA: 5s - loss: 1.3369Shape of y_pred_back - (19, 1)
#  14/119 [==>...........................] - ETA: 5s - loss: 1.2886Shape of y_pred_back - (19, 1)
#  15/119 [==>...........................] - ETA: 5s - loss: 1.2448Shape of y_pred_back - (19, 1)
#  16/119 [===>..........................] - ETA: 5s - loss: 1.2043Shape of y_pred_back - (19, 1)
#  17/119 [===>..........................] - ETA: 5s - loss: 1.1669Shape of y_pred_back - (19, 1)
#  18/119 [===>..........................] - ETA: 5s - loss: 1.1321Shape of y_pred_back - (19, 1)
#  19/119 [===>..........................] - ETA: 5s - loss: 1.1000Shape of y_pred_back - (19, 1)
#  20/119 [====>.........................] - ETA: 5s - loss: 1.0698Shape of y_pred_back - (19, 1)
#  21/119 [====>.........................] - ETA: 5s - loss: 1.0420Shape of y_pred_back - (19, 1)
#  22/119 [====>.........................] - ETA: 5s - loss: 1.0162Shape of y_pred_back - (19, 1)
#  23/119 [====>.........................] - ETA: 5s - loss: 0.9920Shape of y_pred_back - (19, 1)
#  24/119 [=====>........................] - ETA: 5s - loss: 0.9695Shape of y_pred_back - (19, 1)
#  25/119 [=====>........................] - ETA: 5s - loss: 0.9482Shape of y_pred_back - (19, 1)
#  26/119 [=====>........................] - ETA: 5s - loss: 0.9280Shape of y_pred_back - (19, 1)
#  27/119 [=====>........................] - ETA: 5s - loss: 0.9089Shape of y_pred_back - (19, 1)
#  28/119 [======>.......................] - ETA: 4s - loss: 0.8910Shape of y_pred_back - (19, 1)
#  29/119 [======>.......................] - ETA: 4s - loss: 0.8740Shape of y_pred_back - (19, 1)
#  30/119 [======>.......................] - ETA: 4s - loss: 0.8578Shape of y_pred_back - (19, 1)
#  31/119 [======>.......................] - ETA: 4s - loss: 0.8425Shape of y_pred_back - (19, 1)
#  32/119 [=======>......................] - ETA: 4s - loss: 0.8280Shape of y_pred_back - (19, 1)
#  33/119 [=======>......................] - ETA: 4s - loss: 0.8143Shape of y_pred_back - (19, 1)
#  34/119 [=======>......................] - ETA: 4s - loss: 0.8012Shape of y_pred_back - (19, 1)
#  35/119 [=======>......................] - ETA: 4s - loss: 0.7887Shape of y_pred_back - (19, 1)
#  36/119 [========>.....................] - ETA: 4s - loss: 0.7769Shape of y_pred_back - (19, 1)
#  37/119 [========>.....................] - ETA: 4s - loss: 0.7659Shape of y_pred_back - (19, 1)
#  38/119 [========>.....................] - ETA: 4s - loss: 0.7553Shape of y_pred_back - (19, 1)
#  39/119 [========>.....................] - ETA: 4s - loss: 0.7452Shape of y_pred_back - (19, 1)
#  40/119 [=========>....................] - ETA: 4s - loss: 0.7354Shape of y_pred_back - (19, 1)
#  41/119 [=========>....................] - ETA: 4s - loss: 0.7261Shape of y_pred_back - (19, 1)
#  42/119 [=========>....................] - ETA: 4s - loss: 0.7170Shape of y_pred_back - (19, 1)
#  43/119 [=========>....................] - ETA: 4s - loss: 0.7083Shape of y_pred_back - (19, 1)
#  44/119 [==========>...................] - ETA: 4s - loss: 0.6998Shape of y_pred_back - (19, 1)
#  45/119 [==========>...................] - ETA: 4s - loss: 0.6916Shape of y_pred_back - (19, 1)
#  46/119 [==========>...................] - ETA: 4s - loss: 0.6837Shape of y_pred_back - (19, 1)
#  47/119 [==========>...................] - ETA: 3s - loss: 0.6759Shape of y_pred_back - (19, 1)
#  48/119 [===========>..................] - ETA: 3s - loss: 0.6684Shape of y_pred_back - (19, 1)
#  49/119 [===========>..................] - ETA: 3s - loss: 0.6612Shape of y_pred_back - (19, 1)
#  50/119 [===========>..................] - ETA: 3s - loss: 0.6542Shape of y_pred_back - (19, 1)
#  51/119 [===========>..................] - ETA: 3s - loss: 0.6474Shape of y_pred_back - (19, 1)
#  52/119 [============>.................] - ETA: 3s - loss: 0.6408Shape of y_pred_back - (19, 1)
#  53/119 [============>.................] - ETA: 3s - loss: 0.6343Shape of y_pred_back - (19, 1)
#  54/119 [============>.................] - ETA: 3s - loss: 0.6281Shape of y_pred_back - (19, 1)
#  55/119 [============>.................] - ETA: 3s - loss: 0.6220Shape of y_pred_back - (19, 1)
#  56/119 [=============>................] - ETA: 3s - loss: 0.6160Shape of y_pred_back - (19, 1)
#  57/119 [=============>................] - ETA: 3s - loss: 0.6104Shape of y_pred_back - (19, 1)
#  58/119 [=============>................] - ETA: 3s - loss: 0.6048Shape of y_pred_back - (19, 1)
#  59/119 [=============>................] - ETA: 3s - loss: 0.5994Shape of y_pred_back - (19, 1)
#  60/119 [==============>...............] - ETA: 3s - loss: 0.5941Shape of y_pred_back - (19, 1)
#  61/119 [==============>...............] - ETA: 3s - loss: 0.5889Shape of y_pred_back - (19, 1)
#  62/119 [==============>...............] - ETA: 3s - loss: 0.5839Shape of y_pred_back - (19, 1)
#  63/119 [==============>...............] - ETA: 3s - loss: 0.5790Shape of y_pred_back - (19, 1)
#  64/119 [===============>..............] - ETA: 3s - loss: 0.5743Shape of y_pred_back - (19, 1)
#  65/119 [===============>..............] - ETA: 3s - loss: 0.5696Shape of y_pred_back - (19, 1)
#  66/119 [===============>..............] - ETA: 2s - loss: 0.5650Shape of y_pred_back - (19, 1)
#  67/119 [===============>..............] - ETA: 2s - loss: 0.5605Shape of y_pred_back - (19, 1)
#  68/119 [================>.............] - ETA: 2s - loss: 0.5561Shape of y_pred_back - (19, 1)
#  69/119 [================>.............] - ETA: 2s - loss: 0.5519Shape of y_pred_back - (19, 1)
#  70/119 [================>.............] - ETA: 2s - loss: 0.5477Shape of y_pred_back - (19, 1)
#  71/119 [================>.............] - ETA: 2s - loss: 0.5436Shape of y_pred_back - (19, 1)
#  72/119 [=================>............] - ETA: 2s - loss: 0.5396Shape of y_pred_back - (19, 1)
#  73/119 [=================>............] - ETA: 2s - loss: 0.5357Shape of y_pred_back - (19, 1)
#  74/119 [=================>............] - ETA: 2s - loss: 0.5319Shape of y_pred_back - (19, 1)
#  75/119 [=================>............] - ETA: 2s - loss: 0.5282Shape of y_pred_back - (19, 1)
#  76/119 [==================>...........] - ETA: 2s - loss: 0.5247Shape of y_pred_back - (19, 1)
#  77/119 [==================>...........] - ETA: 2s - loss: 0.5213Shape of y_pred_back - (19, 1)
#  78/119 [==================>...........] - ETA: 2s - loss: 0.5183Shape of y_pred_back - (19, 1)
#  79/119 [==================>...........] - ETA: 2s - loss: 0.5154Shape of y_pred_back - (19, 1)
#  80/119 [===================>..........] - ETA: 2s - loss: 0.5126Shape of y_pred_back - (19, 1)
#  81/119 [===================>..........] - ETA: 2s - loss: 0.5098Shape of y_pred_back - (19, 1)
#  82/119 [===================>..........] - ETA: 2s - loss: 0.5071Shape of y_pred_back - (19, 1)
#  83/119 [===================>..........] - ETA: 2s - loss: 0.5044Shape of y_pred_back - (19, 1)
#  84/119 [====================>.........] - ETA: 1s - loss: 0.5018Shape of y_pred_back - (19, 1)
#  85/119 [====================>.........] - ETA: 1s - loss: 0.4993Shape of y_pred_back - (19, 1)
#  86/119 [====================>.........] - ETA: 1s - loss: 0.4968Shape of y_pred_back - (19, 1)
#  87/119 [====================>.........] - ETA: 1s - loss: 0.4944Shape of y_pred_back - (19, 1)
#  88/119 [=====================>........] - ETA: 1s - loss: 0.4920Shape of y_pred_back - (19, 1)
#  89/119 [=====================>........] - ETA: 1s - loss: 0.4897Shape of y_pred_back - (19, 1)
#  90/119 [=====================>........] - ETA: 1s - loss: 0.4874Shape of y_pred_back - (19, 1)
#  91/119 [=====================>........] - ETA: 1s - loss: 0.4852Shape of y_pred_back - (19, 1)
#  92/119 [======================>.......] - ETA: 1s - loss: 0.4831Shape of y_pred_back - (19, 1)
#  93/119 [======================>.......] - ETA: 1s - loss: 0.4811Shape of y_pred_back - (19, 1)
#  94/119 [======================>.......] - ETA: 1s - loss: 0.4792Shape of y_pred_back - (19, 1)
#  95/119 [======================>.......] - ETA: 1s - loss: 0.4772Shape of y_pred_back - (19, 1)
#  96/119 [=======================>......] - ETA: 1s - loss: 0.4754Shape of y_pred_back - (19, 1)
#  97/119 [=======================>......] - ETA: 1s - loss: 0.4735Shape of y_pred_back - (19, 1)
#  98/119 [=======================>......] - ETA: 1s - loss: 0.4718Shape of y_pred_back - (19, 1)
#  99/119 [=======================>......] - ETA: 1s - loss: 0.4701Shape of y_pred_back - (19, 1)
# 100/119 [========================>.....] - ETA: 1s - loss: 0.4685Shape of y_pred_back - (19, 1)
# 101/119 [========================>.....] - ETA: 1s - loss: 0.4670Shape of y_pred_back - (19, 1)
# 102/119 [========================>.....] - ETA: 0s - loss: 0.4657Shape of y_pred_back - (19, 1)
# 103/119 [========================>.....] - ETA: 0s - loss: 0.4648Shape of y_pred_back - (19, 1)
# 104/119 [=========================>....] - ETA: 0s - loss: 0.4639Shape of y_pred_back - (19, 1)
# 105/119 [=========================>....] - ETA: 0s - loss: 0.4635Shape of y_pred_back - (19, 1)
# 106/119 [=========================>....] - ETA: 0s - loss: 0.4632Shape of y_pred_back - (19, 1)
# 107/119 [=========================>....] - ETA: 0s - loss: 0.4629Shape of y_pred_back - (19, 1)
# 108/119 [==========================>...] - ETA: 0s - loss: 0.4628Shape of y_pred_back - (19, 1)
# 109/119 [==========================>...] - ETA: 0s - loss: 0.4628Shape of y_pred_back - (19, 1)
# 110/119 [==========================>...] - ETA: 0s - loss: 0.4629Shape of y_pred_back - (19, 1)
# 111/119 [==========================>...] - ETA: 0s - loss: 0.4632Shape of y_pred_back - (19, 1)
# 112/119 [===========================>..] - ETA: 0s - loss: 0.4639Shape of y_pred_back - (19, 1)
# 113/119 [===========================>..] - ETA: 0s - loss: 0.4650Shape of y_pred_back - (19, 1)
# 114/119 [===========================>..] - ETA: 0s - loss: 0.4662Shape of y_pred_back - (19, 1)
# 115/119 [===========================>..] - ETA: 0s - loss: 0.4676Shape of y_pred_back - (19, 1)
# 116/119 [============================>.] - ETA: 0s - loss: 0.4691Shape of y_pred_back - (19, 1)
# 117/119 [============================>.] - ETA: 0s - loss: 0.4706Shape of y_pred_back - (19, 1)
# 118/119 [============================>.] - ETA: 0s - loss: 0.4724Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - ETA: 0s - loss: 0.4746Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# Shape of y_pred_back - (19, 1)
# 119/119 [==============================] - 7s 59ms/step - loss: 0.4767 - val_loss: 0.6359
# Epoch 50/300
# Shape of y_pred_back - (19, 1)
#   1/119 [..............................] - ETA: 6s - loss: 4.1654Shape of y_pred_back - (19, 1)
#   2/119 [..............................] - ETA: 6s - loss: 3.7112Shape of y_pred_back - (19, 1)
#   3/119 [..............................] - ETA: 6s - loss: 3.4005Shape of y_pred_back - (19, 1)
#   4/119 [>.............................] - ETA: 6s - loss: 3.2386Shape of y_pred_back - (19, 1)
#   5/119 [>.............................] - ETA: 6s - loss: 3.0404Shape of y_pred_back - (19, 1)
#   6/119 [>.............................] - ETA: 6s - loss: 2.8523Shape of y_pred_back - (19, 1)
#   7/119 [>.............................] - ETA: 6s - loss: 2.6816Shape of y_pred_back - (19, 1)
#   8/119 [=>............................] - ETA: 6s - loss: 2.5297Shape of y_pred_back - (19, 1)
#   9/119 [=>............................] - ETA: 6s - loss: 2.3939Shape of y_pred_back - (19, 1)
#  10/119 [=>............................] - ETA: 6s - loss: 2.2726Shape of y_pred_back - (19, 1)
#  11/119 [=>............................] - ETA: 6s - loss: 2.1642Shape of y_pred_back - (19, 1)
#  12/119 [==>...........................] - ETA: 6s - loss: 2.0744Shape of y_pred_back - (19, 1)
#  13/119 [==>...........................] - ETA: 6s - loss: 1.9934Shape of y_pred_back - (19, 1)
#  14/119 [==>...........................] - ETA: 6s - loss: 1.9192Shape of y_pred_back - (19, 1)
#  15/119 [==>...........................] - ETA: 5s - loss: 1.8512Shape of y_pred_back - (19, 1)
#  16/119 [===>..........................] - ETA: 5s - loss: 1.7882Shape of y_pred_back - (19, 1)
#  17/119 [===>..........................] - ETA: 5s - loss: 1.7303Shape of y_pred_back - (19, 1)
#  18/119 [===>..........................] - ETA: 5s - loss: 1.6765Shape of y_pred_back - (19, 1)
#  19/119 [===>..........................] - ETA: 5s - loss: 1.6265Shape of y_pred_back - (19, 1)
#  20/119 [====>.........................] - ETA: 5s - loss: 1.5799Shape of y_pred_back - (19, 1)
#  21/119 [====>.........................] - ETA: 5s - loss: 1.5370Shape of y_pred_back - (19, 1)
#  22/119 [====>.........................] - ETA: 5s - loss: 1.4977Shape of y_pred_back - (19, 1)
#  23/119 [====>.........................] - ETA: 5s - loss: 1.4607Shape of y_pred_back - (19, 1)
#  24/119 [=====>........................] - ETA: 5s - loss: 1.4262Shape of y_pred_back - (19, 1)
#  25/119 [=====>........................] - ETA: 5s - loss: 1.3937Shape of y_pred_back - (19, 1)
#  26/119 [=====>........................] - ETA: 5s - loss: 1.3631Shape of y_pred_back - (19, 1)
#  27/119 [=====>........................] - ETA: 5s - loss: 1.3340Shape of y_pred_back - (19, 1)
#  28/119 [======>.......................] - ETA: 5s - loss: 1.3064Shape of y_pred_back - (19, 1)
#  29/119 [======>.......................] - ETA: 5s - loss: 1.2801Shape of y_pred_back - (19, 1)
#  30/119 [======>.......................] - ETA: 5s - loss: 1.2557Shape of y_pred_back - (19, 1)
#  31/119 [======>.......................] - ETA: 4s - loss: 1.2326Shape of y_pred_back - (19, 1)
#  32/119 [=======>......................] - ETA: 4s - loss: 1.2107Shape of y_pred_back - (19, 1)
#  33/119 [=======>......................] - ETA: 4s - loss: 1.1897Shape of y_pred_back - (19, 1)
#  34/119 [=======>......................] - ETA: 4s - loss: 1.1696Shape of y_pred_back - (19, 1)
#  35/119 [=======>......................] - ETA: 4s - loss: 1.1505

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
y_pred = lstm_model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)
print("Error is", error, y_pred.shape, y_test_t.shape)
print(y_pred[0:15])
print(y_test_t[0:15])

# convert the predicted value to range of real data
y_pred_org = (y_pred * min_max_scaler.data_range_[0]) + min_max_scaler.data_min_[0]
# min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[0]) + min_max_scaler.data_min_[0]
# min_max_scaler.inverse_transform(y_test_t)
print(y_pred_org[0:15])
print(y_test_t_org[0:15])

# %%
plt.figure()
plt.plot(y_pred_org)
plt.plot(y_test_t_org)
plt.title('Prediction vs Real Stock Price')
plt.ylabel('Price')
plt.xlabel('Days')
plt.legend(['Prediction', 'Real'], loc='upper left')

# %%
mean_absolute_percentage_error(y_pred_org,y_test_t_org)*100

# %%
mean_squared_error(y_pred_org,y_test_t_org)

# %%
from sklearn.metrics import accuracy_score
y_pred_lstm_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_pred)
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] # min_max_scaler.inverse_transform(y_test_t)

print(y_pred_lstm_org[0:15])
print(y_test_t_org[0:15])

y_test_t_final = np.zeros((len(y_test_t_org)-1,))
y_pred_lstm_final = np.zeros((len(y_pred)-1,))

#convert prediction into binary output (up or down movement)
for i in range(len(y_pred_lstm_org)-1):
    if y_pred_lstm_org[i+1] >= y_pred_lstm_org[i]:
        y_pred_lstm_final[i] = 1
    else:
        y_pred_lstm_final[i] = 0
        
#convert prediction into binary output (up or down movement)
for i in range(len(y_test_t_org)-1):
    if y_test_t_org[i+1] >= y_test_t_org[i]:
        y_test_t_final[i] = 1
    else:
        y_test_t_final[i] = 0


# error_lstm = mean_absolute_error(y_test_t_final, y_pred_lstm_final)
# print("Error is", error_lstm, y_pred_lstm_final.shape, y_test_t_final.shape)
print(y_pred_lstm_final[0:15])
print(y_test_t_final[0:15])
print("Predicted direction accuracy (Up/down):")
print(accuracy_score(y_test_t_final,y_pred_lstm_final))
