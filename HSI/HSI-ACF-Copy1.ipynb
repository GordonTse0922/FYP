# %%
from statsmodels.graphics.tsaplots import plot_acf
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data=yf.download('HSI')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 1975-01-31    220.000000    220.000000    220.000000    220.000000
# 1975-02-28    253.000000    253.000000    253.000000    253.000000
# 1975-03-31    279.000000    279.000000    279.000000    279.000000
# 1975-04-30    323.000000    323.000000    323.000000    323.000000
# 1975-05-30    321.000000    321.000000    321.000000    321.000000
# ...                  ...           ...           ...           ...
# 2022-02-24  22901.599609  22901.599609  22901.599609  22901.599609
# 2022-02-25  22767.199219  22767.199219  22767.199219  22767.199219
# 2022-02-28  22713.000000  22713.000000  22713.000000  22713.000000
# 2022-03-01  22761.699219  22761.699219  22761.699219  22761.699219
# 2022-03-02  22343.900391  22343.900391  22343.900391  22343.900391
#
#                Adj Close  Volume
# Date
# 1975-01-31    220.000000       0
# 1975-02-28    253.000000       0
# 1975-03-31    279.000000       0
# 1975-04-30    323.000000       0
# 1975-05-30    321.000000       0
# ...                  ...     ...
# 2022-02-24  22901.599609       0
# 2022-02-25  22767.199219       0
# 2022-02-28  22713.000000       0
# 2022-03-01  22761.699219       0
# 2022-03-02  22343.900391       0
#
# [10706 rows x 6 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

res = seasonal_decompose(data, model = "additive",period = 30)

fig, (ax1,ax2,ax3) = plt.subplots(3,1, figsize=(15,8))
res.trend.plot(ax=ax1,ylabel = "trend")
res.resid.plot(ax=ax2,ylabel = "seasoanlity")
res.seasonal.plot(ax=ax3,ylabel = "residual")
plt.show()

# %%
plot_acf(res.seasonal,lags=12)
plt.show()

# %%
plt.rc("figure", figsize=(20,10))
plt.figure(figsize=(20,10))
plot_acf(data.values, lags=360)
plt.show()
