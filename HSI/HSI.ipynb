# %%
from statsmodels.graphics.tsaplots import plot_acf
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data=yf.download('HSI','2020-01-01','2022-01-01')
data.drop('Volume',1,inplace=True)
data=data['Close']
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - HSI: No data found for this date range, symbol may be delisted
# /tmp/ipykernel_24712/2320309470.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data.drop('Volume',1,inplace=True)
# Series([], Name: Close, dtype: float64)

# %%
plt.figure(figsize=(20,10))
plt.plot(data.values)

# %%
plt.rc("figure", figsize=(20,10))
plt.figure(figsize=(20,10))
plot_acf(data.values, lags=360)
plt.show()
