# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score, mean_squared_error,mean_absolute_percentage_error,r2_score
import tensorflow as tf
import talib
from tensorflow import keras
from sklearn.pipeline import make_pipeline
from tensorflow.keras import regularizers

# %%
data=yf.download('0700.hk')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data['6day MA'] = data['Close'].rolling(window = 6).mean()
data['12day MA'] = data['Close'].rolling(window = 12).mean()
data['RSI'] = talib.RSI(data['Close'].values, timeperiod = 7)
data['%R5'] = talib.WILLR(data['High'].values, data['Low'].values, data['Close'].values, 5)
data['%R10'] = talib.WILLR(data['High'].values, data['Low'].values, data['Close'].values, 10)
data['MI6']=talib.MOM(data['Close'],timeperiod=6)
data['MI12']=talib.MOM(data['Close'],timeperiod=12)
macd, macdsignal, macdhist = talib.MACD(data['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
data['EMA12']=talib.EMA(data['Close'], timeperiod=12)
data['EMA26']=talib.EMA(data['Close'],timeperiod=26)
data['MACD']=macd
data['TR']=talib.TRANGE(data['High'],data['Low'],data['Close'])
data['OSC6']=talib.CMO(data['Close'], timeperiod=6)
data['OSC12']=talib.CMO(data['Close'], timeperiod=12)
data['Prediction']=data['Close'].shift(-1)
data.dropna(inplace=True)

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.ensemble import RandomForestRegressor
#k_features=10 (It will get top 10 features best suited for prediction)
#forward=False (Backward feature selection model)
#verbose=2 (It will show details output as shown below.)
#cv=5 (Kfold cross valiation: it will split the training set in 5 set and 4 will be using for training the model and 1 will using as validation)
#n_jobs=-1 (Number of cores it will use for execution.-1 means it will use all the cores of CPU for execution.)
#scoring='r2'(R-squared is a statistical measure of how close the data are to the fitted regression line)
backwardModel=sfs(RandomForestRegressor(),k_features=10,forward=True,verbose=2,cv=5,n_jobs=-1,scoring='r2')
#We will convert our training data into numpy array. If we will not convert it, model is not able to read some of the column names.
backwardModel.fit(np.array(data.drop('Prediction',1)),data['Prediction'].values.ravel())
# Out:
# /tmp/ipykernel_3132/3525057244.py:11: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   backwardModel.fit(np.array(data.drop('Prediction',1)),data['Prediction'].values.ravel())
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  19 | elapsed:    2.2s remaining:   18.9s
# [Parallel(n_jobs=-1)]: Done  12 out of  19 | elapsed:    2.7s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:    4.0s finished
#
# [2022-03-21 01:59:52] Features: 1/10 -- score: 0.2893020424071953[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  18 | elapsed:    0.0s remaining:    0.0s
#
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# SequentialFeatureSelector(estimator=RandomForestRegressor(), k_features=10,
#                           n_jobs=-1, scoring='r2', verbose=2)

# %%
data=data[data.columns[list(backwardModel.k_feature_idx_)]]
data['Prediction']=data['Close'].shift(-1)
data.dropna(inplace=True)
data_val=data[-100:]
data=data[:-100]
data_val.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-03-10  395.399994  398.799988  381.200012  385.000000  385.000000
# 2022-03-11  369.000000  375.399994  360.000000  367.799988  367.799988
# 2022-03-14  353.000000  359.600006  330.000000  331.799988  331.799988
# 2022-03-15  305.200012  333.200012  297.000000  298.000000  298.000000
# 2022-03-16  315.200012  370.799988  310.399994  367.000000  367.000000
#
#                Volume     6day MA       %R10       EMA12         TR  \
# Date
# 2022-03-10   24062703  393.833333 -78.260870  409.434724  17.599976
# 2022-03-11   48435608  385.333333 -90.126598  403.029380  25.000000
# 2022-03-14   66910165  373.433329 -98.348635  392.071012  37.799988
# 2022-03-15  118398276  358.433329 -99.274311  377.598548  36.200012
# 2022-03-16  107736861  355.733327 -45.904171  375.968002  72.799988
#
#             Prediction
# Date
# 2022-03-10  367.799988
# 2022-03-11  331.799988
# 2022-03-14  298.000000
# 2022-03-15  367.000000
# 2022-03-16  390.000000

# %%
sc = MinMaxScaler(feature_range = (-1, 1))

# %%
X=sc.fit_transform(data.drop('Prediction',1))
Y = data["Prediction"].values.reshape(-1,1)
# Y=np.array(data["Close"])
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (3830, 1, 10) (3830, 1) (426, 1, 10) (426, 1)
# /tmp/ipykernel_3132/1768392262.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X=sc.fit_transform(data.drop('Prediction',1))

# %%
model_tech = keras.Sequential()
model_tech.add(keras.layers.LSTM(
  units=128,
  input_shape=(X_train.shape[1], X_train.shape[2]),
    return_sequences=True,
    kernel_regularizer=regularizers.l2(0.01)
))
model_tech.add(keras.layers.LSTM(units=64))
model_tech.add(keras.layers.Dense(units=64))
model_tech.add(keras.layers.Dense(units=1))
model_tech.compile(
  loss='mean_squared_error',
  optimizer=keras.optimizers.Adam(0.001)
)

# %%
history_tech=model_tech.fit(
    X_train, y_train,
    epochs=300,
    batch_size=5,
    validation_split=0.1,
    verbose=1,
    shuffle=False
)
y_pred = model_tech.predict(X_test)
# Out:
# Epoch 1/300
# 690/690 [==============================] - 6s 5ms/step - loss: 13109.6592 - val_loss: 972.0453
# Epoch 2/300
# 690/690 [==============================] - 3s 4ms/step - loss: 391.5601 - val_loss: 260.2980
# Epoch 3/300
# 690/690 [==============================] - 2s 3ms/step - loss: 124.8960 - val_loss: 136.0922
# Epoch 4/300
# 690/690 [==============================] - 3s 4ms/step - loss: 77.9944 - val_loss: 93.4414
# Epoch 5/300
# 690/690 [==============================] - 2s 3ms/step - loss: 65.7394 - val_loss: 75.1700
# Epoch 6/300
# 690/690 [==============================] - 2s 3ms/step - loss: 60.0104 - val_loss: 63.2115
# Epoch 7/300
# 690/690 [==============================] - 2s 3ms/step - loss: 56.1953 - val_loss: 55.3806
# Epoch 8/300
# 690/690 [==============================] - 2s 3ms/step - loss: 53.4824 - val_loss: 50.6050
# Epoch 9/300
# 690/690 [==============================] - 2s 3ms/step - loss: 51.5569 - val_loss: 47.9468
# Epoch 10/300
# 690/690 [==============================] - 2s 3ms/step - loss: 50.2001 - val_loss: 46.5699
# Epoch 11/300
# 690/690 [==============================] - 2s 3ms/step - loss: 49.2467 - val_loss: 45.8712
# Epoch 12/300
# 690/690 [==============================] - 2s 3ms/step - loss: 48.5707 - val_loss: 45.4883
# Epoch 13/300
# 690/690 [==============================] - 2s 3ms/step - loss: 48.0754 - val_loss: 45.2409
# Epoch 14/300
# 690/690 [==============================] - 2s 3ms/step - loss: 47.6910 - val_loss: 45.0573
# Epoch 15/300
# 690/690 [==============================] - 2s 3ms/step - loss: 47.3739 - val_loss: 44.9126
# Epoch 16/300
# 690/690 [==============================] - 2s 3ms/step - loss: 47.0989 - val_loss: 44.7967
# Epoch 17/300
# 690/690 [==============================] - 2s 3ms/step - loss: 46.8523 - val_loss: 44.7043
# Epoch 18/300
# 690/690 [==============================] - 2s 3ms/step - loss: 46.6260 - val_loss: 44.6318
# Epoch 19/300
# 690/690 [==============================] - 2s 3ms/step - loss: 46.4149 - val_loss: 44.5768
# Epoch 20/300
# 690/690 [==============================] - 2s 3ms/step - loss: 46.2158 - val_loss: 44.5383
# Epoch 21/300
# 690/690 [==============================] - 2s 3ms/step - loss: 46.0264 - val_loss: 44.5147
# Epoch 22/300
# 690/690 [==============================] - 2s 3ms/step - loss: 45.8454 - val_loss: 44.5055
# Epoch 23/300
# 690/690 [==============================] - 2s 3ms/step - loss: 45.6716 - val_loss: 44.5098
# Epoch 24/300
# 690/690 [==============================] - 2s 3ms/step - loss: 45.5042 - val_loss: 44.5271
# Epoch 25/300
# 690/690 [==============================] - 2s 3ms/step - loss: 45.3426 - val_loss: 44.5567
# Epoch 26/300
# 690/690 [==============================] - 2s 3ms/step - loss: 45.1861 - val_loss: 44.5984
# Epoch 27/300
# 690/690 [==============================] - 2s 3ms/step - loss: 45.0339 - val_loss: 44.6522
# Epoch 28/300
# 690/690 [==============================] - 2s 3ms/step - loss: 44.8854 - val_loss: 44.7188
# Epoch 29/300
# 690/690 [==============================] - 2s 3ms/step - loss: 44.7397 - val_loss: 44.7984
# Epoch 30/300
# 690/690 [==============================] - 2s 3ms/step - loss: 44.5961 - val_loss: 44.8921
# Epoch 31/300
# 690/690 [==============================] - 2s 3ms/step - loss: 44.4541 - val_loss: 45.0004
# Epoch 32/300
# 690/690 [==============================] - 2s 3ms/step - loss: 44.3133 - val_loss: 45.1245
# Epoch 33/300
# 690/690 [==============================] - 2s 3ms/step - loss: 44.1732 - val_loss: 45.2657
# Epoch 34/300
# 690/690 [==============================] - 2s 3ms/step - loss: 44.0338 - val_loss: 45.4253
# Epoch 35/300
# 690/690 [==============================] - 2s 3ms/step - loss: 43.8951 - val_loss: 45.6048
# Epoch 36/300
# 690/690 [==============================] - 2s 3ms/step - loss: 43.7573 - val_loss: 45.8067
# Epoch 37/300
# 690/690 [==============================] - 2s 3ms/step - loss: 43.6208 - val_loss: 46.0334
# Epoch 38/300
# 690/690 [==============================] - 2s 3ms/step - loss: 43.4859 - val_loss: 46.2874
# Epoch 39/300
# 690/690 [==============================] - 2s 3ms/step - loss: 43.3529 - val_loss: 46.5690
# Epoch 40/300
# 690/690 [==============================] - 2s 3ms/step - loss: 43.2212 - val_loss: 46.8738
# Epoch 41/300
# 690/690 [==============================] - 2s 3ms/step - loss: 43.0896 - val_loss: 47.1923
# Epoch 42/300
# 690/690 [==============================] - 2s 3ms/step - loss: 42.9558 - val_loss: 47.5125
# Epoch 43/300
# 690/690 [==============================] - 2s 3ms/step - loss: 42.8180 - val_loss: 47.8204
# Epoch 44/300
# 690/690 [==============================] - 2s 3ms/step - loss: 42.6760 - val_loss: 48.0990
# Epoch 45/300
# 690/690 [==============================] - 2s 3ms/step - loss: 42.5314 - val_loss: 48.3304
# Epoch 46/300
# 690/690 [==============================] - 2s 3ms/step - loss: 42.3862 - val_loss: 48.4995
# Epoch 47/300
# 690/690 [==============================] - 2s 3ms/step - loss: 42.2419 - val_loss: 48.5971
# Epoch 48/300
# 690/690 [==============================] - 2s 3ms/step - loss: 42.1002 - val_loss: 48.6234
# Epoch 49/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.9633 - val_loss: 48.5918
# Epoch 50/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.8314 - val_loss: 48.5202
# Epoch 51/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.7016 - val_loss: 48.4063
# Epoch 52/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.5694 - val_loss: 48.2160
# Epoch 53/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.4376 - val_loss: 47.9339
# Epoch 54/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.3229 - val_loss: 47.6596
# Epoch 55/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.2194 - val_loss: 47.4547
# Epoch 56/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.1127 - val_loss: 47.2902
# Epoch 57/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.0123 - val_loss: 47.2004
# Epoch 58/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.9020 - val_loss: 47.1032
# Epoch 59/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.8006 - val_loss: 47.0480
# Epoch 60/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.6906 - val_loss: 46.9572
# Epoch 61/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.6095 - val_loss: 47.0138
# Epoch 62/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.3932 - val_loss: 46.3237
# Epoch 63/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.0911 - val_loss: 51.9175
# Epoch 64/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.4076 - val_loss: 40.7821
# Epoch 65/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.8170 - val_loss: 43.2142
# Epoch 66/300
# 690/690 [==============================] - 2s 3ms/step - loss: 41.1478 - val_loss: 46.2381
# Epoch 67/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.7122 - val_loss: 49.1058
# Epoch 68/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.3275 - val_loss: 51.0478
# Epoch 69/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.7405 - val_loss: 46.3629
# Epoch 70/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.2369 - val_loss: 49.1427
# Epoch 71/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.2541 - val_loss: 52.8411
# Epoch 72/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.8780 - val_loss: 41.3570
# Epoch 73/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.9734 - val_loss: 43.5963
# Epoch 74/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.4463 - val_loss: 46.0486
# Epoch 75/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.2115 - val_loss: 48.6111
# Epoch 76/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.9569 - val_loss: 51.2436
# Epoch 77/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.3740 - val_loss: 49.6335
# Epoch 78/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.3528 - val_loss: 48.5980
# Epoch 79/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.4284 - val_loss: 48.9006
# Epoch 80/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.2187 - val_loss: 47.9566
# Epoch 81/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.3861 - val_loss: 49.4782
# Epoch 82/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.0540 - val_loss: 48.4483
# Epoch 83/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.9449 - val_loss: 46.8923
# Epoch 84/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.0779 - val_loss: 47.5131
# Epoch 85/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.0123 - val_loss: 48.2652
# Epoch 86/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.7133 - val_loss: 43.5526
# Epoch 87/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.3999 - val_loss: 48.1220
# Epoch 88/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.6911 - val_loss: 55.7301
# Epoch 89/300
# 690/690 [==============================] - 2s 3ms/step - loss: 40.3904 - val_loss: 39.8647
# Epoch 90/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.7054 - val_loss: 40.7697
# Epoch 91/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.2978 - val_loss: 41.4912
# Epoch 92/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.1813 - val_loss: 42.1533
# Epoch 93/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.1105 - val_loss: 42.8855
# Epoch 94/300
# 690/690 [==============================] - 2s 3ms/step - loss: 39.0324 - val_loss: 43.7242
# Epoch 95/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.9505 - val_loss: 44.6355
# Epoch 96/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.8819 - val_loss: 45.5949
# Epoch 97/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.7868 - val_loss: 46.5314
# Epoch 98/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.6642 - val_loss: 47.2831
# Epoch 99/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.5478 - val_loss: 47.7683
# Epoch 100/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.4426 - val_loss: 47.9525
# Epoch 101/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.3562 - val_loss: 47.9356
# Epoch 102/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.2874 - val_loss: 47.8501
# Epoch 103/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.2278 - val_loss: 47.7745
# Epoch 104/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.1687 - val_loss: 47.7050
# Epoch 105/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.1086 - val_loss: 47.6183
# Epoch 106/300
# 690/690 [==============================] - 2s 3ms/step - loss: 38.0513 - val_loss: 47.5231
# Epoch 107/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.9997 - val_loss: 47.4415
# Epoch 108/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.9503 - val_loss: 47.3846
# Epoch 109/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.8999 - val_loss: 47.3307
# Epoch 110/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.8494 - val_loss: 47.2590
# Epoch 111/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.8028 - val_loss: 47.1931
# Epoch 112/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.7571 - val_loss: 47.1274
# Epoch 113/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.7132 - val_loss: 47.0702
# Epoch 114/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.6686 - val_loss: 47.0003
# Epoch 115/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.6261 - val_loss: 46.9293
# Epoch 116/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.5838 - val_loss: 46.8489
# Epoch 117/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.5442 - val_loss: 46.7818
# Epoch 118/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.5034 - val_loss: 46.7010
# Epoch 119/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.4660 - val_loss: 46.6384
# Epoch 120/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.4257 - val_loss: 46.5478
# Epoch 121/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.3919 - val_loss: 46.5061
# Epoch 122/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.3479 - val_loss: 46.3713
# Epoch 123/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.3231 - val_loss: 46.3928
# Epoch 124/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.2663 - val_loss: 46.1323
# Epoch 125/300
# 690/690 [==============================] - 3s 4ms/step - loss: 37.2695 - val_loss: 46.3956
# Epoch 126/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.1713 - val_loss: 45.7389
# Epoch 127/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.2282 - val_loss: 46.3843
# Epoch 128/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.1365 - val_loss: 46.3498
# Epoch 129/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.0378 - val_loss: 44.6185
# Epoch 130/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.0573 - val_loss: 44.7396
# Epoch 131/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.6100 - val_loss: 49.6089
# Epoch 132/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.3322 - val_loss: 40.1421
# Epoch 133/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.8413 - val_loss: 42.1676
# Epoch 134/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.3878 - val_loss: 44.1452
# Epoch 135/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.2990 - val_loss: 46.4895
# Epoch 136/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.0215 - val_loss: 48.0743
# Epoch 137/300
# 690/690 [==============================] - 2s 4ms/step - loss: 36.7983 - val_loss: 45.8831
# Epoch 138/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.7880 - val_loss: 45.6932
# Epoch 139/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.0861 - val_loss: 48.0409
# Epoch 140/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.7416 - val_loss: 44.6667
# Epoch 141/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.7823 - val_loss: 46.1274
# Epoch 142/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.0892 - val_loss: 49.2865
# Epoch 143/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.8886 - val_loss: 40.9222
# Epoch 144/300
# 690/690 [==============================] - 2s 3ms/step - loss: 37.1196 - val_loss: 42.7701
# Epoch 145/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.9697 - val_loss: 44.5178
# Epoch 146/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.8711 - val_loss: 46.3233
# Epoch 147/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.6396 - val_loss: 46.9315
# Epoch 148/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.5273 - val_loss: 46.0466
# Epoch 149/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.5262 - val_loss: 46.0090
# Epoch 150/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.5636 - val_loss: 46.4795
# Epoch 151/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.4582 - val_loss: 45.7355
# Epoch 152/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.4550 - val_loss: 45.9273
# Epoch 153/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.4572 - val_loss: 46.2629
# Epoch 154/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.3540 - val_loss: 45.3787
# Epoch 155/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.3792 - val_loss: 45.9614
# Epoch 156/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.3469 - val_loss: 46.0472
# Epoch 157/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.2514 - val_loss: 45.1155
# Epoch 158/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.3061 - val_loss: 46.0476
# Epoch 159/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.2285 - val_loss: 45.6223
# Epoch 160/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.1732 - val_loss: 45.3586
# Epoch 161/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.1996 - val_loss: 45.9194
# Epoch 162/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.1093 - val_loss: 45.0371
# Epoch 163/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.1372 - val_loss: 45.9174
# Epoch 164/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.0558 - val_loss: 45.0818
# Epoch 165/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.0625 - val_loss: 45.8166
# Epoch 166/300
# 690/690 [==============================] - 2s 4ms/step - loss: 35.9915 - val_loss: 44.9908
# Epoch 167/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.0105 - val_loss: 45.8840
# Epoch 168/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.9188 - val_loss: 44.5793
# Epoch 169/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.9903 - val_loss: 46.2435
# Epoch 170/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.8562 - val_loss: 43.7976
# Epoch 171/300
# 690/690 [==============================] - 2s 3ms/step - loss: 36.0134 - val_loss: 46.5474
# Epoch 172/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.7966 - val_loss: 43.8129
# Epoch 173/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.9508 - val_loss: 46.5965
# Epoch 174/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.7277 - val_loss: 43.9336
# Epoch 175/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.8841 - val_loss: 46.6184
# Epoch 176/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.6624 - val_loss: 43.8463
# Epoch 177/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.8366 - val_loss: 46.5541
# Epoch 178/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.5946 - val_loss: 43.9568
# Epoch 179/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.7631 - val_loss: 46.5278
# Epoch 180/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.5320 - val_loss: 43.8313
# Epoch 181/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.7144 - val_loss: 46.4256
# Epoch 182/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.4666 - val_loss: 43.9273
# Epoch 183/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.6391 - val_loss: 46.3775
# Epoch 184/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.4059 - val_loss: 43.7982
# Epoch 185/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.5892 - val_loss: 46.2645
# Epoch 186/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.3443 - val_loss: 43.8758
# Epoch 187/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.5166 - val_loss: 46.2131
# Epoch 188/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.2874 - val_loss: 43.7518
# Epoch 189/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.4679 - val_loss: 46.1106
# Epoch 190/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.2286 - val_loss: 43.7887
# Epoch 191/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.4005 - val_loss: 46.0509
# Epoch 192/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.1728 - val_loss: 43.6752
# Epoch 193/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.3502 - val_loss: 45.9475
# Epoch 194/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.1154 - val_loss: 43.6719
# Epoch 195/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.2865 - val_loss: 45.8642
# Epoch 196/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.0607 - val_loss: 43.5697
# Epoch 197/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.2340 - val_loss: 45.7502
# Epoch 198/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.0055 - val_loss: 43.5380
# Epoch 199/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.1727 - val_loss: 45.6509
# Epoch 200/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.9522 - val_loss: 43.4459
# Epoch 201/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.1185 - val_loss: 45.5363
# Epoch 202/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.8988 - val_loss: 43.3983
# Epoch 203/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.0589 - val_loss: 45.4316
# Epoch 204/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.8477 - val_loss: 43.3181
# Epoch 205/300
# 690/690 [==============================] - 2s 3ms/step - loss: 35.0053 - val_loss: 45.3230
# Epoch 206/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.7987 - val_loss: 43.2653
# Epoch 207/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.9497 - val_loss: 45.2213
# Epoch 208/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.7511 - val_loss: 43.1898
# Epoch 209/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.8972 - val_loss: 45.1155
# Epoch 210/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.7041 - val_loss: 43.1295
# Epoch 211/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.8439 - val_loss: 45.0140
# Epoch 212/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.6585 - val_loss: 43.0578
# Epoch 213/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.7931 - val_loss: 44.9116
# Epoch 214/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.6141 - val_loss: 42.9915
# Epoch 215/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.7434 - val_loss: 44.8112
# Epoch 216/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.5713 - val_loss: 42.9231
# Epoch 217/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.6953 - val_loss: 44.7106
# Epoch 218/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.5294 - val_loss: 42.8578
# Epoch 219/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.6477 - val_loss: 44.6110
# Epoch 220/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.4882 - val_loss: 42.7910
# Epoch 221/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.6013 - val_loss: 44.5119
# Epoch 222/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.4477 - val_loss: 42.7245
# Epoch 223/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.5557 - val_loss: 44.4137
# Epoch 224/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.4076 - val_loss: 42.6555
# Epoch 225/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.5112 - val_loss: 44.3154
# Epoch 226/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.3683 - val_loss: 42.5823
# Epoch 227/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.4685 - val_loss: 44.2158
# Epoch 228/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.3306 - val_loss: 42.5071
# Epoch 229/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.4281 - val_loss: 44.1156
# Epoch 230/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.2939 - val_loss: 42.4360
# Epoch 231/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.3885 - val_loss: 44.0165
# Epoch 232/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.2580 - val_loss: 42.3665
# Epoch 233/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.3497 - val_loss: 43.9177
# Epoch 234/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.2228 - val_loss: 42.2983
# Epoch 235/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.3118 - val_loss: 43.8195
# Epoch 236/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.1883 - val_loss: 42.2305
# Epoch 237/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.2746 - val_loss: 43.7211
# Epoch 238/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.1543 - val_loss: 42.1625
# Epoch 239/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.2382 - val_loss: 43.6224
# Epoch 240/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.1206 - val_loss: 42.0938
# Epoch 241/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.2023 - val_loss: 43.5229
# Epoch 242/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.0872 - val_loss: 42.0245
# Epoch 243/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.1669 - val_loss: 43.4229
# Epoch 244/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.0546 - val_loss: 41.9548
# Epoch 245/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.1333 - val_loss: 43.3233
# Epoch 246/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.0235 - val_loss: 41.8855
# Epoch 247/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.1006 - val_loss: 43.2248
# Epoch 248/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.9929 - val_loss: 41.8164
# Epoch 249/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.0684 - val_loss: 43.1269
# Epoch 250/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.9627 - val_loss: 41.7487
# Epoch 251/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.0367 - val_loss: 43.0302
# Epoch 252/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.9329 - val_loss: 41.6819
# Epoch 253/300
# 690/690 [==============================] - 2s 3ms/step - loss: 34.0055 - val_loss: 42.9350
# Epoch 254/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.9035 - val_loss: 41.6161
# Epoch 255/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.9748 - val_loss: 42.8416
# Epoch 256/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.8744 - val_loss: 41.5513
# Epoch 257/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.9444 - val_loss: 42.7497
# Epoch 258/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.8455 - val_loss: 41.4868
# Epoch 259/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.9140 - val_loss: 42.6583
# Epoch 260/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.8167 - val_loss: 41.4225
# Epoch 261/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.8849 - val_loss: 42.5669
# Epoch 262/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.7898 - val_loss: 41.3630
# Epoch 263/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.8563 - val_loss: 42.4779
# Epoch 264/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.7631 - val_loss: 41.2988
# Epoch 265/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.8284 - val_loss: 42.3897
# Epoch 266/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.7367 - val_loss: 41.2348
# Epoch 267/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.8008 - val_loss: 42.3024
# Epoch 268/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.7104 - val_loss: 41.1707
# Epoch 269/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.7735 - val_loss: 42.2155
# Epoch 270/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.6844 - val_loss: 41.1059
# Epoch 271/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.7464 - val_loss: 42.1288
# Epoch 272/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.6585 - val_loss: 41.0401
# Epoch 273/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.7194 - val_loss: 42.0420
# Epoch 274/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.6325 - val_loss: 40.9733
# Epoch 275/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.6924 - val_loss: 41.9546
# Epoch 276/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.6066 - val_loss: 40.9051
# Epoch 277/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.6659 - val_loss: 41.8654
# Epoch 278/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.5815 - val_loss: 40.8377
# Epoch 279/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.6399 - val_loss: 41.7767
# Epoch 280/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.5566 - val_loss: 40.7675
# Epoch 281/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.6140 - val_loss: 41.6886
# Epoch 282/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.5314 - val_loss: 40.6959
# Epoch 283/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.5881 - val_loss: 41.6002
# Epoch 284/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.5071 - val_loss: 40.6242
# Epoch 285/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.5637 - val_loss: 41.5128
# Epoch 286/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.4842 - val_loss: 40.5526
# Epoch 287/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.5401 - val_loss: 41.4269
# Epoch 288/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.4616 - val_loss: 40.4799
# Epoch 289/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.5168 - val_loss: 41.3419
# Epoch 290/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.4392 - val_loss: 40.4073
# Epoch 291/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.4937 - val_loss: 41.2578
# Epoch 292/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.4171 - val_loss: 40.3360
# Epoch 293/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.4708 - val_loss: 41.1749
# Epoch 294/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.3953 - val_loss: 40.2660
# Epoch 295/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.4481 - val_loss: 41.0933
# Epoch 296/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.3736 - val_loss: 40.1974
# Epoch 297/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.4255 - val_loss: 41.0131
# Epoch 298/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.3520 - val_loss: 40.1303
# Epoch 299/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.4029 - val_loss: 40.9341
# Epoch 300/300
# 690/690 [==============================] - 2s 3ms/step - loss: 33.3306 - val_loss: 40.0648

# %%
plt.plot(history_tech.history['loss'], label='train')
plt.plot(history_tech.history['val_loss'], label='test')
plt.legend()

# %%
plt.plot(np.arange(0, len(y_train)), y_train, 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test, marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
# y_test = sc.inverse_transform(y_test)
# y_pred = sc.inverse_transform(y_pred)
plt.plot(y_test, marker='.', label="true")
plt.plot(y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9990826679453672

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.02725051893119261

# %%
mean_squared_error(y_test,y_pred,squared=False)
# Out:
# 5.458681664955267

# %%
x_val=data_val.drop('Prediction',1)
y_val=data_val['Prediction']
x_val=sc.transform(x_val).reshape(x_val.shape[0],1,x_val.shape[1])
y_val_pred=model_tech.predict(x_val)
# Out:
# /tmp/ipykernel_3132/2328949661.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_val=data_val.drop('Prediction',1)

# %%
plt.plot(y_val.values, marker='.', label="true")
plt.plot(y_val_pred, 'r', marker='*',label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show()

# %%
r2_score(y_val,y_val_pred)
# Out:
# 0.8144103016725672

# %%
mean_absolute_percentage_error(y_val,y_val_pred)
# Out:
# 0.027686916947601833

# %%
mean_squared_error(y_val.values,y_val_pred,squared=False)
# Out:
# 15.158824560035852
