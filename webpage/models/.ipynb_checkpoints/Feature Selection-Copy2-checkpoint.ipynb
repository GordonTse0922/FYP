# %%
# Import the necessary libraries first
from sklearn.feature_selection import SelectKBest, RFE
from sklearn.feature_selection import chi2, r_regression
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler ,StandardScaler
import yfinance as yf
import talib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.layers import LSTM,Dropout, BatchNormalization, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras.models import Sequential
from keras.optimizer_v2.adam import Adam
from keras.regularizers import L1L2

# %%
data=yf.download('0005.hk',"2017-09-28","2021-09-24")
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2017-09-28  76.400002  77.099998  76.050003  76.199997  64.386986  22520013
# 2017-09-29  76.500000  76.900002  76.300003  76.550003  64.682732  16766252
# 2017-10-03  76.800003  77.449997  76.699997  77.449997  65.443192  24369212
# 2017-10-04  77.500000  77.949997  77.500000  77.849998  65.781197  21197563
# 2017-10-06  77.599998  77.800003  77.199997  77.349998  65.358719  23715110

# %%
data['Prediction']=data['Adj Close'].shift(-1)
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2017-09-28  76.400002  77.099998  76.050003  76.199997  64.386986  22520013
# 2017-09-29  76.500000  76.900002  76.300003  76.550003  64.682732  16766252
# 2017-10-03  76.800003  77.449997  76.699997  77.449997  65.443192  24369212
# 2017-10-04  77.500000  77.949997  77.500000  77.849998  65.781197  21197563
# 2017-10-06  77.599998  77.800003  77.199997  77.349998  65.358719  23715110
#
#             Prediction
# Date
# 2017-09-28   64.682732
# 2017-09-29   65.443192
# 2017-10-03   65.781197
# 2017-10-04   65.358719
# 2017-10-06   65.485458

# %%
data['H-L'] = data['High'] - data['Low']
data['O-C'] = data['Close'] - data['Open']
data["% Change"]=data["Close"].shift(1).pct_change()
data['3day MA'] = data['Close'].shift(1).rolling(window = 3).mean()
data['10day MA'] = data['Close'].shift(1).rolling(window = 10).mean()
data['30day MA'] = data['Close'].shift(1).rolling(window = 30).mean()
data['Std_dev']= data['Close'].shift(1).rolling(5).std()
data['RSI'] = talib.RSI(data['Close'].values, timeperiod = 9)
# data['Williams %R'] = talib.WILLR(data['High'].values, data['Low'].values, data['Close'].values, 7)
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2017-09-28  76.400002  77.099998  76.050003  76.199997  64.386986  22520013
# 2017-09-29  76.500000  76.900002  76.300003  76.550003  64.682732  16766252
# 2017-10-03  76.800003  77.449997  76.699997  77.449997  65.443192  24369212
# 2017-10-04  77.500000  77.949997  77.500000  77.849998  65.781197  21197563
# 2017-10-06  77.599998  77.800003  77.199997  77.349998  65.358719  23715110
#
#             Prediction       H-L       O-C  % Change    3day MA  10day MA  \
# Date
# 2017-09-28   64.682732  1.049995 -0.200005       NaN        NaN       NaN
# 2017-09-29   65.443192  0.599998  0.050003       NaN        NaN       NaN
# 2017-10-03   65.781197  0.750000  0.649994  0.004593        NaN       NaN
# 2017-10-04   65.358719  0.449997  0.349998  0.011757  76.733332       NaN
# 2017-10-06   65.485458  0.600006 -0.250000  0.005165  77.283333       NaN
#
#             30day MA  Std_dev  RSI
# Date
# 2017-09-28       NaN      NaN  NaN
# 2017-09-29       NaN      NaN  NaN
# 2017-10-03       NaN      NaN  NaN
# 2017-10-04       NaN      NaN  NaN
# 2017-10-06       NaN      NaN  NaN

# %%
data.dropna(inplace=True)

# %%
# Feature extraction
X=data.drop('Prediction',1)
Y=data['Prediction'].values.reshape(-1,1)
test = SelectKBest(score_func=r_regression, k=5)
fit = test.fit(X, Y)

# Summarize scores
np.set_printoptions(precision=3)
print(fit.scores_)

features = fit.transform(X)
# Summarize selected features
print(features[0:5,:])
# Out:
# [ 0.99   0.989  0.99   0.99   0.998 -0.328 -0.133  0.034  0.026  0.988
#   0.985  0.974 -0.102  0.128]
# [[75.9   76.25  75.6   75.65  64.567]
#  [75.2   75.45  75.05  75.15  64.14 ]
#  [75.15  75.3   75.05  75.1   64.098]
#  [75.5   75.7   75.25  75.35  64.311]
#  [75.35  75.65  75.1   75.25  64.226]]
# /home/gordon/anaconda3/envs/FYP/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cols = list(X.columns)
model = LinearRegression()
rfe = RFE(model)
fit = rfe.fit(X, Y)
temp = pd.Series(fit.support_,index = cols)
print("Num Features: %s" % (fit.n_features_))
print("Selected Features: %s" % (fit.support_))
print("Feature Ranking: %s" % (fit.ranking_))
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)
# Out:
# Num Features: 7
# Selected Features: [ True  True  True False  True False  True  True  True False False False
#  False False]
# Feature Ranking: [1 1 1 2 1 8 1 1 1 4 5 7 3 6]
# Index(['Open', 'High', 'Low', 'Adj Close', 'H-L', 'O-C', '% Change'], dtype='object')

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X,Y)
# Out:
# /home/gordon/anaconda3/envs/FYP/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:156: LinAlgWarning: Ill-conditioned matrix (rcond=2.3464e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Ridge()

# %%
#no of features
nof_list=np.arange(1,16)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,n_features_to_select=nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 14
# Score with 14 features: 0.996893

# %%
cols = list(X.columns)
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, n_features_to_select=6)             
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,Y)  
#Fitting the data to model
model.fit(X_rfe,Y)              
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)
# Out:
# Index(['High', 'Low', 'Adj Close', 'H-L', 'O-C', '% Change'], dtype='object')

# %%
reg = LassoCV()
reg.fit(X, Y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,Y))
coef = pd.Series(reg.coef_, index = X.columns)
# Out:
# /home/gordon/anaconda3/envs/FYP/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:1572: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best alpha using built-in LassoCV: 79552.562792
# Best score using built-in LassoCV: 0.107440

# %%
X.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'H-L', 'O-C',
#        '% Change', '3day MA', '10day MA', '30day MA', 'Std_dev', 'RSI'],
#       dtype='object')

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 1 variables and eliminated the other 13 variables

# %%
imp_coef = coef.sort_values()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
# Out:
# Text(0.5, 1.0, 'Feature importance using Lasso Model')

# %%
def correlation(dataset,threshold):
    col_corr=set() # set will contains unique values.
    corr_matrix=dataset.corr() #finding the correlation between columns.
    for i in range(len(corr_matrix.columns)): #number of columns
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold: #checking the correlation between columns.
                colName=corr_matrix.columns[i] #getting the column name
                col_corr.add(colName) #adding the correlated column name heigher than threshold value.
    return col_corr #returning set of column names
col=correlation(X,0.8)
print('Correlated columns:',col)
# Out:
# Correlated columns: {'Close', '10day MA', 'Adj Close', '3day MA', '30day MA', 'Low', 'High'}

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
#I am going to use RandomForestRegressor algoritham as an estimator. Your can select other regression alogritham as well.
from sklearn.ensemble import RandomForestRegressor
#k_features=10 (It will get top 10 features best suited for prediction)
#forward=True (Forward feature selection model)
#verbose=2 (It will show details output as shown below.)
#cv=5 (Kfold cross valiation: it will split the training set in 5 set and 4 will be using for training the model and 1 will using as validation)
#n_jobs=-1 (Number of cores it will use for execution.-1 means it will use all the cores of CPU for execution.)
#scoring='r2'(R-squared is a statistical measure of how close the data are to the fitted regression line)
forward_model=sfs(RandomForestRegressor(),k_features=10,forward=True,verbose=2,cv=5,n_jobs=-1,scoring='r2')
forward_model.fit(X_train,y_train.ravel())
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    0.9s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    1.1s finished
#
# [2021-12-25 23:40:04] Features: 1/10 -- score: 0.9940467138606148[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  13 | elapsed:    0.8s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    0.9s finished
#
# [2021-12-25 23:40:05] Features: 2/10 -- score: 0.995192535410083[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  12 | elapsed:    0.7s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    0.7s finished
#
# [2021-12-25 23:40:06] Features: 3/10 -- score: 0.9954064578060244[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  11 | elapsed:    0.8s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    0.8s finished
#
# [2021-12-25 23:40:07] Features: 4/10 -- score: 0.9954594522467268[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    0.8s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.9s finished
#
# [2021-12-25 23:40:07] Features: 5/10 -- score: 0.9954724578861877[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   9 | elapsed:    0.7s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done   7 out of   9 | elapsed:    0.9s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    0.9s finished
#
# [2021-12-25 23:40:08] Features: 6/10 -- score: 0.9954693530796781[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    1.0s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.0s finished
#
# [2021-12-25 23:40:09] Features: 7/10 -- score: 0.9954250960999191[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    0.8s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    0.8s finished
#
# [2021-12-25 23:40:10] Features: 8/10 -- score: 0.9954055607951426[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    0.8s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    0.8s finished
#
# [2021-12-25 23:40:11] Features: 9/10 -- score: 0.9954016091029996[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:    0.9s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.9s finished
#
# [2021-12-25 23:40:12] Features: 10/10 -- score: 0.995370489029248
# SequentialFeatureSelector(estimator=RandomForestRegressor(), k_features=10,
#                           n_jobs=-1, scoring='r2', verbose=2)

# %%
#Get the selected feature index.
forward_model.k_feature_idx_
# Out:
# (0, 2, 3, 4, 7, 9, 10, 11, 12, 13)

# %%
#Get the column name for the selected feature.
forward_model.k_feature_names_
# Out:
# ('Open',
#  'Low',
#  'Close',
#  'Adj Close',
#  'O-C',
#  '3day MA',
#  '10day MA',
#  '30day MA',
#  'Std_dev',
#  'RSI')

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.ensemble import RandomForestRegressor
#k_features=10 (It will get top 10 features best suited for prediction)
#forward=False (Backward feature selection model)
#verbose=2 (It will show details output as shown below.)
#cv=5 (Kfold cross valiation: it will split the training set in 5 set and 4 will be using for training the model and 1 will using as validation)
#n_jobs=-1 (Number of cores it will use for execution.-1 means it will use all the cores of CPU for execution.)
#scoring='r2'(R-squared is a statistical measure of how close the data are to the fitted regression line)
backwardModel=sfs(RandomForestRegressor(),k_features=10,forward=False,verbose=2,cv=5,n_jobs=-1,scoring='r2')
#We will convert our training data into numpy array. If we will not convert it, model is not able to read some of the column names. 
backwardModel.fit(np.array(X_train),y_train.ravel())
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    1.4s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    1.4s finished
#
# [2021-12-25 23:40:14] Features: 13/10 -- score: 0.9952371557824584[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  13 | elapsed:    1.1s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    1.3s finished
#
# [2021-12-25 23:40:16] Features: 12/10 -- score: 0.9952829749728117[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  12 | elapsed:    1.1s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    1.3s finished
#
# [2021-12-25 23:40:17] Features: 11/10 -- score: 0.9953583175428792[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  11 | elapsed:    1.0s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    1.1s finished
#
# [2021-12-25 23:40:18] Features: 10/10 -- score: 0.9953786785239057
# SequentialFeatureSelector(estimator=RandomForestRegressor(), forward=False,
#                           k_features=10, n_jobs=-1, scoring='r2', verbose=2)

# %%
#Get the selected feature index.
backwardModel.k_feature_idx_
# Out:
# (0, 2, 3, 4, 6, 7, 10, 11, 12, 13)

# %%
#Get the column name for the selected feature.
X_train.columns[list(backwardModel.k_feature_idx_)]
# Out:
# Index(['Open', 'Low', 'Close', 'Adj Close', 'H-L', 'O-C', '10day MA',
#        '30day MA', 'Std_dev', 'RSI'],
#       dtype='object')

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as efs
#min_features=1 (minimum number of feature)
#max_features=5 (maximum number of feature)
#n_jobs=-1 (Number of cores it will use for execution.-1 means it will use all the cores of CPU for execution.)
#scoring='r2'(R-squared is a statistical measure of how close the data are to the fitted regression line)
emodel=efs(RandomForestRegressor(),min_features=1,max_features=5,scoring='r2',n_jobs=-1)
#Lets take only 10 features which we got from backward feature selection.
miniData=X_train[X_train.columns[list(backwardModel.k_feature_idx_)]]

emodel.fit(np.array(miniData),y_train.ravel())
#If you see below the model creates 637 feature combinations from 10 features.Thats why its computationally very expensive.
# Out:
# Features: 637/637
# ExhaustiveFeatureSelector(estimator=RandomForestRegressor(), max_features=5,
#                           n_jobs=-1, scoring='r2')

# %%
#Get the selected feature index.
emodel.best_idx_
# Out:
# (3, 7, 8, 9)

# %%
#Get the column name for the selected feature.
miniData.columns[list(emodel.best_idx_)]
# Out:
# Index(['Adj Close', '30day MA', 'Std_dev', 'RSI'], dtype='object')

# %%
emodel=efs(RandomForestRegressor(),min_features=1,max_features=7,scoring='r2',n_jobs=-1)
#Lets take only 10 features which we got from backward feature selection.
miniData_forward=X_train[X_train.columns[list(forward_model.k_feature_idx_)]]

emodel.fit(np.array(miniData_forward),y_train.ravel())
#If you see below the model creates 637 feature comb
# Out:
# Features: 967/967
# ExhaustiveFeatureSelector(estimator=RandomForestRegressor(), max_features=7,
#                           n_jobs=-1, scoring='r2')

# %%
#Get the selected feature index.
emodel.best_idx_
# Out:
# (1, 3, 4, 6, 7, 8)

# %%
#Get the column name for the selected feature.
miniData_forward.columns[list(emodel.best_idx_)]
# Out:
# Index(['Low', 'Adj Close', 'O-C', '10day MA', '30day MA', 'Std_dev'], dtype='object')

# %%
data_selected=data[miniData_forward.columns[list(emodel.best_idx_)]]

# %%
data_selected['Prediction']=data['Prediction']
data_selected=data_selected[:-5]
data_unseen=data_selected[-5:]
# Out:
# <ipython-input-29-b909f1970ec0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_selected['Prediction']=data['Prediction']

# %%
# Build the LSTM model
adam = Adam(lr=0.001)
reg=L1L2(l1=0.00, l2=0.1)
BATCH_SIZE=1
X=data_selected.drop('Prediction',1).values
sc = MinMaxScaler(feature_range=(-1,1))
sc_y = MinMaxScaler(feature_range=(-1,1))
X=sc.fit_transform(X)
X = X.reshape(X.shape[0], 1, X.shape[1])
y=data_selected['Prediction'].values.reshape(-1,1)
y=sc_y.fit_transform(y)
print(y)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)
model = Sequential()
model.add(LSTM(128, input_shape=(1, X_train.shape[2]),
                        dropout=0.0, recurrent_dropout=0.0,
                        stateful=False, return_sequences=True,
                        kernel_initializer='random_uniform',
                        bias_regularizer=reg))
model.add(Dropout(0.7))

model.add(LSTM(64, dropout=0.0))
model.add(Dropout(0.5))
    
model.add(Dense(32))
model.add(Dense(1))
# model.add(LSTM(7,input_shape=(1, X.shape[2]),bias_regularizer=reg,dropout=0.4,unit_forget_bias=False,return_sequences=True))
# model.add(Dense(1))
model.compile(
  loss="mean_squared_error",
  optimizer=adam
)
# Out:
# /home/gordon/anaconda3/envs/FYP/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:357: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [[ 0.604]
#  [ 0.602]
#  [ 0.611]
#  [ 0.608]
#  [ 0.602]
#  [ 0.621]
#  [ 0.67 ]
#  [ 0.641]
#  [ 0.646]
#  [ 0.665]
#  [ 0.67 ]
#  [ 0.709]
#  [ 0.709]
#  [ 0.706]
#  [ 0.698]
#  [ 0.685]
#  [ 0.639]
#  [ 0.645]
#  [ 0.665]
#  [ 0.72 ]
#  [ 0.722]
#  [ 0.782]
#  [ 0.767]
#  [ 0.73 ]
#  [ 0.741]
#  [ 0.759]
#  [ 0.757]
#  [ 0.767]
#  [ 0.783]
#  [ 0.776]
#  [ 0.783]
#  [ 0.782]
#  [ 0.832]
#  [ 0.819]
#  [ 0.802]
#  [ 0.813]
#  [ 0.802]
#  [ 0.819]
#  [ 0.861]
#  [ 0.933]
#  [ 0.92 ]
#  [ 0.935]
#  [ 0.961]
#  [ 0.97 ]
#  [ 0.985]
#  [ 0.983]
#  [ 0.969]
#  [ 0.994]
#  [ 1.   ]
#  [ 0.987]
#  [ 0.994]
#  [ 0.97 ]
#  [ 0.935]
#  [ 0.939]
#  [ 0.933]
#  [ 0.92 ]
#  [ 0.889]
#  [ 0.787]
#  [ 0.783]
#  [ 0.802]
#  [ 0.776]
#  [ 0.761]
#  [ 0.776]
#  [ 0.854]
#  [ 0.915]
#  [ 0.819]
#  [ 0.843]
#  [ 0.827]
#  [ 0.831]
#  [ 0.827]
#  [ 0.792]
#  [ 0.769]
#  [ 0.765]
#  [ 0.739]
#  [ 0.691]
#  [ 0.716]
#  [ 0.691]
#  [ 0.705]
#  [ 0.716]
#  [ 0.746]
#  [ 0.735]
#  [ 0.712]
#  [ 0.708]
#  [ 0.729]
#  [ 0.737]
#  [ 0.729]
#  [ 0.725]
#  [ 0.705]
#  [ 0.642]
#  [ 0.656]
#  [ 0.659]
#  [ 0.618]
#  [ 0.618]
#  [ 0.601]
#  [ 0.557]
#  [ 0.582]
#  [ 0.625]
#  [ 0.644]
#  [ 0.665]
#  [ 0.671]
#  [ 0.705]
#  [ 0.691]
#  [ 0.673]
#  [ 0.68 ]
#  [ 0.705]
#  [ 0.724]
#  [ 0.731]
#  [ 0.756]
#  [ 0.75 ]
#  [ 0.733]
#  [ 0.746]
#  [ 0.795]
#  [ 0.786]
#  [ 0.758]
#  [ 0.654]
#  [ 0.659]
#  [ 0.69 ]
#  [ 0.697]
#  [ 0.735]
#  [ 0.752]
#  [ 0.784]
#  [ 0.767]
#  [ 0.771]
#  [ 0.761]
#  [ 0.77 ]
#  [ 0.791]
#  [ 0.78 ]
#  [ 0.782]
#  [ 0.763]
#  [ 0.755]
#  [ 0.719]
#  [ 0.682]
#  [ 0.721]
#  [ 0.721]
#  [ 0.745]
#  [ 0.742]
#  [ 0.742]
#  [ 0.77 ]
#  [ 0.743]
#  [ 0.759]
#  [ 0.751]
#  [ 0.747]
#  [ 0.738]
#  [ 0.736]
#  [ 0.669]
#  [ 0.692]
#  [ 0.661]
#  [ 0.661]
#  [ 0.637]
#  [ 0.627]
#  [ 0.589]
#  [ 0.604]
#  [ 0.631]
#  [ 0.583]
#  [ 0.577]
#  [ 0.589]
#  [ 0.593]
#  [ 0.621]
#  [ 0.642]
#  [ 0.606]
#  [ 0.612]
#  [ 0.619]
#  [ 0.619]
#  [ 0.614]
#  [ 0.593]
#  [ 0.616]
#  [ 0.616]
#  [ 0.623]
#  [ 0.671]
#  [ 0.686]
#  [ 0.675]
#  [ 0.679]
#  [ 0.673]
#  [ 0.669]
#  [ 0.656]
#  [ 0.6  ]
#  [ 0.581]
#  [ 0.595]
#  [ 0.602]
#  [ 0.604]
#  [ 0.621]
#  [ 0.593]
#  [ 0.574]
#  [ 0.583]
#  [ 0.553]
#  [ 0.529]
#  [ 0.527]
#  [ 0.544]
#  [ 0.535]
#  [ 0.525]
#  [ 0.51 ]
#  [ 0.5  ]
#  [ 0.527]
#  [ 0.531]
#  [ 0.529]
#  [ 0.504]
#  [ 0.479]
#  [ 0.459]
#  [ 0.477]
#  [ 0.438]
#  [ 0.427]
#  [ 0.415]
#  [ 0.382]
#  [ 0.38 ]
#  [ 0.394]
#  [ 0.429]
#  [ 0.442]
#  [ 0.429]
#  [ 0.436]
#  [ 0.444]
#  [ 0.471]
#  [ 0.513]
#  [ 0.483]
#  [ 0.51 ]
#  [ 0.5  ]
#  [ 0.492]
#  [ 0.436]
#  [ 0.444]
#  [ 0.448]
#  [ 0.463]
#  [ 0.448]
#  [ 0.432]
#  [ 0.45 ]
#  [ 0.4  ]
#  [ 0.4  ]
#  [ 0.35 ]
#  [ 0.351]
#  [ 0.342]
#  [ 0.314]
#  [ 0.334]
#  [ 0.258]
#  [ 0.227]
#  [ 0.205]
#  [ 0.184]
#  [ 0.303]
#  [ 0.287]
#  [ 0.336]
#  [ 0.361]
#  [ 0.414]
#  [ 0.379]
#  [ 0.4  ]
#  [ 0.396]
#  [ 0.394]
#  [ 0.346]
#  [ 0.361]
#  [ 0.35 ]
#  [ 0.369]
#  [ 0.398]
#  [ 0.406]
#  [ 0.4  ]
#  [ 0.363]
#  [ 0.371]
#  [ 0.396]
#  [ 0.394]
#  [ 0.432]
#  [ 0.441]
#  [ 0.463]
#  [ 0.424]
#  [ 0.433]
#  [ 0.484]
#  [ 0.48 ]
#  [ 0.41 ]
#  [ 0.357]
#  [ 0.309]
#  [ 0.31 ]
#  [ 0.295]
#  [ 0.32 ]
#  [ 0.367]
#  [ 0.324]
#  [ 0.33 ]
#  [ 0.312]
#  [ 0.324]
#  [ 0.303]
#  [ 0.342]
#  [ 0.326]
#  [ 0.32 ]
#  [ 0.31 ]
#  [ 0.351]
#  [ 0.293]
#  [ 0.291]
#  [ 0.334]
#  [ 0.355]
#  [ 0.35 ]
#  [ 0.379]
#  [ 0.351]
#  [ 0.375]
#  [ 0.342]
#  [ 0.363]
#  [ 0.365]
#  [ 0.365]
#  [ 0.373]
#  [ 0.373]
#  [ 0.363]
#  [ 0.357]
#  [ 0.371]
#  [ 0.394]
#  [ 0.392]
#  [ 0.396]
#  [ 0.41 ]
#  [ 0.426]
#  [ 0.402]
#  [ 0.396]
#  [ 0.392]
#  [ 0.398]
#  [ 0.408]
#  [ 0.441]
#  [ 0.445]
#  [ 0.412]
#  [ 0.465]
#  [ 0.404]
#  [ 0.4  ]
#  [ 0.42 ]
#  [ 0.4  ]
#  [ 0.392]
#  [ 0.382]
#  [ 0.388]
#  [ 0.39 ]
#  [ 0.392]
#  [ 0.392]
#  [ 0.398]
#  [ 0.412]
#  [ 0.418]
#  [ 0.394]
#  [ 0.402]
#  [ 0.418]
#  [ 0.4  ]
#  [ 0.41 ]
#  [ 0.418]
#  [ 0.428]
#  [ 0.438]
#  [ 0.426]
#  [ 0.416]
#  [ 0.414]
#  [ 0.372]
#  [ 0.38 ]
#  [ 0.378]
#  [ 0.372]
#  [ 0.38 ]
#  [ 0.414]
#  [ 0.442]
#  [ 0.48 ]
#  [ 0.484]
#  [ 0.492]
#  [ 0.504]
#  [ 0.502]
#  [ 0.488]
#  [ 0.5  ]
#  [ 0.508]
#  [ 0.528]
#  [ 0.538]
#  [ 0.528]
#  [ 0.532]
#  [ 0.512]
#  [ 0.5  ]
#  [ 0.504]
#  [ 0.522]
#  [ 0.532]
#  [ 0.554]
#  [ 0.612]
#  [ 0.548]
#  [ 0.572]
#  [ 0.522]
#  [ 0.482]
#  [ 0.5  ]
#  [ 0.476]
#  [ 0.492]
#  [ 0.5  ]
#  [ 0.477]
#  [ 0.463]
#  [ 0.459]
#  [ 0.467]
#  [ 0.465]
#  [ 0.471]
#  [ 0.473]
#  [ 0.473]
#  [ 0.449]
#  [ 0.435]
#  [ 0.417]
#  [ 0.386]
#  [ 0.402]
#  [ 0.425]
#  [ 0.427]
#  [ 0.465]
#  [ 0.473]
#  [ 0.443]
#  [ 0.427]
#  [ 0.406]
#  [ 0.423]
#  [ 0.417]
#  [ 0.461]
#  [ 0.463]
#  [ 0.441]
#  [ 0.429]
#  [ 0.419]
#  [ 0.421]
#  [ 0.457]
#  [ 0.447]
#  [ 0.469]
#  [ 0.475]
#  [ 0.479]
#  [ 0.473]
#  [ 0.455]
#  [ 0.451]
#  [ 0.451]
#  [ 0.463]
#  [ 0.463]
#  [ 0.455]
#  [ 0.459]
#  [ 0.455]
#  [ 0.445]
#  [ 0.457]
#  [ 0.433]
#  [ 0.445]
#  [ 0.443]
#  [ 0.441]
#  [ 0.425]
#  [ 0.411]
#  [ 0.406]
#  [ 0.388]
#  [ 0.376]
#  [ 0.34 ]
#  [ 0.293]
#  [ 0.265]
#  [ 0.261]
#  [ 0.261]
#  [ 0.252]
#  [ 0.214]
#  [ 0.159]
#  [ 0.171]
#  [ 0.154]
#  [ 0.142]
#  [ 0.202]
#  [ 0.179]
#  [ 0.171]
#  [ 0.156]
#  [ 0.167]
#  [ 0.13 ]
#  [ 0.123]
#  [ 0.123]
#  [ 0.128]
#  [ 0.134]
#  [ 0.123]
#  [ 0.119]
#  [ 0.199]
#  [ 0.183]
#  [ 0.199]
#  [ 0.212]
#  [ 0.241]
#  [ 0.317]
#  [ 0.296]
#  [ 0.314]
#  [ 0.31 ]
#  [ 0.275]
#  [ 0.28 ]
#  [ 0.273]
#  [ 0.286]
#  [ 0.265]
#  [ 0.284]
#  [ 0.261]
#  [ 0.275]
#  [ 0.282]
#  [ 0.302]
#  [ 0.271]
#  [ 0.238]
#  [ 0.214]
#  [ 0.222]
#  [ 0.208]
#  [ 0.213]
#  [ 0.276]
#  [ 0.317]
#  [ 0.317]
#  [ 0.324]
#  [ 0.357]
#  [ 0.357]
#  [ 0.367]
#  [ 0.378]
#  [ 0.369]
#  [ 0.396]
#  [ 0.388]
#  [ 0.33 ]
#  [ 0.296]
#  [ 0.286]
#  [ 0.299]
#  [ 0.303]
#  [ 0.324]
#  [ 0.324]
#  [ 0.334]
#  [ 0.328]
#  [ 0.321]
#  [ 0.278]
#  [ 0.28 ]
#  [ 0.247]
#  [ 0.232]
#  [ 0.224]
#  [ 0.244]
#  [ 0.272]
#  [ 0.257]
#  [ 0.232]
#  [ 0.242]
#  [ 0.278]
#  [ 0.269]
#  [ 0.276]
#  [ 0.269]
#  [ 0.24 ]
#  [ 0.253]
#  [ 0.234]
#  [ 0.194]
#  [ 0.203]
#  [ 0.213]
#  [ 0.224]
#  [ 0.219]
#  [ 0.238]
#  [ 0.261]
#  [ 0.334]
#  [ 0.319]
#  [ 0.349]
#  [ 0.344]
#  [ 0.353]
#  [ 0.351]
#  [ 0.342]
#  [ 0.34 ]
#  [ 0.355]
#  [ 0.357]
#  [ 0.355]
#  [ 0.357]
#  [ 0.336]
#  [ 0.319]
#  [ 0.315]
#  [ 0.29 ]
#  [ 0.313]
#  [ 0.313]
#  [ 0.317]
#  [ 0.309]
#  [ 0.311]
#  [ 0.315]
#  [ 0.326]
#  [ 0.317]
#  [ 0.284]
#  [ 0.29 ]
#  [ 0.276]
#  [ 0.267]
#  [ 0.217]
#  [ 0.182]
#  [ 0.188]
#  [ 0.174]
#  [ 0.178]
#  [ 0.186]
#  [ 0.232]
#  [ 0.228]
#  [ 0.24 ]
#  [ 0.263]
#  [ 0.292]
#  [ 0.296]
#  [ 0.305]
#  [ 0.294]
#  [ 0.226]
#  [ 0.194]
#  [ 0.186]
#  [ 0.18 ]
#  [ 0.174]
#  [ 0.155]
#  [ 0.136]
#  [ 0.095]
#  [ 0.043]
#  [ 0.028]
#  [ 0.018]
#  [-0.033]
#  [-0.014]
#  [-0.062]
#  [-0.141]
#  [-0.135]
#  [-0.145]
#  [-0.229]
#  [-0.269]
#  [-0.348]
#  [-0.3  ]
#  [-0.317]
#  [-0.315]
#  [-0.214]
#  [-0.331]
#  [-0.294]
#  [-0.244]
#  [-0.269]
#  [-0.281]
#  [-0.319]
#  [-0.333]
#  [-0.509]
#  [-0.553]
#  [-0.595]
#  [-0.551]
#  [-0.501]
#  [-0.511]
#  [-0.465]
#  [-0.446]
#  [-0.482]
#  [-0.519]
#  [-0.528]
#  [-0.505]
#  [-0.542]
#  [-0.555]
#  [-0.561]
#  [-0.559]
#  [-0.528]
#  [-0.509]
#  [-0.496]
#  [-0.565]
#  [-0.549]
#  [-0.549]
#  [-0.555]
#  [-0.526]
#  [-0.505]
#  [-0.536]
#  [-0.553]
#  [-0.582]
#  [-0.586]
#  [-0.582]
#  [-0.53 ]
#  [-0.572]
#  [-0.57 ]
#  [-0.68 ]
#  [-0.687]
#  [-0.636]
#  [-0.618]
#  [-0.632]
#  [-0.68 ]
#  [-0.649]
#  [-0.624]
#  [-0.584]
#  [-0.555]
#  [-0.486]
#  [-0.465]
#  [-0.492]
#  [-0.517]
#  [-0.597]
#  [-0.62 ]
#  [-0.653]
#  [-0.616]
#  [-0.603]
#  [-0.628]
#  [-0.618]
#  [-0.645]
#  [-0.613]
#  [-0.632]
#  [-0.645]
#  [-0.672]
#  [-0.666]
#  [-0.62 ]
#  [-0.613]
#  [-0.536]
#  [-0.563]
#  [-0.632]
#  [-0.628]
#  [-0.657]
#  [-0.622]
#  [-0.639]
#  [-0.624]
#  [-0.624]
#  [-0.634]
#  [-0.649]
#  [-0.611]
#  [-0.649]
#  [-0.651]
#  [-0.674]
#  [-0.701]
#  [-0.724]
#  [-0.685]
#  [-0.689]
#  [-0.718]
#  [-0.783]
#  [-0.772]
#  [-0.76 ]
#  [-0.779]
#  [-0.808]
#  [-0.795]
#  [-0.753]
#  [-0.685]
#  [-0.699]
#  [-0.728]
#  [-0.733]
#  [-0.747]
#  [-0.751]
#  [-0.772]
#  [-0.772]
#  [-0.762]
#  [-0.743]
#  [-0.76 ]
#  [-0.787]
#  [-0.758]
#  [-0.766]
#  [-0.779]
#  [-0.793]
#  [-0.781]
#  [-0.795]
#  [-0.806]
#  [-0.799]
#  [-0.812]
#  [-0.824]
#  [-0.831]
#  [-0.833]
#  [-0.839]
#  [-0.852]
#  [-0.887]
#  [-0.885]
#  [-0.954]
#  [-0.979]
#  [-0.977]
#  [-0.983]
#  [-1.   ]
#  [-0.891]
#  [-0.925]
#  [-0.933]
#  [-0.883]
#  [-0.881]
#  [-0.86 ]
#  [-0.866]
#  [-0.864]
#  [-0.864]
#  [-0.904]
#  [-0.929]
#  [-0.919]
#  [-0.887]
#  [-0.891]
#  [-0.881]
#  [-0.873]
#  [-0.831]
#  [-0.766]
#  [-0.814]
#  [-0.829]
#  [-0.837]
#  [-0.808]
#  [-0.766]
#  [-0.766]
#  [-0.751]
#  [-0.728]
#  [-0.722]
#  [-0.603]
#  [-0.538]
#  [-0.576]
#  [-0.622]
#  [-0.557]
#  [-0.538]
#  [-0.54 ]
#  [-0.545]
#  [-0.553]
#  [-0.534]
#  [-0.517]
#  [-0.409]
#  [-0.423]
#  [-0.423]
#  [-0.444]
#  [-0.465]
#  [-0.402]
#  [-0.365]
#  [-0.35 ]
#  [-0.386]
#  [-0.45 ]
#  [-0.434]
#  [-0.428]
#  [-0.438]
#  [-0.45 ]
#  [-0.465]
#  [-0.453]
#  [-0.436]
#  [-0.459]
#  [-0.528]
#  [-0.53 ]
#  [-0.526]
#  [-0.499]
#  [-0.507]
#  [-0.496]
#  [-0.482]
#  [-0.48 ]
#  [-0.488]
#  [-0.501]
#  [-0.444]
#  [-0.365]
#  [-0.365]
#  [-0.382]
#  [-0.371]
#  [-0.392]
#  [-0.382]
#  [-0.384]
#  [-0.421]
#  [-0.348]
#  [-0.371]
#  [-0.325]
#  [-0.373]
#  [-0.39 ]
#  [-0.415]
#  [-0.392]
#  [-0.442]
#  [-0.467]
#  [-0.476]
#  [-0.467]
#  [-0.45 ]
#  [-0.465]
#  [-0.436]
#  [-0.45 ]
#  [-0.436]
#  [-0.398]
#  [-0.396]
#  [-0.267]
#  [-0.254]
#  [-0.239]
#  [-0.275]
#  [-0.235]
#  [-0.227]
#  [-0.252]
#  [-0.187]
#  [-0.202]
#  [-0.252]
#  [-0.296]
#  [-0.246]
#  [-0.233]
#  [-0.252]
#  [-0.183]
#  [-0.141]
#  [-0.183]
#  [-0.17 ]
#  [-0.219]
#  [-0.187]
#  [-0.217]
#  [-0.219]
#  [-0.174]
#  [-0.174]
#  [-0.208]
#  [-0.236]
#  [-0.279]
#  [-0.262]
#  [-0.257]
#  [-0.247]
#  [-0.232]
#  [-0.23 ]
#  [-0.236]
#  [-0.212]
#  [-0.172]
#  [-0.185]
#  [-0.217]
#  [-0.208]
#  [-0.202]
#  [-0.223]
#  [-0.242]
#  [-0.208]
#  [-0.204]
#  [-0.242]
#  [-0.257]
#  [-0.259]
#  [-0.247]
#  [-0.208]
#  [-0.146]
#  [-0.11 ]
#  [-0.086]
#  [-0.152]
#  [-0.116]
#  [-0.105]
#  [-0.073]
#  [-0.075]
#  [-0.073]
#  [-0.107]
#  [-0.125]
#  [-0.131]
#  [-0.09 ]
#  [-0.099]
#  [-0.071]
#  [-0.103]
#  [-0.099]
#  [-0.084]
#  [-0.071]
#  [-0.075]
#  [-0.082]
#  [-0.002]
#  [-0.067]
#  [-0.047]
#  [-0.073]
#  [-0.088]
#  [-0.099]
#  [-0.092]
#  [-0.084]
#  [-0.105]
#  [-0.137]
#  [-0.14 ]
#  [-0.15 ]
#  [-0.118]
#  [-0.11 ]
#  [-0.157]
#  [-0.227]
#  [-0.219]
#  [-0.206]
#  [-0.212]
#  [-0.204]
#  [-0.212]
#  [-0.24 ]
#  [-0.257]
#  [-0.257]
#  [-0.244]
#  [-0.24 ]
#  [-0.268]
#  [-0.296]
#  [-0.313]
#  [-0.298]
#  [-0.249]
#  [-0.279]
#  [-0.287]
#  [-0.304]
#  [-0.347]
#  [-0.377]
#  [-0.364]
#  [-0.324]
#  [-0.339]
#  [-0.364]
#  [-0.332]
#  [-0.347]
#  [-0.341]
#  [-0.334]
#  [-0.317]
#  [-0.341]
#  [-0.33 ]
#  [-0.324]
#  [-0.328]
#  [-0.302]
#  [-0.302]
#  [-0.292]
#  [-0.281]
#  [-0.285]
#  [-0.279]
#  [-0.3  ]
#  [-0.319]
#  [-0.341]
#  [-0.354]
#  [-0.339]
#  [-0.367]
#  [-0.357]
#  [-0.35 ]
#  [-0.357]
#  [-0.372]
#  [-0.38 ]
#  [-0.365]
#  [-0.385]
#  [-0.38 ]
#  [-0.383]
#  [-0.4  ]
#  [-0.424]
#  [-0.426]
#  [-0.404]
#  [-0.413]
#  [-0.435]
#  [-0.439]]

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 1, 128)            69120
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 64)                49408
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 120,641
# Trainable params: 120,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Fit model with history to check for overfitting
es = EarlyStopping(monitor='val_loss', mode='min',patience=3)
history = model.fit(X_train,y_train,epochs=1200,batch_size=BATCH_SIZE,validation_data=(X_test,y_test),shuffle=False, callbacks=[es])
# Out:
# Epoch 1/1200
# 662/662 [==============================] - 3s 3ms/step - loss: 9.4638 - val_loss: 2.5618
# Epoch 2/1200
# 662/662 [==============================] - 1s 2ms/step - loss: 1.6816 - val_loss: 0.2436
# Epoch 3/1200
# 662/662 [==============================] - 1s 2ms/step - loss: 0.1513 - val_loss: 0.0081
# Epoch 4/1200
# 662/662 [==============================] - 1s 2ms/step - loss: 0.0205 - val_loss: 0.0040
# Epoch 5/1200
# 662/662 [==============================] - 1s 2ms/step - loss: 0.0178 - val_loss: 0.0104
# Epoch 6/1200
# 662/662 [==============================] - 1s 2ms/step - loss: 0.0195 - val_loss: 0.0048
# Epoch 7/1200
# 662/662 [==============================] - 1s 2ms/step - loss: 0.0165 - val_loss: 0.0021
# Epoch 8/1200
# 662/662 [==============================] - 1s 2ms/step - loss: 0.0184 - val_loss: 0.0060
# Epoch 9/1200
# 662/662 [==============================] - 1s 2ms/step - loss: 0.0185 - val_loss: 0.0040
# Epoch 10/1200
# 662/662 [==============================] - 1s 2ms/step - loss: 0.0139 - val_loss: 0.0028

# %%
y_pred = model.predict(X_test)

# %%
y_test=sc_y.inverse_transform(y_test)
y_pred=sc_y.inverse_transform(y_pred)
y_pred.shape
# Out:
# (285, 1)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
plt.plot(np.arange(0, len(y_train)), y_train, 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test, marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
plt.plot(y_test, marker='.', label="true")
plt.plot(y_pred, 'r',marker='*', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
print(y_pred)
# Out:
# [[47.152]
#  [49.94 ]
#  [60.64 ]
#  [60.322]
#  [55.415]
#  [31.762]
#  [45.217]
#  [34.781]
#  [68.039]
#  [69.652]
#  [46.005]
#  [43.506]
#  [46.046]
#  [55.445]
#  [57.519]
#  [62.873]
#  [34.933]
#  [61.363]
#  [38.964]
#  [60.414]
#  [47.289]
#  [61.348]
#  [40.358]
#  [60.996]
#  [67.663]
#  [49.377]
#  [53.162]
#  [59.789]
#  [59.963]
#  [50.588]
#  [36.36 ]
#  [40.286]
#  [57.679]
#  [44.207]
#  [67.408]
#  [55.778]
#  [60.562]
#  [61.734]
#  [61.774]
#  [32.675]
#  [59.72 ]
#  [31.275]
#  [59.308]
#  [53.14 ]
#  [61.843]
#  [60.76 ]
#  [62.595]
#  [59.404]
#  [62.914]
#  [32.193]
#  [44.645]
#  [39.356]
#  [37.589]
#  [60.15 ]
#  [60.081]
#  [39.194]
#  [42.281]
#  [59.797]
#  [61.599]
#  [66.161]
#  [60.513]
#  [40.991]
#  [72.572]
#  [36.613]
#  [59.361]
#  [36.572]
#  [56.289]
#  [46.205]
#  [59.712]
#  [41.991]
#  [71.863]
#  [46.662]
#  [59.984]
#  [37.7  ]
#  [68.251]
#  [31.885]
#  [58.867]
#  [44.924]
#  [55.678]
#  [60.668]
#  [56.13 ]
#  [36.427]
#  [70.445]
#  [68.22 ]
#  [66.769]
#  [44.332]
#  [47.438]
#  [58.039]
#  [62.039]
#  [37.616]
#  [32.174]
#  [60.615]
#  [40.254]
#  [35.469]
#  [63.044]
#  [35.324]
#  [57.059]
#  [60.733]
#  [66.624]
#  [46.971]
#  [57.76 ]
#  [43.537]
#  [60.71 ]
#  [39.159]
#  [60.594]
#  [67.985]
#  [62.403]
#  [62.615]
#  [39.139]
#  [70.177]
#  [39.054]
#  [68.631]
#  [66.863]
#  [59.534]
#  [56.842]
#  [29.253]
#  [47.077]
#  [43.674]
#  [40.962]
#  [69.14 ]
#  [39.177]
#  [40.56 ]
#  [69.462]
#  [45.88 ]
#  [41.521]
#  [43.275]
#  [57.241]
#  [44.202]
#  [35.146]
#  [44.875]
#  [54.905]
#  [59.281]
#  [56.611]
#  [35.418]
#  [59.908]
#  [40.344]
#  [59.863]
#  [34.82 ]
#  [38.526]
#  [55.342]
#  [44.86 ]
#  [44.189]
#  [30.863]
#  [56.949]
#  [31.904]
#  [61.419]
#  [59.757]
#  [32.567]
#  [60.447]
#  [42.799]
#  [66.116]
#  [63.623]
#  [66.202]
#  [38.588]
#  [55.185]
#  [32.371]
#  [60.439]
#  [58.688]
#  [66.058]
#  [41.262]
#  [59.628]
#  [40.568]
#  [30.008]
#  [59.534]
#  [59.804]
#  [52.977]
#  [55.469]
#  [43.165]
#  [43.821]
#  [69.031]
#  [30.062]
#  [69.981]
#  [41.403]
#  [60.487]
#  [65.749]
#  [65.075]
#  [72.074]
#  [36.997]
#  [58.946]
#  [54.154]
#  [59.949]
#  [62.489]
#  [47.353]
#  [55.982]
#  [61.018]
#  [59.24 ]
#  [56.943]
#  [33.031]
#  [60.102]
#  [47.221]
#  [69.538]
#  [68.001]
#  [34.41 ]
#  [65.827]
#  [60.447]
#  [32.007]
#  [44.272]
#  [40.101]
#  [60.645]
#  [33.656]
#  [66.284]
#  [55.699]
#  [59.891]
#  [60.173]
#  [43.021]
#  [68.263]
#  [56.612]
#  [67.575]
#  [56.183]
#  [59.393]
#  [29.274]
#  [43.289]
#  [60.061]
#  [58.757]
#  [66.303]
#  [56.879]
#  [44.17 ]
#  [58.602]
#  [43.426]
#  [32.169]
#  [38.024]
#  [60.524]
#  [68.397]
#  [38.488]
#  [59.146]
#  [41.471]
#  [29.857]
#  [61.244]
#  [45.077]
#  [57.751]
#  [47.802]
#  [73.181]
#  [65.706]
#  [33.972]
#  [56.092]
#  [54.879]
#  [62.055]
#  [61.007]
#  [57.647]
#  [46.684]
#  [58.471]
#  [58.348]
#  [72.572]
#  [72.877]
#  [57.052]
#  [66.768]
#  [46.819]
#  [59.619]
#  [60.396]
#  [37.19 ]
#  [40.554]
#  [30.75 ]
#  [71.02 ]
#  [39.733]
#  [36.472]
#  [67.235]
#  [43.571]
#  [65.043]
#  [61.608]
#  [61.655]
#  [40.591]
#  [41.842]
#  [65.445]
#  [56.482]
#  [57.479]
#  [34.335]
#  [67.281]
#  [67.506]
#  [70.079]
#  [56.952]
#  [62.368]
#  [46.969]
#  [60.717]
#  [36.126]
#  [57.476]
#  [38.013]
#  [44.454]
#  [46.876]
#  [56.908]
#  [68.491]
#  [46.254]
#  [37.419]
#  [55.051]
#  [69.319]
#  [73.381]]

# %%
print(y_test)
# Out:
# [[50.162]
#  [48.793]
#  [59.447]
#  [59.814]
#  [55.567]
#  [32.224]
#  [45.175]
#  [34.68 ]
#  [66.317]
#  [68.237]
#  [47.002]
#  [45.324]
#  [47.2  ]
#  [56.622]
#  [55.442]
#  [61.566]
#  [36.077]
#  [59.031]
#  [39.256]
#  [59.672]
#  [49.125]
#  [61.568]
#  [44.073]
#  [61.084]
#  [66.463]
#  [49.901]
#  [53.303]
#  [59.261]
#  [59.589]
#  [49.468]
#  [36.8  ]
#  [41.8  ]
#  [58.446]
#  [44.682]
#  [66.159]
#  [56.575]
#  [60.617]
#  [60.054]
#  [61.476]
#  [32.272]
#  [60.01 ]
#  [32.561]
#  [56.972]
#  [53.161]
#  [61.224]
#  [59.298]
#  [62.399]
#  [58.984]
#  [61.255]
#  [33.428]
#  [45.324]
#  [40.46 ]
#  [38.582]
#  [60.944]
#  [59.447]
#  [40.9  ]
#  [43.744]
#  [59.312]
#  [61.753]
#  [65.07 ]
#  [60.032]
#  [42.4  ]
#  [71.438]
#  [37.908]
#  [58.862]
#  [37.763]
#  [56.91 ]
#  [47.792]
#  [59.402]
#  [43.25 ]
#  [69.09 ]
#  [48.286]
#  [59.357]
#  [38.293]
#  [67.447]
#  [32.754]
#  [57.377]
#  [45.422]
#  [57.918]
#  [60.477]
#  [56.664]
#  [37.811]
#  [68.109]
#  [67.227]
#  [66.171]
#  [45.077]
#  [48.187]
#  [57.962]
#  [61.738]
#  [38.486]
#  [32.705]
#  [59.907]
#  [41.424]
#  [35.884]
#  [61.744]
#  [35.595]
#  [56.622]
#  [58.457]
#  [65.122]
#  [48.483]
#  [58.398]
#  [45.422]
#  [60.897]
#  [39.497]
#  [60.045]
#  [65.643]
#  [62.491]
#  [62.03 ]
#  [41.809]
#  [68.706]
#  [38.052]
#  [67.988]
#  [65.897]
#  [59.768]
#  [56.569]
#  [29.767]
#  [47.743]
#  [46.   ]
#  [42.724]
#  [67.896]
#  [40.171]
#  [40.027]
#  [68.28 ]
#  [46.   ]
#  [42.213]
#  [44.583]
#  [57.678]
#  [45.916]
#  [35.066]
#  [45.225]
#  [55.471]
#  [58.952]
#  [56.333]
#  [36.751]
#  [59.122]
#  [41.45 ]
#  [59.214]
#  [35.74 ]
#  [37.474]
#  [55.375]
#  [45.566]
#  [45.175]
#  [30.923]
#  [56.227]
#  [32.85 ]
#  [61.753]
#  [59.169]
#  [32.416]
#  [59.445]
#  [42.965]
#  [64.059]
#  [62.456]
#  [64.524]
#  [38.967]
#  [55.855]
#  [32.079]
#  [60.01 ]
#  [57.692]
#  [63.795]
#  [42.608]
#  [58.772]
#  [41.809]
#  [31.068]
#  [58.457]
#  [59.447]
#  [54.818]
#  [55.007]
#  [44.534]
#  [45.422]
#  [67.683]
#  [28.226]
#  [69.09 ]
#  [41.818]
#  [58.952]
#  [65.027]
#  [63.531]
#  [71.438]
#  [38.293]
#  [57.422]
#  [54.319]
#  [60.85 ]
#  [61.338]
#  [46.867]
#  [56.431]
#  [60.392]
#  [59.496]
#  [57.678]
#  [33.332]
#  [59.768]
#  [47.792]
#  [68.109]
#  [67.422]
#  [35.933]
#  [63.883]
#  [59.627]
#  [32.561]
#  [44.632]
#  [41.45 ]
#  [60.932]
#  [33.524]
#  [64.311]
#  [53.892]
#  [60.757]
#  [59.445]
#  [43.398]
#  [67.03 ]
#  [57.102]
#  [66.725]
#  [57.246]
#  [56.162]
#  [28.804]
#  [43.736]
#  [59.683]
#  [57.602]
#  [64.098]
#  [57.198]
#  [45.57 ]
#  [57.197]
#  [44.287]
#  [32.272]
#  [37.185]
#  [60.43 ]
#  [67.535]
#  [39.16 ]
#  [58.682]
#  [41.665]
#  [30.297]
#  [60.482]
#  [46.212]
#  [56.927]
#  [48.533]
#  [73.145]
#  [64.499]
#  [34.391]
#  [56.143]
#  [55.764]
#  [59.672]
#  [61.271]
#  [58.446]
#  [48.582]
#  [59.166]
#  [57.822]
#  [71.736]
#  [72.889]
#  [57.486]
#  [65.731]
#  [44.94 ]
#  [58.772]
#  [59.312]
#  [37.426]
#  [42.   ]
#  [31.116]
#  [71.736]
#  [40.45 ]
#  [36.944]
#  [65.548]
#  [44.879]
#  [63.883]
#  [60.588]
#  [61.077]
#  [41.35 ]
#  [42.411]
#  [64.587]
#  [57.438]
#  [56.32 ]
#  [35.258]
#  [65.677]
#  [66.899]
#  [69.382]
#  [56.475]
#  [62.491]
#  [48.286]
#  [60.212]
#  [37.426]
#  [58.11 ]
#  [38.775]
#  [45.472]
#  [47.94 ]
#  [56.04 ]
#  [66.871]
#  [47.348]
#  [40.798]
#  [54.344]
#  [67.944]
#  [72.974]]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9898556616797438

# %%
#model.save('HSBC_FeatureSelected')

# %%
data_unseen
# Out:
#                   Low  Adj Close       O-C   10day MA   30day MA   Std_dev  \
# Date
# 2021-09-08  40.299999  40.450001 -0.049999  41.625000  42.708333  0.285044
# 2021-09-09  40.250000  40.400002 -0.299999  41.470000  42.631667  0.419225
# 2021-09-10  40.250000  40.900002  0.550003  41.295000  42.548333  0.501747
# 2021-09-13  40.150002  40.700001  0.200001  41.185001  42.476667  0.414729
# 2021-09-14  40.099998  40.200001 -0.500000  41.090001  42.385000  0.265518
#
#             Prediction
# Date
# 2021-09-08   40.400002
# 2021-09-09   40.900002
# 2021-09-10   40.700001
# 2021-09-13   40.200001
# 2021-09-14   40.099998

# %%
unseen_data=sc.fit_transform(data_unseen.drop('Prediction',1).values)
unseen_data=unseen_data.reshape(unseen_data.shape[0],1,unseen_data.shape[1])
unseen_pred=model.predict(unseen_data)
unseen_pred=sc_y.inverse_transform(unseen_pred)
unseen_test=data_unseen['Prediction'].values.reshape(-1,1)
print(unseen_pred)
print(unseen_test)
# Out:
# [[60.881]
#  [52.455]
#  [67.468]
#  [50.582]
#  [26.77 ]]
# [[40.4]
#  [40.9]
#  [40.7]
#  [40.2]
#  [40.1]]

# %%
plt.plot(data_unseen['Prediction'].values, marker='.', label="true")
plt.plot(unseen_pred, 'r',marker='*', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
r2_score(data_unseen['Prediction'].values,unseen_pred)
# Out:
# -3566.2707342586905
