# %%
# Import the necessary libraries first
from sklearn.feature_selection import SelectKBest, RFE
from sklearn.feature_selection import chi2, r_regression
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler ,StandardScaler
import yfinance as yf
import talib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.layers import LSTM,Dropout, BatchNormalization, Dense, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras.models import Sequential
from keras.optimizer_v2.adam import Adam

# %%
data=yf.download('0005.hk',"2011-09-28","2021-09-24")
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2011-09-28  62.250000  62.500000  61.450001  62.049999  37.729336  33168736
# 2011-09-30  62.299999  62.500000  60.500000  60.900002  37.030087  23553529
# 2011-10-03  58.549999  59.049999  58.000000  58.299999  35.449158  29682170
# 2011-10-04  58.000000  58.849998  56.349998  56.849998  34.567501  29013910
# 2011-10-06  58.250000  59.400002  57.549999  59.299999  36.057205  29335630

# %%
data['Prediction']=data['Adj Close'].shift(-1)
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2011-09-28  62.250000  62.500000  61.450001  62.049999  37.729336  33168736
# 2011-09-30  62.299999  62.500000  60.500000  60.900002  37.030087  23553529
# 2011-10-03  58.549999  59.049999  58.000000  58.299999  35.449158  29682170
# 2011-10-04  58.000000  58.849998  56.349998  56.849998  34.567501  29013910
# 2011-10-06  58.250000  59.400002  57.549999  59.299999  36.057205  29335630
#
#             Prediction
# Date
# 2011-09-28   37.030087
# 2011-09-30   35.449158
# 2011-10-03   34.567501
# 2011-10-04   36.057205
# 2011-10-06   37.486122

# %%
data['H-L'] = data['High'] - data['Low']
data['O-C'] = data['Adj Close'] - data['Open']
data["% Change"]=data["Adj Close"].pct_change()
data['3day MA'] = data['Adj Close'].rolling(window = 3).mean()
data['10day MA'] = data['Adj Close'].rolling(window = 10).mean()
data['30day MA'] = data['Adj Close'].rolling(window = 30).mean()
data['Std_dev']= data['Adj Close'].rolling(5).std()
data['RSI'] = talib.RSI(data['Adj Close'].values, timeperiod = 7)
data['Williams %R'] = talib.WILLR(data['High'].values, data['Low'].values, data['Close'].values, 7)
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2011-09-28  62.250000  62.500000  61.450001  62.049999  37.729336  33168736
# 2011-09-30  62.299999  62.500000  60.500000  60.900002  37.030087  23553529
# 2011-10-03  58.549999  59.049999  58.000000  58.299999  35.449158  29682170
# 2011-10-04  58.000000  58.849998  56.349998  56.849998  34.567501  29013910
# 2011-10-06  58.250000  59.400002  57.549999  59.299999  36.057205  29335630
#
#             Prediction       H-L        O-C  % Change    3day MA  10day MA  \
# Date
# 2011-09-28   37.030087  1.049999 -24.520664       NaN        NaN       NaN
# 2011-09-30   35.449158  2.000000 -25.269913 -0.018533        NaN       NaN
# 2011-10-03   34.567501  1.049999 -23.100842 -0.042693  36.736193       NaN
# 2011-10-04   36.057205  2.500000 -23.432499 -0.024871  35.682248       NaN
# 2011-10-06   37.486122  1.850002 -22.192795  0.043096  35.357955       NaN
#
#             30day MA   Std_dev  RSI  Williams %R
# Date
# 2011-09-28       NaN       NaN  NaN          NaN
# 2011-09-30       NaN       NaN  NaN          NaN
# 2011-10-03       NaN       NaN  NaN          NaN
# 2011-10-04       NaN       NaN  NaN          NaN
# 2011-10-06       NaN  1.252154  NaN          NaN

# %%
data.dropna(inplace=True)

# %%
# Feature extraction
X=data.drop('Prediction',1)
Y=data['Prediction'].values.reshape(-1,1)
test = SelectKBest(score_func=r_regression, k=5)
fit = test.fit(X, Y)

# Summarize scores
np.set_printoptions(precision=3)
print(fit.scores_)

features = fit.transform(X)
# Summarize selected features
print(features[0:5,:])
# Out:
# [ 0.736  0.736  0.738  0.737  0.998 -0.212 -0.084 -0.124  0.033  0.997
#   0.991  0.975 -0.167  0.125  0.075]
# [[61.65  37.517 39.837 40.812 39.052]
#  [61.55  37.608 38.804 40.31  39.048]
#  [63.1   38.459 37.861 39.906 39.095]
#  [61.9   37.729 37.932 39.593 39.171]
#  [60.35  36.939 37.709 39.186 39.25 ]]
# /home/gordon/anaconda3/envs/FYP/lib/python3.8/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
cols = list(X.columns)
model = LinearRegression()
rfe = RFE(model)
fit = rfe.fit(X, Y)
temp = pd.Series(fit.support_,index = cols)
print("Num Features: %s" % (fit.n_features_))
print("Selected Features: %s" % (fit.support_))
print("Feature Ranking: %s" % (fit.ranking_))
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)
# Out:
# Num Features: 7
# Selected Features: [ True False  True  True  True False  True  True  True False False False
#  False False False]
# Feature Ranking: [1 2 1 1 1 9 1 1 1 3 4 5 6 7 8]
# Index(['Open', 'Low', 'Close', 'Adj Close', 'H-L', 'O-C', '% Change'], dtype='object')

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X,Y)
# Out:
# /home/gordon/anaconda3/envs/FYP/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:156: LinAlgWarning: Ill-conditioned matrix (rcond=1.32761e-18): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# Ridge()

# %%
#no of features
nof_list=np.arange(1,16)            
high_score=0
#Variable to store the optimum features
nof=0           
score_list =[]
for n in range(len(nof_list)):
    X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.3, random_state = 0)
    model = LinearRegression()
    rfe = RFE(model,n_features_to_select=nof_list[n])
    X_train_rfe = rfe.fit_transform(X_train,y_train)
    X_test_rfe = rfe.transform(X_test)
    model.fit(X_train_rfe,y_train)
    score = model.score(X_test_rfe,y_test)
    score_list.append(score)
    if(score>high_score):
        high_score = score
        nof = nof_list[n]
print("Optimum number of features: %d" %nof)
print("Score with %d features: %f" % (nof, high_score))
# Out:
# Optimum number of features: 3
# Score with 3 features: 0.995784

# %%
cols = list(X.columns)
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, n_features_to_select=6)             
#Transforming data using RFE
X_rfe = rfe.fit_transform(X,Y)  
#Fitting the data to model
model.fit(X_rfe,Y)              
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)
# Out:
# Index(['Open', 'Close', 'Adj Close', 'H-L', 'O-C', '% Change'], dtype='object')

# %%
reg = LassoCV()
reg.fit(X, Y)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,Y))
coef = pd.Series(reg.coef_, index = X.columns)
# Out:
# /home/gordon/anaconda3/envs/FYP/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:1572: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best alpha using built-in LassoCV: 27900197.432322
# Best score using built-in LassoCV: 0.015306

# %%
X.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'H-L', 'O-C',
#        '% Change', '3day MA', '10day MA', '30day MA', 'Std_dev', 'RSI',
#        'Williams %R'],
#       dtype='object')

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 1 variables and eliminated the other 14 variables

# %%
imp_coef = coef.sort_values()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
# Out:
# Text(0.5, 1.0, 'Feature importance using Lasso Model')

# %%
def correlation(dataset,threshold):
    col_corr=set() # set will contains unique values.
    corr_matrix=dataset.corr() #finding the correlation between columns.
    for i in range(len(corr_matrix.columns)): #number of columns
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold: #checking the correlation between columns.
                colName=corr_matrix.columns[i] #getting the column name
                col_corr.add(colName) #adding the correlated column name heigher than threshold value.
    return col_corr #returning set of column names
col=correlation(X,0.8)
print('Correlated columns:',col)
# Out:
# Correlated columns: {'Williams %R', '10day MA', '3day MA', 'Close', 'High', '30day MA', 'Low'}

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
#I am going to use RandomForestRegressor algoritham as an estimator. Your can select other regression alogritham as well.
from sklearn.ensemble import RandomForestRegressor
#k_features=10 (It will get top 10 features best suited for prediction)
#forward=True (Forward feature selection model)
#verbose=2 (It will show details output as shown below.)
#cv=5 (Kfold cross valiation: it will split the training set in 5 set and 4 will be using for training the model and 1 will using as validation)
#n_jobs=-1 (Number of cores it will use for execution.-1 means it will use all the cores of CPU for execution.)
#scoring='r2'(R-squared is a statistical measure of how close the data are to the fitted regression line)
forward_model=sfs(RandomForestRegressor(),k_features=10,forward=True,verbose=2,cv=5,n_jobs=-1,scoring='r2')
forward_model.fit(X_train,y_train.ravel())
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    1.1s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    1.3s finished
#
# [2021-12-26 02:28:32] Features: 1/10 -- score: 0.9938050946039805[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    1.1s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    1.3s finished
#
# [2021-12-26 02:28:33] Features: 2/10 -- score: 0.9946407199486824[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  13 | elapsed:    1.3s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    1.4s finished
#
# [2021-12-26 02:28:34] Features: 3/10 -- score: 0.9948837299756145[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  12 | elapsed:    1.2s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    1.3s finished
#
# [2021-12-26 02:28:36] Features: 4/10 -- score: 0.9949692290665221[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  11 | elapsed:    1.4s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    1.5s finished
#
# [2021-12-26 02:28:37] Features: 5/10 -- score: 0.9950295859205184[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    1.6s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    1.6s finished
#
# [2021-12-26 02:28:39] Features: 6/10 -- score: 0.995026011533513[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   9 | elapsed:    1.6s remaining:    5.7s
# [Parallel(n_jobs=-1)]: Done   7 out of   9 | elapsed:    1.7s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    1.7s finished
#
# [2021-12-26 02:28:41] Features: 7/10 -- score: 0.9950286495113175[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of   8 | elapsed:    1.9s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.9s finished
#
# [2021-12-26 02:28:42] Features: 8/10 -- score: 0.9950149866820197[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    2.0s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    2.0s finished
#
# [2021-12-26 02:28:45] Features: 9/10 -- score: 0.9950229879468087[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    2.2s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    2.3s finished
#
# [2021-12-26 02:28:47] Features: 10/10 -- score: 0.9950189179764019
# SequentialFeatureSelector(estimator=RandomForestRegressor(), k_features=10,
#                           n_jobs=-1, scoring='r2', verbose=2)

# %%
#Get the selected feature index.
forward_model.k_feature_idx_
# Out:
# (1, 3, 4, 5, 6, 10, 11, 12, 13, 14)

# %%
#Get the column name for the selected feature.
forward_model.k_feature_names_
# Out:
# ('High',
#  'Close',
#  'Adj Close',
#  'Volume',
#  'H-L',
#  '10day MA',
#  '30day MA',
#  'Std_dev',
#  'RSI',
#  'Williams %R')

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.ensemble import RandomForestRegressor
#k_features=10 (It will get top 10 features best suited for prediction)
#forward=False (Backward feature selection model)
#verbose=2 (It will show details output as shown below.)
#cv=5 (Kfold cross valiation: it will split the training set in 5 set and 4 will be using for training the model and 1 will using as validation)
#n_jobs=-1 (Number of cores it will use for execution.-1 means it will use all the cores of CPU for execution.)
#scoring='r2'(R-squared is a statistical measure of how close the data are to the fitted regression line)
backwardModel=sfs(RandomForestRegressor(),k_features=10,forward=False,verbose=2,cv=5,n_jobs=-1,scoring='r2')
#We will convert our training data into numpy array. If we will not convert it, model is not able to read some of the column names. 
backwardModel.fit(np.array(X_train),y_train.ravel())
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    3.6s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    3.7s finished
#
# [2021-12-26 02:28:54] Features: 14/10 -- score: 0.9949927799145257[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    2.9s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:    3.5s finished
#
# [2021-12-26 02:28:57] Features: 13/10 -- score: 0.99496642789926[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  13 | elapsed:    2.7s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:    3.2s finished
#
# [2021-12-26 02:29:00] Features: 12/10 -- score: 0.995006888135365[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  12 | elapsed:    2.7s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:    3.0s finished
#
# [2021-12-26 02:29:03] Features: 11/10 -- score: 0.9950244189152022[Parallel(n_jobs=-1)]: Using backend LokyBackend with 24 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  11 | elapsed:    2.3s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    2.5s finished
#
# [2021-12-26 02:29:06] Features: 10/10 -- score: 0.9949903301537988
# SequentialFeatureSelector(estimator=RandomForestRegressor(), forward=False,
#                           k_features=10, n_jobs=-1, scoring='r2', verbose=2)

# %%
#Get the selected feature index.
backwardModel.k_feature_idx_
# Out:
# (1, 3, 4, 5, 6, 8, 10, 11, 12, 13)

# %%
#Get the column name for the selected feature.
X_train.columns[list(backwardModel.k_feature_idx_)]
# Out:
# Index(['High', 'Close', 'Adj Close', 'Volume', 'H-L', '% Change', '10day MA',
#        '30day MA', 'Std_dev', 'RSI'],
#       dtype='object')

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as efs
#min_features=1 (minimum number of feature)
#max_features=5 (maximum number of feature)
#n_jobs=-1 (Number of cores it will use for execution.-1 means it will use all the cores of CPU for execution.)
#scoring='r2'(R-squared is a statistical measure of how close the data are to the fitted regression line)
emodel=efs(RandomForestRegressor(),min_features=1,max_features=5,scoring='r2',n_jobs=-1)
#Lets take only 10 features which we got from backward feature selection.
miniData=X_train[X_train.columns[list(backwardModel.k_feature_idx_)]]

emodel.fit(np.array(miniData),y_train.ravel())
#If you see below the model creates 637 feature combinations from 10 features.Thats why its computationally very expensive.
# Out:
# Features: 637/637
# ExhaustiveFeatureSelector(estimator=RandomForestRegressor(), max_features=5,
#                           n_jobs=-1, scoring='r2')

# %%
#Get the selected feature index.
emodel.best_idx_
# Out:
# (0, 2, 4, 6, 8)

# %%
#Get the column name for the selected feature.
miniData.columns[list(emodel.best_idx_)]
# Out:
# Index(['High', 'Adj Close', 'H-L', '10day MA', 'Std_dev'], dtype='object')

# %%
emodel=efs(RandomForestRegressor(),min_features=1,max_features=5,scoring='r2',n_jobs=-1)
#Lets take only 10 features which we got from backward feature selection.
miniData_forward=X_train[X_train.columns[list(forward_model.k_feature_idx_)]]

emodel.fit(np.array(miniData_forward),y_train.ravel())
#If you see below the model creates 637 feature comb
# Out:
# Features: 637/637
# ExhaustiveFeatureSelector(estimator=RandomForestRegressor(), max_features=5,
#                           n_jobs=-1, scoring='r2')

# %%
#Get the selected feature index.
emodel.best_idx_
# Out:
# (2, 3, 4, 5, 6)

# %%
#Get the column name for the selected feature.
miniData_forward.columns[list(emodel.best_idx_)]
# Out:
# Index(['Adj Close', 'Volume', 'H-L', '10day MA', '30day MA'], dtype='object')

# %%
data_selected=data[miniData_forward.columns[list(emodel.best_idx_)]]

# %%
data_selected['Prediction']=data['Prediction']
data_selected=data_selected[:-5]
data_unseen=data_selected[-5:]
# Out:
# <ipython-input-29-b909f1970ec0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_selected['Prediction']=data['Prediction']

# %%
# Build the LSTM model
X=data_selected.drop('Prediction',1).values
scaler=MinMaxScaler(feature_range=(-1,1))
X=scaler.fit_transform(X)
X = X.reshape(X.shape[0], 1, X.shape[1])
y=data_selected['Prediction'].values.reshape(-1,1)
scaler_y=MinMaxScaler(feature_range=(-1,1))
y=scaler_y.fit_transform(y)
print(y.shape)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 0)
model = Sequential()
model.add(LSTM(1,batch_input_shape=(1,1, X.shape[2]),stateful=False))
# model.add(LSTM(10,activation='relu'))
# model.add(Dropout(.4))
model.add(Dense(1))
model.compile(
  loss="mean_squared_error",
  optimizer='Adam'
)
# Out:
# (2428, 1)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (1, 1)                    28
# _________________________________________________________________
# dense (Dense)                (1, 1)                    2
# =================================================================
# Total params: 30
# Trainable params: 30
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Fit model with history to check for overfitting
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=5, min_delta=0.0001)
history = model.fit(X_train,y_train,epochs=1200,batch_size=1,validation_data=(X_test,y_test),shuffle=False,callbacks=[es])
# Out:
# Epoch 1/1200
# 1942/1942 [==============================] - 11s 916us/step - loss: 0.1356 - val_loss: 0.0112
# Epoch 2/1200
# 1942/1942 [==============================] - 2s 917us/step - loss: 0.0094 - val_loss: 0.0067
# Epoch 3/1200
# 1942/1942 [==============================] - 2s 935us/step - loss: 0.0057 - val_loss: 0.0049
# Epoch 4/1200
# 1942/1942 [==============================] - 2s 876us/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 5/1200
# 1942/1942 [==============================] - 2s 914us/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 6/1200
# 1942/1942 [==============================] - 2s 841us/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 7/1200
# 1942/1942 [==============================] - 2s 896us/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 8/1200
# 1942/1942 [==============================] - 2s 880us/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 9/1200
# 1942/1942 [==============================] - 2s 819us/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 10/1200
# 1942/1942 [==============================] - 2s 831us/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 11/1200
# 1942/1942 [==============================] - 2s 852us/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 12/1200
# 1942/1942 [==============================] - 2s 799us/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 13/1200
# 1942/1942 [==============================] - 2s 809us/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 14/1200
# 1942/1942 [==============================] - 2s 845us/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 15/1200
# 1942/1942 [==============================] - 2s 898us/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 16/1200
# 1942/1942 [==============================] - 2s 917us/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 17/1200
# 1942/1942 [==============================] - 2s 911us/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 18/1200
# 1942/1942 [==============================] - 2s 817us/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 19/1200
# 1942/1942 [==============================] - 2s 909us/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 20/1200
# 1942/1942 [==============================] - 2s 909us/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 21/1200
# 1942/1942 [==============================] - 2s 913us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 22/1200
# 1942/1942 [==============================] - 2s 918us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 23/1200
# 1942/1942 [==============================] - 2s 904us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 24/1200
# 1942/1942 [==============================] - 2s 886us/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 25/1200
# 1942/1942 [==============================] - 2s 800us/step - loss: 9.9714e-04 - val_loss: 0.0011
# Epoch 26/1200
# 1942/1942 [==============================] - 2s 850us/step - loss: 9.9083e-04 - val_loss: 0.0011
# Epoch 27/1200
# 1942/1942 [==============================] - 2s 936us/step - loss: 9.8526e-04 - val_loss: 0.0011
# Epoch 28/1200
# 1942/1942 [==============================] - 2s 928us/step - loss: 9.8030e-04 - val_loss: 0.0011
# Epoch 00028: early stopping

# %%
y_pred = model.predict(X_test,batch_size=1)
y_pred.shape
# Out:
# (486, 1)

# %%
y_pred=scaler_y.inverse_transform(y_pred.flatten().reshape(-1,1))
y_test=scaler_y.inverse_transform(y_test)
y_pred
# Out:
# array([[44.428],
#        [54.511],
#        [45.751],
#        [70.353],
#        [62.848],
#        [55.88 ],
#        [43.879],
#        [37.196],
#        [43.401],
#        [45.718],
#        [55.613],
#        [53.074],
#        [53.116],
#        [61.633],
#        [70.316],
#        [38.304],
#        [56.054],
#        [37.056],
#        [57.865],
#        [38.832],
#        [60.587],
#        [55.719],
#        [54.457],
#        [41.832],
#        [43.11 ],
#        [57.813],
#        [56.384],
#        [50.65 ],
#        [44.75 ],
#        [58.293],
#        [64.215],
#        [43.682],
#        [42.522],
#        [68.54 ],
#        [41.97 ],
#        [58.345],
#        [61.319],
#        [36.871],
#        [66.885],
#        [52.317],
#        [54.844],
#        [50.685],
#        [48.336],
#        [56.854],
#        [42.925],
#        [47.514],
#        [31.517],
#        [70.75 ],
#        [45.261],
#        [54.723],
#        [44.509],
#        [35.371],
#        [53.897],
#        [44.797],
#        [46.914],
#        [39.974],
#        [56.212],
#        [64.065],
#        [45.146],
#        [57.601],
#        [53.694],
#        [45.775],
#        [48.279],
#        [48.334],
#        [38.605],
#        [47.714],
#        [55.018],
#        [52.087],
#        [61.344],
#        [55.286],
#        [57.215],
#        [39.655],
#        [45.678],
#        [53.153],
#        [57.739],
#        [57.722],
#        [41.477],
#        [57.457],
#        [46.553],
#        [43.116],
#        [56.034],
#        [54.708],
#        [45.705],
#        [39.706],
#        [65.159],
#        [49.793],
#        [62.633],
#        [62.92 ],
#        [41.923],
#        [34.906],
#        [51.324],
#        [68.214],
#        [63.529],
#        [55.423],
#        [55.439],
#        [57.993],
#        [58.093],
#        [40.117],
#        [36.188],
#        [39.852],
#        [48.78 ],
#        [51.335],
#        [51.979],
#        [61.693],
#        [55.398],
#        [56.828],
#        [61.145],
#        [57.186],
#        [51.103],
#        [41.504],
#        [35.696],
#        [46.034],
#        [58.498],
#        [52.414],
#        [42.237],
#        [46.072],
#        [56.632],
#        [51.441],
#        [52.417],
#        [46.795],
#        [67.1  ],
#        [42.04 ],
#        [34.578],
#        [46.083],
#        [64.512],
#        [54.859],
#        [45.332],
#        [47.427],
#        [67.231],
#        [53.423],
#        [43.086],
#        [46.235],
#        [55.418],
#        [46.701],
#        [41.067],
#        [51.021],
#        [53.587],
#        [42.439],
#        [61.635],
#        [56.723],
#        [42.868],
#        [56.514],
#        [66.598],
#        [46.   ],
#        [57.251],
#        [39.721],
#        [50.971],
#        [35.875],
#        [55.335],
#        [57.095],
#        [47.949],
#        [37.327],
#        [57.34 ],
#        [51.125],
#        [59.395],
#        [55.909],
#        [31.655],
#        [57.248],
#        [64.139],
#        [55.103],
#        [60.729],
#        [65.756],
#        [51.742],
#        [46.873],
#        [44.468],
#        [62.522],
#        [41.055],
#        [54.875],
#        [59.103],
#        [46.498],
#        [60.918],
#        [55.445],
#        [43.647],
#        [49.947],
#        [36.951],
#        [47.121],
#        [37.296],
#        [57.014],
#        [41.568],
#        [52.45 ],
#        [65.262],
#        [58.544],
#        [41.947],
#        [57.402],
#        [59.069],
#        [42.477],
#        [45.433],
#        [37.301],
#        [65.158],
#        [59.574],
#        [44.904],
#        [55.121],
#        [54.873],
#        [57.596],
#        [53.656],
#        [66.318],
#        [47.669],
#        [60.2  ],
#        [67.295],
#        [43.197],
#        [61.355],
#        [71.209],
#        [55.983],
#        [56.752],
#        [36.951],
#        [58.231],
#        [41.331],
#        [56.609],
#        [38.194],
#        [52.11 ],
#        [43.172],
#        [35.436],
#        [35.698],
#        [48.44 ],
#        [34.768],
#        [38.609],
#        [63.403],
#        [39.398],
#        [55.603],
#        [45.946],
#        [60.499],
#        [47.062],
#        [44.224],
#        [35.918],
#        [37.013],
#        [59.709],
#        [54.023],
#        [63.404],
#        [53.324],
#        [38.96 ],
#        [49.579],
#        [51.367],
#        [42.775],
#        [59.74 ],
#        [36.59 ],
#        [37.757],
#        [60.429],
#        [32.512],
#        [56.89 ],
#        [51.287],
#        [38.511],
#        [47.176],
#        [66.428],
#        [37.813],
#        [63.897],
#        [61.696],
#        [55.998],
#        [38.477],
#        [52.171],
#        [43.449],
#        [38.111],
#        [51.475],
#        [57.357],
#        [48.045],
#        [37.484],
#        [56.737],
#        [52.076],
#        [40.146],
#        [53.816],
#        [41.671],
#        [45.175],
#        [66.474],
#        [39.476],
#        [37.487],
#        [47.938],
#        [60.94 ],
#        [50.004],
#        [42.986],
#        [30.955],
#        [38.169],
#        [43.949],
#        [48.069],
#        [54.836],
#        [54.504],
#        [57.007],
#        [66.623],
#        [53.29 ],
#        [54.285],
#        [53.401],
#        [43.944],
#        [64.006],
#        [53.624],
#        [55.292],
#        [37.013],
#        [60.152],
#        [38.035],
#        [60.369],
#        [65.274],
#        [64.132],
#        [56.058],
#        [53.942],
#        [36.04 ],
#        [56.971],
#        [46.026],
#        [56.345],
#        [50.534],
#        [41.397],
#        [56.125],
#        [56.942],
#        [56.511],
#        [58.289],
#        [42.962],
#        [42.563],
#        [52.718],
#        [37.527],
#        [57.139],
#        [52.01 ],
#        [37.35 ],
#        [67.671],
#        [42.463],
#        [53.283],
#        [55.23 ],
#        [65.031],
#        [33.986],
#        [62.279],
#        [50.069],
#        [38.38 ],
#        [54.13 ],
#        [54.016],
#        [46.537],
#        [59.089],
#        [56.568],
#        [45.031],
#        [64.014],
#        [55.775],
#        [28.549],
#        [55.736],
#        [37.072],
#        [64.83 ],
#        [52.692],
#        [55.751],
#        [58.627],
#        [57.582],
#        [52.078],
#        [61.947],
#        [64.206],
#        [66.368],
#        [54.065],
#        [60.982],
#        [70.413],
#        [51.665],
#        [50.811],
#        [42.852],
#        [49.195],
#        [55.471],
#        [37.354],
#        [40.079],
#        [44.09 ],
#        [67.548],
#        [34.712],
#        [58.461],
#        [42.939],
#        [39.652],
#        [56.846],
#        [46.06 ],
#        [58.088],
#        [56.893],
#        [56.524],
#        [64.193],
#        [61.794],
#        [36.971],
#        [58.262],
#        [55.735],
#        [42.204],
#        [57.313],
#        [37.195],
#        [59.596],
#        [39.039],
#        [45.35 ],
#        [54.204],
#        [43.944],
#        [42.526],
#        [45.37 ],
#        [55.185],
#        [65.162],
#        [54.706],
#        [41.925],
#        [55.547],
#        [45.766],
#        [53.394],
#        [53.272],
#        [54.466],
#        [43.594],
#        [30.656],
#        [55.564],
#        [57.947],
#        [42.552],
#        [58.904],
#        [65.227],
#        [44.384],
#        [63.879],
#        [54.416],
#        [41.534],
#        [52.94 ],
#        [41.657],
#        [55.293],
#        [51.79 ],
#        [30.998],
#        [48.635],
#        [52.334],
#        [57.465],
#        [57.866],
#        [56.34 ],
#        [50.707],
#        [50.208],
#        [52.688],
#        [57.501],
#        [38.801],
#        [55.163],
#        [38.588],
#        [56.398],
#        [55.128],
#        [64.113],
#        [67.361],
#        [57.466],
#        [49.254],
#        [36.803],
#        [47.229],
#        [60.453],
#        [65.115],
#        [51.277],
#        [53.309],
#        [56.739],
#        [47.958],
#        [56.957],
#        [34.847],
#        [68.316],
#        [37.447],
#        [55.2  ],
#        [51.674],
#        [55.099],
#        [48.531],
#        [52.563],
#        [57.544],
#        [43.139],
#        [51.542],
#        [41.423],
#        [55.068],
#        [57.688],
#        [56.746],
#        [63.411],
#        [38.181],
#        [47.877],
#        [42.876],
#        [38.954],
#        [51.073],
#        [38.472],
#        [39.762],
#        [52.99 ],
#        [38.578],
#        [37.988],
#        [54.925],
#        [38.369],
#        [52.568],
#        [55.839],
#        [54.812],
#        [49.314],
#        [45.569],
#        [43.316],
#        [41.039],
#        [46.567],
#        [46.818],
#        [55.659],
#        [58.294],
#        [38.603],
#        [54.849],
#        [50.889],
#        [65.797],
#        [55.705],
#        [39.574],
#        [65.143],
#        [42.173],
#        [54.077],
#        [60.186],
#        [48.499],
#        [44.431],
#        [54.027],
#        [61.925],
#        [58.256],
#        [45.821],
#        [63.651],
#        [45.832],
#        [61.473],
#        [48.891],
#        [52.552],
#        [51.075]], dtype=float32)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
plt.plot(np.arange(0, len(y_train)), y_train, 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test, marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred, 'r', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
plt.plot(y_test, marker='.', label="true")
plt.plot(y_pred, 'r',marker='*', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
print(y_pred)
# Out:
# [[44.428]
#  [54.511]
#  [45.751]
#  [70.353]
#  [62.848]
#  [55.88 ]
#  [43.879]
#  [37.196]
#  [43.401]
#  [45.718]
#  [55.613]
#  [53.074]
#  [53.116]
#  [61.633]
#  [70.316]
#  [38.304]
#  [56.054]
#  [37.056]
#  [57.865]
#  [38.832]
#  [60.587]
#  [55.719]
#  [54.457]
#  [41.832]
#  [43.11 ]
#  [57.813]
#  [56.384]
#  [50.65 ]
#  [44.75 ]
#  [58.293]
#  [64.215]
#  [43.682]
#  [42.522]
#  [68.54 ]
#  [41.97 ]
#  [58.345]
#  [61.319]
#  [36.871]
#  [66.885]
#  [52.317]
#  [54.844]
#  [50.685]
#  [48.336]
#  [56.854]
#  [42.925]
#  [47.514]
#  [31.517]
#  [70.75 ]
#  [45.261]
#  [54.723]
#  [44.509]
#  [35.371]
#  [53.897]
#  [44.797]
#  [46.914]
#  [39.974]
#  [56.212]
#  [64.065]
#  [45.146]
#  [57.601]
#  [53.694]
#  [45.775]
#  [48.279]
#  [48.334]
#  [38.605]
#  [47.714]
#  [55.018]
#  [52.087]
#  [61.344]
#  [55.286]
#  [57.215]
#  [39.655]
#  [45.678]
#  [53.153]
#  [57.739]
#  [57.722]
#  [41.477]
#  [57.457]
#  [46.553]
#  [43.116]
#  [56.034]
#  [54.708]
#  [45.705]
#  [39.706]
#  [65.159]
#  [49.793]
#  [62.633]
#  [62.92 ]
#  [41.923]
#  [34.906]
#  [51.324]
#  [68.214]
#  [63.529]
#  [55.423]
#  [55.439]
#  [57.993]
#  [58.093]
#  [40.117]
#  [36.188]
#  [39.852]
#  [48.78 ]
#  [51.335]
#  [51.979]
#  [61.693]
#  [55.398]
#  [56.828]
#  [61.145]
#  [57.186]
#  [51.103]
#  [41.504]
#  [35.696]
#  [46.034]
#  [58.498]
#  [52.414]
#  [42.237]
#  [46.072]
#  [56.632]
#  [51.441]
#  [52.417]
#  [46.795]
#  [67.1  ]
#  [42.04 ]
#  [34.578]
#  [46.083]
#  [64.512]
#  [54.859]
#  [45.332]
#  [47.427]
#  [67.231]
#  [53.423]
#  [43.086]
#  [46.235]
#  [55.418]
#  [46.701]
#  [41.067]
#  [51.021]
#  [53.587]
#  [42.439]
#  [61.635]
#  [56.723]
#  [42.868]
#  [56.514]
#  [66.598]
#  [46.   ]
#  [57.251]
#  [39.721]
#  [50.971]
#  [35.875]
#  [55.335]
#  [57.095]
#  [47.949]
#  [37.327]
#  [57.34 ]
#  [51.125]
#  [59.395]
#  [55.909]
#  [31.655]
#  [57.248]
#  [64.139]
#  [55.103]
#  [60.729]
#  [65.756]
#  [51.742]
#  [46.873]
#  [44.468]
#  [62.522]
#  [41.055]
#  [54.875]
#  [59.103]
#  [46.498]
#  [60.918]
#  [55.445]
#  [43.647]
#  [49.947]
#  [36.951]
#  [47.121]
#  [37.296]
#  [57.014]
#  [41.568]
#  [52.45 ]
#  [65.262]
#  [58.544]
#  [41.947]
#  [57.402]
#  [59.069]
#  [42.477]
#  [45.433]
#  [37.301]
#  [65.158]
#  [59.574]
#  [44.904]
#  [55.121]
#  [54.873]
#  [57.596]
#  [53.656]
#  [66.318]
#  [47.669]
#  [60.2  ]
#  [67.295]
#  [43.197]
#  [61.355]
#  [71.209]
#  [55.983]
#  [56.752]
#  [36.951]
#  [58.231]
#  [41.331]
#  [56.609]
#  [38.194]
#  [52.11 ]
#  [43.172]
#  [35.436]
#  [35.698]
#  [48.44 ]
#  [34.768]
#  [38.609]
#  [63.403]
#  [39.398]
#  [55.603]
#  [45.946]
#  [60.499]
#  [47.062]
#  [44.224]
#  [35.918]
#  [37.013]
#  [59.709]
#  [54.023]
#  [63.404]
#  [53.324]
#  [38.96 ]
#  [49.579]
#  [51.367]
#  [42.775]
#  [59.74 ]
#  [36.59 ]
#  [37.757]
#  [60.429]
#  [32.512]
#  [56.89 ]
#  [51.287]
#  [38.511]
#  [47.176]
#  [66.428]
#  [37.813]
#  [63.897]
#  [61.696]
#  [55.998]
#  [38.477]
#  [52.171]
#  [43.449]
#  [38.111]
#  [51.475]
#  [57.357]
#  [48.045]
#  [37.484]
#  [56.737]
#  [52.076]
#  [40.146]
#  [53.816]
#  [41.671]
#  [45.175]
#  [66.474]
#  [39.476]
#  [37.487]
#  [47.938]
#  [60.94 ]
#  [50.004]
#  [42.986]
#  [30.955]
#  [38.169]
#  [43.949]
#  [48.069]
#  [54.836]
#  [54.504]
#  [57.007]
#  [66.623]
#  [53.29 ]
#  [54.285]
#  [53.401]
#  [43.944]
#  [64.006]
#  [53.624]
#  [55.292]
#  [37.013]
#  [60.152]
#  [38.035]
#  [60.369]
#  [65.274]
#  [64.132]
#  [56.058]
#  [53.942]
#  [36.04 ]
#  [56.971]
#  [46.026]
#  [56.345]
#  [50.534]
#  [41.397]
#  [56.125]
#  [56.942]
#  [56.511]
#  [58.289]
#  [42.962]
#  [42.563]
#  [52.718]
#  [37.527]
#  [57.139]
#  [52.01 ]
#  [37.35 ]
#  [67.671]
#  [42.463]
#  [53.283]
#  [55.23 ]
#  [65.031]
#  [33.986]
#  [62.279]
#  [50.069]
#  [38.38 ]
#  [54.13 ]
#  [54.016]
#  [46.537]
#  [59.089]
#  [56.568]
#  [45.031]
#  [64.014]
#  [55.775]
#  [28.549]
#  [55.736]
#  [37.072]
#  [64.83 ]
#  [52.692]
#  [55.751]
#  [58.627]
#  [57.582]
#  [52.078]
#  [61.947]
#  [64.206]
#  [66.368]
#  [54.065]
#  [60.982]
#  [70.413]
#  [51.665]
#  [50.811]
#  [42.852]
#  [49.195]
#  [55.471]
#  [37.354]
#  [40.079]
#  [44.09 ]
#  [67.548]
#  [34.712]
#  [58.461]
#  [42.939]
#  [39.652]
#  [56.846]
#  [46.06 ]
#  [58.088]
#  [56.893]
#  [56.524]
#  [64.193]
#  [61.794]
#  [36.971]
#  [58.262]
#  [55.735]
#  [42.204]
#  [57.313]
#  [37.195]
#  [59.596]
#  [39.039]
#  [45.35 ]
#  [54.204]
#  [43.944]
#  [42.526]
#  [45.37 ]
#  [55.185]
#  [65.162]
#  [54.706]
#  [41.925]
#  [55.547]
#  [45.766]
#  [53.394]
#  [53.272]
#  [54.466]
#  [43.594]
#  [30.656]
#  [55.564]
#  [57.947]
#  [42.552]
#  [58.904]
#  [65.227]
#  [44.384]
#  [63.879]
#  [54.416]
#  [41.534]
#  [52.94 ]
#  [41.657]
#  [55.293]
#  [51.79 ]
#  [30.998]
#  [48.635]
#  [52.334]
#  [57.465]
#  [57.866]
#  [56.34 ]
#  [50.707]
#  [50.208]
#  [52.688]
#  [57.501]
#  [38.801]
#  [55.163]
#  [38.588]
#  [56.398]
#  [55.128]
#  [64.113]
#  [67.361]
#  [57.466]
#  [49.254]
#  [36.803]
#  [47.229]
#  [60.453]
#  [65.115]
#  [51.277]
#  [53.309]
#  [56.739]
#  [47.958]
#  [56.957]
#  [34.847]
#  [68.316]
#  [37.447]
#  [55.2  ]
#  [51.674]
#  [55.099]
#  [48.531]
#  [52.563]
#  [57.544]
#  [43.139]
#  [51.542]
#  [41.423]
#  [55.068]
#  [57.688]
#  [56.746]
#  [63.411]
#  [38.181]
#  [47.877]
#  [42.876]
#  [38.954]
#  [51.073]
#  [38.472]
#  [39.762]
#  [52.99 ]
#  [38.578]
#  [37.988]
#  [54.925]
#  [38.369]
#  [52.568]
#  [55.839]
#  [54.812]
#  [49.314]
#  [45.569]
#  [43.316]
#  [41.039]
#  [46.567]
#  [46.818]
#  [55.659]
#  [58.294]
#  [38.603]
#  [54.849]
#  [50.889]
#  [65.797]
#  [55.705]
#  [39.574]
#  [65.143]
#  [42.173]
#  [54.077]
#  [60.186]
#  [48.499]
#  [44.431]
#  [54.027]
#  [61.925]
#  [58.256]
#  [45.821]
#  [63.651]
#  [45.832]
#  [61.473]
#  [48.891]
#  [52.552]
#  [51.075]]

# %%
print(y_test)
# Out:
# [[44.025]
#  [54.41 ]
#  [46.311]
#  [71.864]
#  [63.414]
#  [56.039]
#  [44.534]
#  [37.023]
#  [43.897]
#  [45.505]
#  [55.693]
#  [52.489]
#  [53.066]
#  [61.566]
#  [71.736]
#  [38.049]
#  [56.593]
#  [37.109]
#  [57.909]
#  [38.606]
#  [59.717]
#  [54.265]
#  [55.045]
#  [42.   ]
#  [43.937]
#  [57.526]
#  [57.155]
#  [50.793]
#  [45.219]
#  [56.974]
#  [64.738]
#  [43.394]
#  [43.267]
#  [69.382]
#  [42.361]
#  [58.952]
#  [59.672]
#  [36.097]
#  [68.293]
#  [52.442]
#  [54.191]
#  [50.866]
#  [48.64 ]
#  [56.945]
#  [43.364]
#  [47.348]
#  [29.382]
#  [72.59 ]
#  [45.667]
#  [55.469]
#  [45.324]
#  [35.157]
#  [53.514]
#  [45.247]
#  [48.138]
#  [40.1  ]
#  [56.351]
#  [64.226]
#  [45.032]
#  [57.374]
#  [53.903]
#  [46.963]
#  [47.629]
#  [48.187]
#  [39.497]
#  [48.286]
#  [55.305]
#  [51.619]
#  [61.967]
#  [55.01 ]
#  [57.52 ]
#  [40.171]
#  [46.563]
#  [53.737]
#  [58.135]
#  [57.425]
#  [42.559]
#  [58.139]
#  [45.911]
#  [42.861]
#  [55.901]
#  [54.071]
#  [45.566]
#  [40.734]
#  [65.677]
#  [48.793]
#  [62.545]
#  [62.359]
#  [42.953]
#  [34.873]
#  [51.491]
#  [68.706]
#  [64.634]
#  [55.269]
#  [54.735]
#  [57.647]
#  [57.892]
#  [40.4  ]
#  [36.359]
#  [41.258]
#  [48.882]
#  [51.095]
#  [52.111]
#  [61.369]
#  [55.681]
#  [56.238]
#  [60.71 ]
#  [56.987]
#  [50.314]
#  [42.756]
#  [35.74 ]
#  [46.19 ]
#  [57.927]
#  [52.433]
#  [42.902]
#  [45.518]
#  [57.526]
#  [51.532]
#  [52.022]
#  [47.2  ]
#  [67.623]
#  [41.75 ]
#  [35.258]
#  [45.175]
#  [65.292]
#  [54.831]
#  [45.144]
#  [48.139]
#  [69.645]
#  [53.694]
#  [43.173]
#  [46.457]
#  [55.935]
#  [47.125]
#  [41.   ]
#  [51.162]
#  [53.316]
#  [41.616]
#  [61.199]
#  [56.431]
#  [43.415]
#  [56.056]
#  [67.183]
#  [45.966]
#  [57.371]
#  [38.745]
#  [51.997]
#  [37.376]
#  [55.34 ]
#  [56.748]
#  [47.99 ]
#  [36.79 ]
#  [57.645]
#  [50.95 ]
#  [60.098]
#  [57.038]
#  [29.767]
#  [56.814]
#  [64.683]
#  [55.145]
#  [60.804]
#  [66.831]
#  [52.183]
#  [46.788]
#  [44.025]
#  [62.322]
#  [39.834]
#  [54.764]
#  [59.768]
#  [45.966]
#  [60.804]
#  [54.723]
#  [44.313]
#  [50.699]
#  [36.174]
#  [47.029]
#  [36.821]
#  [57.962]
#  [42.229]
#  [52.472]
#  [65.679]
#  [58.731]
#  [41.545]
#  [57.006]
#  [58.048]
#  [42.411]
#  [46.003]
#  [38.052]
#  [64.46 ]
#  [59.676]
#  [45.443]
#  [54.329]
#  [54.781]
#  [57.534]
#  [53.454]
#  [66.463]
#  [49.443]
#  [60.322]
#  [68.109]
#  [43.419]
#  [60.81 ]
#  [72.889]
#  [56.424]
#  [56.94 ]
#  [36.409]
#  [58.521]
#  [40.326]
#  [55.717]
#  [38.437]
#  [51.538]
#  [43.706]
#  [34.572]
#  [35.558]
#  [48.483]
#  [34.054]
#  [38.49 ]
#  [63.663]
#  [38.052]
#  [55.759]
#  [45.422]
#  [60.43 ]
#  [46.943]
#  [44.879]
#  [36.751]
#  [37.988]
#  [59.261]
#  [54.038]
#  [63.796]
#  [53.062]
#  [38.841]
#  [50.392]
#  [50.738]
#  [42.445]
#  [59.491]
#  [36.511]
#  [38.004]
#  [60.045]
#  [32.561]
#  [56.971]
#  [51.762]
#  [37.586]
#  [48.042]
#  [67.073]
#  [37.233]
#  [64.543]
#  [61.845]
#  [56.267]
#  [38.22 ]
#  [52.62 ]
#  [43.844]
#  [40.798]
#  [52.111]
#  [58.166]
#  [47.978]
#  [36.883]
#  [55.903]
#  [51.904]
#  [39.726]
#  [53.694]
#  [41.424]
#  [45.57 ]
#  [66.943]
#  [39.497]
#  [36.667]
#  [48.397]
#  [61.131]
#  [50.279]
#  [42.855]
#  [28.226]
#  [39.156]
#  [44.237]
#  [47.792]
#  [54.865]
#  [57.197]
#  [56.575]
#  [65.643]
#  [52.979]
#  [54.319]
#  [53.071]
#  [44.534]
#  [64.098]
#  [55.06 ]
#  [55.764]
#  [38.081]
#  [59.492]
#  [37.558]
#  [60.454]
#  [65.036]
#  [64.695]
#  [56.039]
#  [53.36 ]
#  [35.644]
#  [57.122]
#  [47.707]
#  [56.303]
#  [49.468]
#  [42.   ]
#  [56.641]
#  [57.875]
#  [56.683]
#  [58.401]
#  [42.666]
#  [42.953]
#  [53.104]
#  [36.735]
#  [57.198]
#  [52.022]
#  [38.459]
#  [68.194]
#  [42.398]
#  [53.385]
#  [54.792]
#  [65.418]
#  [32.176]
#  [61.338]
#  [50.812]
#  [38.954]
#  [53.986]
#  [54.635]
#  [44.94 ]
#  [58.322]
#  [55.688]
#  [44.682]
#  [64.098]
#  [55.822]
#  [27.696]
#  [55.54 ]
#  [34.536]
#  [65.549]
#  [52.116]
#  [55.769]
#  [58.772]
#  [57.726]
#  [52.111]
#  [62.399]
#  [64.411]
#  [66.487]
#  [54.2  ]
#  [60.783]
#  [72.376]
#  [51.331]
#  [50.808]
#  [42.213]
#  [49.29 ]
#  [55.589]
#  [36.8  ]
#  [39.508]
#  [45.247]
#  [69.389]
#  [33.428]
#  [58.302]
#  [43.517]
#  [40.087]
#  [56.651]
#  [47.189]
#  [57.829]
#  [56.333]
#  [55.759]
#  [64.387]
#  [62.261]
#  [36.735]
#  [57.582]
#  [54.598]
#  [38.486]
#  [57.357]
#  [37.641]
#  [59.357]
#  [39.16 ]
#  [45.854]
#  [54.168]
#  [43.93 ]
#  [42.532]
#  [46.377]
#  [55.045]
#  [65.781]
#  [55.168]
#  [41.665]
#  [55.391]
#  [45.225]
#  [53.457]
#  [53.62 ]
#  [55.416]
#  [44.92 ]
#  [29.767]
#  [55.391]
#  [58.172]
#  [42.965]
#  [57.605]
#  [66.463]
#  [44.984]
#  [64.524]
#  [54.816]
#  [41.35 ]
#  [52.508]
#  [42.4  ]
#  [55.37 ]
#  [51.049]
#  [29.912]
#  [46.963]
#  [52.566]
#  [57.692]
#  [57.422]
#  [56.759]
#  [50.844]
#  [50.491]
#  [52.788]
#  [57.377]
#  [39.038]
#  [55.277]
#  [38.745]
#  [55.622]
#  [54.663]
#  [64.133]
#  [67.799]
#  [60.908]
#  [49.698]
#  [36.521]
#  [47.425]
#  [60.054]
#  [65.485]
#  [50.465]
#  [53.179]
#  [56.522]
#  [47.94 ]
#  [57.227]
#  [35.188]
#  [68.28 ]
#  [37.474]
#  [55.338]
#  [51.705]
#  [55.716]
#  [48.64 ]
#  [52.525]
#  [56.424]
#  [43.615]
#  [51.056]
#  [36.605]
#  [54.735]
#  [57.678]
#  [55.97 ]
#  [63.035]
#  [38.762]
#  [48.914]
#  [43.067]
#  [39.449]
#  [51.132]
#  [37.715]
#  [39.901]
#  [52.979]
#  [38.534]
#  [38.645]
#  [54.676]
#  [39.779]
#  [52.69 ]
#  [56.136]
#  [54.974]
#  [49.011]
#  [47.041]
#  [43.483]
#  [41.528]
#  [48.393]
#  [47.717]
#  [55.375]
#  [58.334]
#  [38.023]
#  [55.135]
#  [51.158]
#  [67.16 ]
#  [55.887]
#  [39.497]
#  [65.331]
#  [42.666]
#  [54.445]
#  [60.276]
#  [48.351]
#  [43.793]
#  [54.172]
#  [61.799]
#  [57.937]
#  [45.48 ]
#  [64.411]
#  [45.688]
#  [61.292]
#  [49.364]
#  [52.111]
#  [50.757]]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9934501386481147

# %%
#model.save('HSBC_FeatureSelected')

# %%
data_unseen
# Out:
#             Adj Close    Volume       H-L   10day MA   30day MA  Prediction
# Date
# 2021-09-08  40.450001  21636170  0.549999  41.470000  42.357999   40.400002
# 2021-09-09  40.400002  16569193  0.750000  41.295000  42.292625   40.900002
# 2021-09-10  40.900002   7986921  0.700001  41.185001  42.238981   40.700001
# 2021-09-13  40.700001   8576584  0.699997  41.090001  42.165505   40.200001
# 2021-09-14  40.200001  19188693  1.000000  40.965001  42.093465   40.099998

# %%
unseen_x=data_unseen.drop('Prediction',1).values
unseen_x=scaler.transform(unseen_x).reshape(5,1,5)
unseen_pred=model.predict(unseen_x,batch_size=1)
unseen_pred=scaler_y.inverse_transform(unseen_pred.flatten().reshape(-1,1))

# %%
plt.plot(data_unseen['Prediction'].values, marker='.', label="true")
plt.plot(unseen_pred, 'r',marker='*', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
r2_score(data_unseen['Prediction'].values,unseen_pred)
# Out:
# -0.7030799609322351
