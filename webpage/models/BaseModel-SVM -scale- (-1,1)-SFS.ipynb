# %%
import yfinance as yf
import keras.backend as K
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import MinMaxScaler ,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score, mean_squared_error,mean_absolute_percentage_error,r2_score
from sklearn.pipeline import make_pipeline
import tensorflow as tf
from tensorflow import keras
from keras.layers import LSTM,Dropout, BatchNormalization, Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras.models import Sequential
from keras.optimizer_v2.adam import Adam
from keras.optimizer_v2.rmsprop import RMSprop
import talib

# %%
# Get the data for the SPY ETF by specifying the stock ticker, start date, and end date
data = yf.download('0700.hk')
# data.drop("Adj Close",axis=1,inplace=True)
data.head(15)
# Out:
# [*********************100%***********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close      Volume
# Date
# 2004-06-16  0.875  0.925  0.815  0.830   0.802119  2198875000
# 2004-06-17  0.830  0.875  0.825  0.845   0.816615   419007500
# 2004-06-18  0.840  0.850  0.790  0.805   0.777959   182990000
# 2004-06-21  0.820  0.825  0.790  0.800   0.773127   114085000
# 2004-06-22  0.800  0.800  0.800  0.800   0.773127           0
# 2004-06-23  0.810  0.890  0.805  0.885   0.855272   275080000
# 2004-06-24  0.895  0.905  0.865  0.890   0.860104   173615000
# 2004-06-25  0.895  0.910  0.870  0.880   0.850439   106062500
# 2004-06-28  0.880  0.880  0.850  0.865   0.835943    73730000
# 2004-06-29  0.860  0.885  0.860  0.865   0.835943    75407500
# 2004-06-30  0.875  0.885  0.860  0.860   0.831111    61085000
# 2004-07-01  0.860  0.860  0.860  0.860   0.831111           0
# 2004-07-02  0.855  0.875  0.835  0.870   0.840775    65130000
# 2004-07-05  0.870  0.870  0.870  0.870   0.840775           0
# 2004-07-06  0.875  0.890  0.870  0.880   0.850439    77145000

# %%
scaler=MinMaxScaler(feature_range=(-1,1))
df = data
df['6day MA'] = df['Close'].rolling(window = 6).mean()
df['12day MA'] = df['Close'].rolling(window = 12).mean()
df['RSI'] = talib.RSI(df['Close'].values, timeperiod = 7)
df['%R5'] = talib.WILLR(df['High'].values, df['Low'].values, df['Close'].values, 5)
df['%R10'] = talib.WILLR(df['High'].values, df['Low'].values, df['Close'].values, 10)
df['MTM6']=talib.MOM(df['Close'],timeperiod=6)
df['MTM12']=talib.MOM(df['Close'],timeperiod=12)
macd, macdsignal, macdhist = talib.MACD(df['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
df['EMA12']=talib.EMA(df['Close'], timeperiod=12)
df['EMA26']=talib.EMA(df['Close'],timeperiod=26)
df['MACD']=macd
df['TR']=talib.TRANGE(df['High'],df['Low'],df['Close'])
df['OSC6']=talib.CMO(df['Close'], timeperiod=6)
df['OSC12']=talib.CMO(df['Close'], timeperiod=12)
#Create one more column Prediction shifted 15 days up. 
df['Prediction'] = data[['Close']].shift(-1)
#print data set
df=df.dropna()
print(df)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2004


# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.ensemble import RandomForestRegressor
#k_features=10 (It will get top 10 features best suited for prediction)
#forward=False (Backward feature selection model)
#verbose=2 (It will show details output as shown below.)
#cv=5 (Kfold cross valiation: it will split the training set in 5 set and 4 will be using for training the model and 1 will using as validation)
#n_jobs=-1 (Number of cores it will use for execution.-1 means it will use all the cores of CPU for execution.)
#scoring='r2'(R-squared is a statistical measure of how close the data are to the fitted regression line)
backwardModel=sfs(SVR(),k_features=(1,19),forward=True,verbose=2,cv=5,n_jobs=-1,scoring='r2')
#We will convert our training data into numpy array. If we will not convert it, model is not able to read some of the column names.
backwardModel.fit(np.array(df.drop('Prediction',1)),df['Prediction'].values.ravel())
# Out:
# /var/folders/8h/w0jn89bj2w5g85gj4ck7w0t00000gn/T/ipykernel_52717/4077387924.py:11: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   backwardModel.fit(np.array(df.drop('Prediction',1)),df['Prediction'].values.ravel())
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  19 | elapsed:    8.1s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done  19 out of  19 | elapsed:   10.8s finished
#
# [2022-01-01 18:17:21] Features: 1/19 -- score: -4.759117068332182[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  18 | elapsed:    8.2s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done  18 out of  18 | elapsed:   10.2s finished
#
# [2022-01-01 18:17:32] Features: 2/19 -- score: -3.8094505530383893[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  17 | elapsed:    9.8s remaining:    5.4s
# [Parallel(n_jobs=-1)]: Done  17 out of  17 | elapsed:   12.5s finished
#
# [2022-01-01 18:17:44] Features: 3/19 -- score: -3.5126175853596946[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  16 | elapsed:    8.9s remaining:    5.3s
# [Parallel(n_jobs=-1)]: Done  16 out of  16 | elapsed:    9.1s finished
#
# [2022-01-01 18:17:53] Features: 4/19 -- score: -3.395490412197565[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    4.4s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    9.2s finished
#
# [2022-01-01 18:18:02] Features: 5/19 -- score: -3.381550889845586[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  14 | elapsed:    6.8s remaining:    6.8s
# [Parallel(n_jobs=-1)]: Done  14 out of  14 | elapsed:   12.6s finished
#
# [2022-01-01 18:18:15] Features: 6/19 -- score: -3.554268637449674[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  13 | elapsed:    6.6s remaining:   10.5s
# [Parallel(n_jobs=-1)]: Done  13 out of  13 | elapsed:   11.6s finished
#
# [2022-01-01 18:18:27] Features: 7/19 -- score: -3.6091340568327417[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  12 | elapsed:    6.0s remaining:   12.0s
# [Parallel(n_jobs=-1)]: Done  12 out of  12 | elapsed:   12.0s finished
#
# [2022-01-01 18:18:39] Features: 8/19 -- score: -3.567318838479005[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  11 | elapsed:    7.2s remaining:   32.3s
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:    7.7s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:   12.9s finished
#
# [2022-01-01 18:18:52] Features: 9/19 -- score: -3.5686217476364788[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    7.7s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   14.5s finished
#
# [2022-01-01 18:19:06] Features: 10/19 -- score: -3.621580884698942[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    8.2s remaining:   10.3s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:   14.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:   14.9s finished
#
# [2022-01-01 18:19:21] Features: 11/19 -- score: -3.6478150942364977[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    6.9s remaining:   11.5s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    7.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    7.2s finished
#
# [2022-01-01 18:19:28] Features: 12/19 -- score: -3.705323467857851[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    7.9s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    8.1s finished
#
# [2022-01-01 18:19:36] Features: 13/19 -- score: -3.7968345119532203[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    6.5s remaining:    6.5s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    6.7s finished
#
# [2022-01-01 18:19:43] Features: 14/19 -- score: -3.804668601581566[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    7.0s remaining:   10.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    7.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    7.2s finished
#
# [2022-01-01 18:19:50] Features: 15/19 -- score: -3.872830849339279[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    6.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    6.8s finished
#
# [2022-01-01 18:19:57] Features: 16/19 -- score: -3.9330782803649016[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    6.4s finished
#
# [2022-01-01 18:20:03] Features: 17/19 -- score: -4.018069651119534[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    6.0s finished
#
# [2022-01-01 18:20:09] Features: 18/19 -- score: -4.178736490789586[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    6.3s finished
#
# [2022-01-01 18:20:16] Features: 19/19 -- score: -354.61389580950157
# SequentialFeatureSelector(estimator=SVR(), k_features=(1, 19), n_jobs=-1,
#                           scoring='r2', verbose=2)

# %%
df.columns[list(backwardModel.k_feature_idx_)]
# Out:
# Index(['Close', 'MTM6', 'MTM12', 'MACD', 'TR'], dtype='object')

# %%
#Create a data set X and convert it into numpy array , which will be having actual values
X = np.array(df[df.columns[list(backwardModel.k_feature_idx_)]])
# X=scaler.fit_transform(X)
#Remove the last 15 rows
x_unseen=X[-100:]
X=X[:-100]
print(X.shape)
# Create a dataset y which will be having Predicted values and convert into numpy array
y = np.array(df['Prediction']).reshape(-1,1)
# y=scaler_y.fit_transform(y)
# Remove Last 15 rows
y_unseen=y[-100:]
y=y[:-100]
print(y.shape)
# Out:
# (4205, 5)
# (4205, 1)

# %%
# Split the data into train and test with 90 & 10 % respectively
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
# SVM Model
svr = make_pipeline(MinMaxScaler(feature_range=(-1,1)),SVR(C=1e3,gamma=0.001))
# Train the model 
svr.fit(x_train, y_train)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/FYP/lib/python3.9/site-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(steps=[('minmaxscaler', MinMaxScaler(feature_range=(-1, 1))),
#                 ('svr', SVR(C=1000.0, gamma=0.001))])

# %%
# The best possible score is 1.0
svm_confidence = svr.score(x_test, y_test)
print("svm confidence: ", svm_confidence)
# Out:
# svm confidence:  0.9994827010582927

# %%
y_pred=svr.predict(x_test).reshape(-1,1)
# y_pred=scaler_y.inverse_transform(y_pred)
# y_test=scaler_y.inverse_transform(y_test)

# %%
plt.plot(y_test, marker='.', label="true")
plt.plot(y_pred, 'r',marker='*', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
mean_squared_error(y_test,y_pred,squared=False)
# Out:
# 4.019525400333343

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.02245133669929728

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9994827010582927

# %% [markdown]
# # Unseen Data

# %%
svm_prediction = svr.predict(x_unseen)
# svm_prediction=scaler_y.inverse_transform(svm_prediction.reshape(-1,1))
# y_unseen=scaler_y.inverse_transform(y_unseen.reshape(-1,1))

# %%
plt.plot(y_unseen, marker='.', label="true")
plt.plot(svm_prediction, 'r',marker='*', label="prediction")
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %%
r2_score(y_unseen,svm_prediction)
# Out:
# 0.7066531602923509

# %%
mean_squared_error(y_unseen,svm_prediction,squared=False)
# Out:
# 11.381595524733173

# %%
mean_absolute_percentage_error(y_unseen,svm_prediction)
# Out:
# 0.018077287052672076
